# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 1000
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  133
#      Geometry Stories  Geometry Building Number Units  \
# 0                   3                               3
# 1                   1                               1
# 2                  20                              67
# 3                   1                               1
# 4                   5                              43
# ..                ...                             ...
# 995                 2                               6
# 996                13                              67
# 997                 1                               1
# 998                 3                               3
# 999                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                  Bottom
# 1                          Not Applicable                    None
# 2                                  Middle                  Middle
# 3                          Not Applicable                    None
# 4                                  Middle                     Top
# ..                                    ...                     ...
# 995                                  Left                     Top
# 996                                  Left                  Middle
# 997                        Not Applicable                    None
# 998                        Not Applicable                     Top
# 999                        Not Applicable                    None
#
#                                    Windows    Insulation Wall  \
# 0            Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 1    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R17.2
# 2            Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 3            Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 4                Double, Clear, Metal, Air  QC_WoodStud-R12.2
# ..                                     ...                ...
# 995          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 996          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 997          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 998              Double, Clear, Metal, Air  QC_WoodStud-R18.9
# 999              Double, Clear, Metal, Air    QC_WoodStud-R14
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R12.5    QC_Wall-R10.1, interior
# 1             QC_R27.3    QC_Wall-R14.4, interior
# 2             QC_R12.5    QC_Wall-R10.1, interior
# 3             QC_R30.9    QC_Wall-R17.1, interior
# 4             QC_R12.5    QC_Wall-R10.1, interior
# ..                 ...                        ...
# 995             QC_R41      QC_Wall-R17, interior
# 996             QC_R41      QC_Wall-R17, interior
# 997           QC_R30.9    QC_Wall-R17.1, interior
# 998           QC_R29.8    QC_Wall-R17.1, interior
# 999           QC_R24.6      QC_Wall-R12, interior
#
#     Geometry Wall Exterior Finish geometry attic type  ... Eclairage_LED  \
# 0                            None        Vented Attic  ...  Plus de 50 %
# 1                            None        Vented Attic  ...            0%
# 2                            None        Vented Attic  ...   Ne sait pas
# 3                            None        Vented Attic  ...            0%
# 4                            None        Vented Attic  ...            0%
# ..                            ...                 ...  ...           ...
# 995                          None        Vented Attic  ...  Plus de 50 %
# 996                          None        Vented Attic  ...      1 à 24 %
# 997                          None        Vented Attic  ...     25 à 50 %
# 998                          None        Vented Attic  ...  Plus de 50 %
# 999                          None        Vented Attic  ...            0%
#
#     Type_Batiment An_Construction     Infiltration An_ConstructionCode  \
# 0            Plex          < 1950   Option=6 ACH50       [1946 - 1971)
# 1          Maison   [1970 - 1980)   Option=6 ACH50       [1946 - 1971)
# 2      Collective          < 1950  Option=15 ACH50              < 1946
# 3          Maison   [1990 - 2000)   Option=6 ACH50       [1986 - 2013)
# 4      Collective          < 1950   Option=8 ACH50              < 1946
# ..            ...             ...              ...                 ...
# 995    Collective   [2010 - 2020)   Option=4 ACH50             >= 2013
# 996    Collective         >= 2020   Option=5 ACH50             >= 2013
# 997        Maison   [1980 - 1990)   Option=1 ACH50       [1986 - 2013)
# 998          Plex   [2000 - 2010)   Option=1 ACH50       [1986 - 2013)
# 999        Maison   [1960 - 1970)   Option=7 ACH50       [1946 - 1971)
#
#     Source_Energie_Chauf Cuisiniere_Energie  \
# 0            Electricite         Electrique
# 1                   Bois         Electrique
# 2            Electricite         Electrique
# 3            Electricite         Electrique
# 4            Electricite         Electrique
# ..                   ...                ...
# 995          Electricite         Electrique
# 996          Electricite         Electrique
# 997          Electricite              Aucun
# 998          Electricite         Electrique
# 999          Electricite         Electrique
#
#                                     Chauffage_Logement  \
# 0      Unités convecteurs, plancher ou plafond radiant
# 1    Fournaise ou poêle à bois et Plinthes électriques
# 2      Unités convecteurs, plancher ou plafond radiant
# 3      Unités convecteurs, plancher ou plafond radiant
# 4                                 Plinthes électriques
# ..                                                 ...
# 995                               Plinthes électriques
# 996                               Plinthes électriques
# 997                               Plinthes électriques
# 998                               Plinthes électriques
# 999                               Plinthes électriques
#
#                  Climatisation ChaufEau_ChaufType
# 0                       Murale         Electrique
# 1                       Aucune         Electrique
# 2    Fenêtre, mobile, portable         Electrique
# 3                       Aucune         Electrique
# 4    Fenêtre, mobile, portable         Electrique
# ..                         ...                ...
# 995                     Aucune         Electrique
# 996                     Murale         Electrique
# 997  Fenêtre, mobile, portable         Electrique
# 998                     Murale         Electrique
# 999  Fenêtre, mobile, portable         Electrique
#
# [1000 rows x 67 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 995  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 996  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 997  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 998  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 999  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 995                                        True                         -5
# 996                                        True                         -5
# 997                                        True                         -5
# 998                                        True                         -5
# 999                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              3          apartment unit
# 1                              1  single-family detached
# 2                             67          apartment unit
# 3                              1  single-family detached
# 4                             43          apartment unit
# ..                           ...                     ...
# 995                            6          apartment unit
# 996                           67          apartment unit
# 997                            1  single-family detached
# 998                            3          apartment unit
# 999                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      0.5556
# 1                                  8                      1.8000
# 2                                  8                      0.5556
# 3                                  8                      1.8000
# 4                                  8                      0.5556
# ..                               ...                         ...
# 995                                8                      0.5556
# 996                                8                      0.5556
# 997                                8                      1.8000
# 998                                8                      0.5556
# 999                                8                      1.8000
#
#      geometry_unit_cfa  year_built  geometry_unit_num_bedrooms  ...  \
# 0                 1682        1940                           3  ...
# 1                 1698        1975                           3  ...
# 2                  750        1940                           2  ...
# 3                  750        1995                           2  ...
# 4                 1138        1940                           3  ...
# ..                 ...         ...                         ...  ...
# 995               3750        2015                           1  ...
# 996               1138        2020                           2  ...
# 997                750        1985                           5  ...
# 998               1138        2005                           2  ...
# 999               1228        1965                           4  ...
#
#      misc_plug_loads_vehicle_annual_kwh  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                3274.0
# ..                                  ...
# 995                                 NaN
# 996                                 NaN
# 997                                 NaN
# 998                                 NaN
# 999                                 NaN
#
#     misc_plug_loads_vehicle_usage_multiplier  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        1.0
# ..                                       ...
# 995                                      NaN
# 996                                      NaN
# 997                                      NaN
# 998                                      NaN
# 999                                      NaN
#
#     heat_pump_heating_capacity_retention_fraction  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 995                                           NaN
# 996                                           NaN
# 997                                           NaN
# 998                                           NaN
# 999                                           NaN
#
#     heat_pump_heating_capacity_retention_temp  heat_pump_is_ducted  \
# 0                                         NaN                  NaN
# 1                                         NaN                  NaN
# 2                                         NaN                  NaN
# 3                                         NaN                  NaN
# 4                                         NaN                  NaN
# ..                                        ...                  ...
# 995                                       NaN                  NaN
# 996                                       NaN                  NaN
# 997                                       NaN                  NaN
# 998                                       NaN                  NaN
# 999                                       NaN                  NaN
#
#     heat_pump_cooling_compressor_type  heat_pump_compressor_lockout_temp  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ..                                ...                                ...
# 995                               NaN                                NaN
# 996                               NaN                                NaN
# 997                               NaN                                NaN
# 998                               NaN                                NaN
# 999                               NaN                                NaN
#
#      geothermal_loop_grout_type  geothermal_loop_pipe_type  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 995                         NaN                        NaN
# 996                         NaN                        NaN
# 997                         NaN                        NaN
# 998                         NaN                        NaN
# 999                         NaN                        NaN
#
#      simulation_control_ground_to_air_heat_pump_model_type
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
# [1000 rows x 143 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
