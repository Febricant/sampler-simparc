# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  134
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                   1                               1
# 2                   2                               2
# 3                   9                             183
# 4                   1                              16
# ..                ...                             ...
# 195                 1                               1
# 196                 2                               2
# 197                 1                               1
# 198                 1                               1
# 199                11                             116
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                          Not Applicable                    None
# 2                          Not Applicable                     Top
# 3                                  Middle                  Middle
# 4                                  Middle                  Bottom
# ..                                    ...                     ...
# 195                        Not Applicable                    None
# 196                        Not Applicable                  Bottom
# 197                        Not Applicable                    None
# 198                        Not Applicable                    None
# 199                                  Left                  Middle
#
#     Infiltration                                Windows    Insulation Wall  \
# 0        7 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# 1        5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 2        5 ACH50              Double, Clear, Metal, Air  QC_WoodStud-R12.6
# 3        4 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 4        4 ACH50              Double, Clear, Metal, Air  QC_WoodStud-R18.9
# ..           ...                                    ...                ...
# 195     15 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 196      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 197     15 ACH50          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# 198      6 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# 199      7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R30.9    QC_Wall-R17.1, interior
# 1             QC_R30.9    QC_Wall-R17.1, interior
# 2             QC_R18.3      QC_Wall-R12, interior
# 3             QC_R29.8    QC_Wall-R17.1, interior
# 4             QC_R29.8    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195           QC_R30.9    QC_Wall-R17.1, interior
# 196           QC_R29.8    QC_Wall-R17.1, interior
# 197           QC_R24.6      QC_Wall-R12, interior
# 198           QC_R30.9    QC_Wall-R17.1, interior
# 199           QC_R12.5    QC_Wall-R10.1, interior
#
#     Geometry Wall Exterior Finish  ... Spa_Logement Spa_Saison  \
# 0                            None  ...        Aucun      Aucun
# 1                            None  ...        Aucun      Aucun
# 2                            None  ...        Aucun      Aucun
# 3                            None  ...        Aucun      Aucun
# 4                            None  ...        Aucun      Aucun
# ..                            ...  ...          ...        ...
# 195                          None  ...        Aucun      Aucun
# 196                          None  ...        Aucun      Aucun
# 197                          None  ...        Aucun      Aucun
# 198                          None  ...        Aucun      Aucun
# 199                          None  ...        Aucun      Aucun
#
#     Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide Type_Batiment  \
# 0                          Aucun                        Aucun        Maison
# 1                          Aucun                        Aucun        Maison
# 2                          Aucun                        Aucun          Plex
# 3                          Aucun                        Aucun    Collective
# 4                          Aucun                        Aucun    Collective
# ..                           ...                          ...           ...
# 195                        Aucun                        Aucun        Maison
# 196                        Aucun                        Aucun          Plex
# 197                        Aucun                        Aucun        Maison
# 198                        Aucun                        Aucun        Maison
# 199                        Aucun                        Aucun    Collective
#
#     Source_Energie_Chauf                                 Chauffage_Logement  \
# 0            Electricite         Thermopompe murale et Plinthes électriques
# 1            Electricite         Thermopompe murale et Plinthes électriques
# 2            Electricite                               Plinthes électriques
# 3            Electricite                               Plinthes électriques
# 4            Electricite                               Plinthes électriques
# ..                   ...                                                ...
# 195          Electricite    Unités convecteurs, plancher ou plafond radiant
# 196          Electricite                               Plinthes électriques
# 197          Electricite                               Plinthes électriques
# 198                 Bois  Fournaise ou poêle à bois et Unités convecteur...
# 199          Electricite                               Plinthes électriques
#
#                  Climatisation ChaufEau_ChaufType Cuisiniere_Energie
# 0                       Murale         Electrique         Electrique
# 1                       Murale         Electrique         Electrique
# 2    Fenêtre, mobile, portable         Electrique         Electrique
# 3    Fenêtre, mobile, portable         Electrique         Electrique
# 4                       Murale         Electrique         Electrique
# ..                         ...                ...                ...
# 195                     Murale         Electrique         Electrique
# 196  Fenêtre, mobile, portable              Aucun         Electrique
# 197                     Murale         Electrique         Electrique
# 198                     Aucune         Electrique         Electrique
# 199  Fenêtre, mobile, portable         Electrique         Electrique
#
# [200 rows x 67 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 196  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 199  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                              1  single-family detached
# 2                              2          apartment unit
# 3                            183          apartment unit
# 4                             16          apartment unit
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                            2          apartment unit
# 197                            1  single-family detached
# 198                            1  single-family detached
# 199                          116          apartment unit
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      1.8000
# 2                                  8                      0.5556
# 3                                  8                      0.5556
# 4                                  8                      0.5556
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      0.5556
# 197                                8                      1.8000
# 198                                8                      1.8000
# 199                                8                      0.5556
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 1698                        0.50        1995  ...
# 1                 2179                        0.50        1995  ...
# 2                 1682                        0.50        1955  ...
# 3                 1682                        0.50        2005  ...
# 4                 1682                        0.50        2005  ...
# ..                 ...                         ...         ...  ...
# 195               1698                        0.50        2005  ...
# 196               1138                        0.50        2005  ...
# 197                298                        0.75        1955  ...
# 198               2678                        0.50        1995  ...
# 199                750                        0.50        1940  ...
#
#      door_area  overhangs_front_depth  \
# 0           20                    NaN
# 1           20                    NaN
# 2           20                   10.0
# 3           20                    NaN
# 4           20                    NaN
# ..         ...                    ...
# 195         20                    NaN
# 196         20                   10.0
# 197         20                    NaN
# 198         20                    NaN
# 199         20                    NaN
#
#      overhangs_front_distance_to_top_of_window  \
# 0                                          NaN
# 1                                          NaN
# 2                                          1.0
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 195                                        NaN
# 196                                        1.0
# 197                                        NaN
# 198                                        NaN
# 199                                        NaN
#
#      cooling_system_cooling_compressor_type  \
# 0                                       NaN
# 1                                       NaN
# 2                              single stage
# 3                              single stage
# 4                            variable speed
# ..                                      ...
# 195                          variable speed
# 196                            single stage
# 197                          variable speed
# 198                                    None
# 199                            single stage
#
#     misc_plug_loads_vehicle_annual_kwh  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 195                                NaN
# 196                                NaN
# 197                                NaN
# 198                                NaN
# 199                                NaN
#
#      misc_plug_loads_vehicle_usage_multiplier  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       NaN
# 198                                       NaN
# 199                                       NaN
#
#     heat_pump_compressor_lockout_temp  geothermal_loop_grout_type  \
# 0                                 NaN                         NaN
# 1                                 NaN                         NaN
# 2                                 NaN                         NaN
# 3                                 NaN                         NaN
# 4                                 NaN                         NaN
# ..                                ...                         ...
# 195                               NaN                         NaN
# 196                               NaN                         NaN
# 197                               NaN                         NaN
# 198                               NaN                         NaN
# 199                               NaN                         NaN
#
#      geothermal_loop_pipe_type  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 195                        NaN
# 196                        NaN
# 197                        NaN
# 198                        NaN
# 199                        NaN
#
#      simulation_control_ground_to_air_heat_pump_model_type
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
# [200 rows x 143 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
