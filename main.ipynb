# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  131
#      Geometry Stories  Geometry Building Number Units  \
# 0                  12                             116
# 1                  35                             326
# 2                   7                              12
# 3                   3                               3
# 4                   1                               1
# ..                ...                             ...
# 195                 1                               1
# 196                 1                               1
# 197                 1                               1
# 198                 1                               1
# 199                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                                    Left                  Bottom
# 1                                  Middle                  Middle
# 2                                    Left                  Middle
# 3                          Not Applicable                  Middle
# 4                          Not Applicable                    None
# ..                                    ...                     ...
# 195                        Not Applicable                    None
# 196                        Not Applicable                    None
# 197                        Not Applicable                    None
# 198                        Not Applicable                    None
# 199                        Not Applicable                    None
#
#     Infiltration                                Windows    Insulation Wall  \
# 0        5 ACH50  Double, Low-E, Non-metal, Air, M-Gain  QC_WoodStud-R18.9
# 1        3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 2        5 ACH50              Double, Clear, Metal, Air  QC_WoodStud-R12.6
# 3        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 4       10 ACH50              Double, Clear, Metal, Air    QC_WoodStud-R14
# ..           ...                                    ...                ...
# 195     15 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 196      7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 197     10 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 198      7 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R17.2
# 199      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R29.8    QC_Wall-R17.1, interior
# 1               QC_R41      QC_Wall-R17, interior
# 2             QC_R18.3      QC_Wall-R12, interior
# 3               QC_R41      QC_Wall-R17, interior
# 4             QC_R24.6      QC_Wall-R12, interior
# ..                 ...                        ...
# 195           QC_R27.3    QC_Wall-R14.4, interior
# 196           QC_R27.3    QC_Wall-R14.4, interior
# 197           QC_R30.9    QC_Wall-R17.1, interior
# 198           QC_R27.3    QC_Wall-R14.4, interior
# 199           QC_R30.9    QC_Wall-R17.1, interior
#
#     Geometry Wall Exterior Finish  ... Spa_Logement Spa_Saison  \
# 0                            None  ...        Aucun      Aucun
# 1                            None  ...        Aucun      Aucun
# 2                            None  ...        Aucun      Aucun
# 3                            None  ...        Aucun      Aucun
# 4                            None  ...        Aucun      Aucun
# ..                            ...  ...          ...        ...
# 195                          None  ...        Aucun      Aucun
# 196                          None  ...        Aucun      Aucun
# 197                          None  ...        Aucun      Aucun
# 198                          None  ...        Aucun      Aucun
# 199                          None  ...        Aucun      Aucun
#
#     Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide Type_Batiment  \
# 0                          Aucun                        Aucun    Collective
# 1                          Aucun                        Aucun    Collective
# 2                          Aucun                        Aucun    Collective
# 3                          Aucun                        Aucun          Plex
# 4                          Aucun                        Aucun        Maison
# ..                           ...                          ...           ...
# 195                        Aucun                        Aucun        Maison
# 196                        Aucun                        Aucun        Maison
# 197                        Aucun                        Aucun        Maison
# 198                        Aucun                        Aucun        Maison
# 199                        Aucun                        Aucun        Maison
#
#     Source_Energie_Chauf                               Chauffage_Logement  \
# 0            Electricite                             Plinthes électriques
# 1            Electricite                             Plinthes électriques
# 2            Electricite                             Plinthes électriques
# 3            Electricite                             Plinthes électriques
# 4            Electricite  Unités convecteurs, plancher ou plafond radiant
# ..                   ...                                              ...
# 195          Electricite                      Système central à air chaud
# 196          Electricite                             Plinthes électriques
# 197          Electricite                             Plinthes électriques
# 198          Electricite       Thermopompe murale et Plinthes électriques
# 199           Bi-energie                      Système central à air chaud
#
#                  Climatisation ChaufEau_ChaufType Cuisiniere_Energie
# 0    Fenêtre, mobile, portable         Electrique         Electrique
# 1                     Centrale         Electrique         Electrique
# 2                       Murale         Electrique         Electrique
# 3    Fenêtre, mobile, portable         Electrique         Electrique
# 4    Fenêtre, mobile, portable         Electrique         Electrique
# ..                         ...                ...                ...
# 195  Fenêtre, mobile, portable        Ne sait pas         Electrique
# 196                     Aucune         Electrique         Electrique
# 197                     Murale         Electrique         Electrique
# 198                     Murale         Electrique                Gaz
# 199  Fenêtre, mobile, portable         Electrique         Electrique
#
# [200 rows x 67 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                            116          apartment unit
# 1                            326          apartment unit
# 2                             12          apartment unit
# 3                              3          apartment unit
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                            1  single-family detached
# 197                            1  single-family detached
# 198                            1  single-family detached
# 199                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      0.5556
# 1                                  8                      0.5556
# 2                                  8                      0.5556
# 3                                  8                      0.5556
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      1.8000
# 197                                8                      1.8000
# 198                                8                      1.8000
# 199                                8                      1.8000
#
#      geometry_unit_cfa  year_built  geometry_unit_num_bedrooms  ...  \
# 0                 2115        1985                           5  ...
# 1                 1682        2015                           2  ...
# 2                  750        1955                           2  ...
# 3                  322        2020                           1  ...
# 4                 1698        1965                           4  ...
# ..                 ...         ...                         ...  ...
# 195                750        1975                           2  ...
# 196               1228        1975                           3  ...
# 197               1228        2005                           3  ...
# 198               2678        1975                           5  ...
# 199               2179        2005                           5  ...
#
#      door_area overhangs_front_depth  \
# 0           20                   NaN
# 1           20                   NaN
# 2           20                   NaN
# 3           20                  10.0
# 4           20                   NaN
# ..         ...                   ...
# 195         20                   NaN
# 196         20                   NaN
# 197         20                   NaN
# 198         20                   NaN
# 199         20                   NaN
#
#     overhangs_front_distance_to_top_of_window heat_pump_is_ducted  \
# 0                                         NaN                 NaN
# 1                                         NaN                 NaN
# 2                                         NaN                 NaN
# 3                                         1.0                 NaN
# 4                                         NaN                 NaN
# ..                                        ...                 ...
# 195                                       NaN                 NaN
# 196                                       NaN                 NaN
# 197                                       NaN                 NaN
# 198                                       NaN               false
# 199                                       NaN                 NaN
#
#      heat_pump_cooling_compressor_type  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 195                                NaN
# 196                                NaN
# 197                                NaN
# 198                     variable speed
# 199                                NaN
#
#     heat_pump_heating_capacity_retention_fraction  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 195                                           NaN
# 196                                           NaN
# 197                                           NaN
# 198                                          0.25
# 199                                           NaN
#
#      heat_pump_heating_capacity_retention_temp  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 195                                        NaN
# 196                                        NaN
# 197                                        NaN
# 198                                       -5.0
# 199                                        NaN
#
#      misc_plug_loads_vehicle_annual_kwh  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 195                                 NaN
# 196                                 NaN
# 197                              3274.0
# 198                                 NaN
# 199                                 NaN
#
#      misc_plug_loads_vehicle_usage_multiplier  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       1.0
# 198                                       NaN
# 199                                       NaN
#
#      heat_pump_compressor_lockout_temp
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 195                                NaN
# 196                                NaN
# 197                                NaN
# 198                                NaN
# 199                                NaN
#
# [200 rows x 140 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
