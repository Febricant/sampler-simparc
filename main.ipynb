# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBachArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 10
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBachArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire


MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)
display(pd.DataFrame(lst_dct_args))
dfHPXML = pd.DataFrame(lst_dct_HPXML)
dfHPXML.to_csv("building-test.csv", index=False)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  196
#   geometry_building_num_units          Territoire_HQ     Type_Logement  \
# 0                           1               Montréal  Maison en rangee
# 1                           6               Montréal        Collective
# 2                           2  Est et Nord du Québec            Duplex
# 3                           4              Richelieu        Collective
# 4                          19            Montmorency        Collective
# 5                         200               Montréal        Collective
# 6                           2              Richelieu            Duplex
# 7                           2               Montréal            Duplex
# 8                           8               Montréal        Collective
# 9                          45               Montréal        Collective
#
#   Mode_Occupation     Presence_Garage Nombre_Etages  \
# 0    Proprietaire       Pas de Garage   Deux étages
# 1       Locataire       Pas de Garage      Un étage
# 2    Proprietaire       Pas de Garage   Deux étages
# 3       Locataire       Pas de Garage      Un étage
# 4       Locataire       Pas de Garage      Un étage
# 5    Proprietaire       Pas de Garage      Un étage
# 6       Locataire       Pas de Garage      Un étage
# 7    Proprietaire  Garage non chauffé      Un étage
# 8    Proprietaire       Pas de Garage   Deux étages
# 9       Locataire       Pas de Garage      Un étage
#
#                    Presence_SousSol Nombre_Pieces Nombre_Personnes  \
# 0                   Sous sol 6 pied             4        5 et plus
# 1  Aucun Sous-sol ou vide sanitaire             6                2
# 2  Aucun Sous-sol ou vide sanitaire             7                1
# 3  Aucun Sous-sol ou vide sanitaire             4                2
# 4  Aucun Sous-sol ou vide sanitaire             5                1
# 5  Aucun Sous-sol ou vide sanitaire             3                1
# 6  Aucun Sous-sol ou vide sanitaire             3                2
# 7  Aucun Sous-sol ou vide sanitaire             3                4
# 8  Aucun Sous-sol ou vide sanitaire             6                2
# 9  Aucun Sous-sol ou vide sanitaire             2                1
#
#   Superficie_Totale An_Construction Source_Energie_Chauf
# 0      [500 - 1000)   [2000 - 2010)          Electricite
# 1     [2500 - 3000)   [1970 - 1980)          Electricite
# 2     [2000 - 2500)   [1960 - 1970)          Electricite
# 3     [1000 - 1500)   [1980 - 1990)          Electricite
# 4     [1500 - 2000)          < 1950          Electricite
# 5         [1 - 500)          < 1950          Electricite
# 6      [500 - 1000)   [1950 - 1960)          Electricite
# 7     [1500 - 2000)          < 1950          Electricite
# 8     [1000 - 1500)   [1970 - 1980)          Electricite
# 9         [1 - 500)   [1980 - 1990)          Electricite
#   geometry_building_num_units  \
# 0                           1
# 1                           6
# 2                           2
# 3                           4
# 4                          19
# 5                         200
# 6                           2
# 7                           2
# 8                           8
# 9                          45
#
#                         weather_station_epw_filepath  \
# 0  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2  2020s_CAN_QC_Saguenay-Bagotville.AP-CFB.Bagotv...
# 3  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 5  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 6  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 7  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 8  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 9  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#    simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                        True                         -5
# 1                                        True                         -5
# 2                                        True                         -5
# 3                                        True                         -5
# 4                                        True                         -5
# 5                                        True                         -5
# 6                                        True                         -5
# 7                                        True                         -5
# 8                                        True                         -5
# 9                                        True                         -5
#
#        geometry_unit_type  geometry_average_ceiling_height  \
# 0  single-family attached                                8
# 1          apartment unit                                8
# 2          apartment unit                                8
# 3          apartment unit                                8
# 4          apartment unit                                8
# 5          apartment unit                                8
# 6          apartment unit                                8
# 7          apartment unit                                8
# 8          apartment unit                                8
# 9          apartment unit                                8
#
#    geometry_unit_aspect_ratio  geometry_unit_cfa  geometry_garage_protrusion  \
# 0                      0.5556                750                        0.50
# 1                      0.5556               2648                        0.50
# 2                      0.5556               2115                        0.50
# 3                      0.5556               1138                        0.50
# 4                      0.5556               1682                        0.50
# 5                      0.5556                322                        0.75
# 6                      0.5556                750                        0.50
# 7                      0.5556               1682                        0.50
# 8                      0.5556               1138                        0.50
# 9                      0.5556                322                        0.75
#
#    year_built  ...  window_back_wwr  geometry_attic_type  \
# 0        2005  ...             0.18          VentedAttic
# 1        1975  ...             0.18          VentedAttic
# 2        1965  ...             0.18          VentedAttic
# 3        1985  ...             0.18          VentedAttic
# 4        1940  ...             0.18          VentedAttic
# 5        1940  ...             0.18          VentedAttic
# 6        1955  ...             0.18          VentedAttic
# 7        1940  ...             0.18          VentedAttic
# 8        1975  ...             0.18          VentedAttic
# 9        1985  ...             0.18          VentedAttic
#
#    misc_fuel_loads_grill_fuel_type  heat_pump_cooling_efficiency_type  \
# 0                      natural gas                               SEER
# 1                      natural gas                               SEER
# 2                      natural gas                               SEER
# 3                      natural gas                               SEER
# 4                      natural gas                               SEER
# 5                      natural gas                               SEER
# 6                      natural gas                               SEER
# 7                      natural gas                               SEER
# 8                      natural gas                               SEER
# 9                      natural gas                               SEER
#
#   ducts_supply_leakage_to_outside_value  clothes_dryer_present  \
# 0                                   0.1                   true
# 1                                   0.1                   true
# 2                                   0.1                   true
# 3                                   0.1                   true
# 4                                   0.1                   true
# 5                                   0.1                   true
# 6                                   0.1                   true
# 7                                   0.1                   true
# 8                                   0.1                   true
# 9                                   0.1                   true
#
#   geometry_roof_pitch  lighting_interior_fraction_led  ceiling_fan_present  \
# 0                6:12                               0                 true
# 1                6:12                               0                 true
# 2                6:12                               0                 true
# 3                6:12                               0                 true
# 4                6:12                               0                 true
# 5                6:12                               0                 true
# 6                6:12                               0                 true
# 7                6:12                               0                 true
# 8                6:12                               0                 true
# 9                6:12                               0                 true
#
#    neighbor_left_distance
# 0                      10
# 1                      10
# 2                      10
# 3                      10
# 4                      10
# 5                      10
# 6                      10
# 7                      10
# 8                      10
# 9                      10
#
# [10 rows x 196 columns]
