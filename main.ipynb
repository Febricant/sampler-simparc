# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 10
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
display(df1)
pd.DataFrame(lst_dct_HPXML)
# Out:
# Nombre d'attributs HPXML:  191
#   Territoire_HQ        Type_Logement Mode_Occupation  \
# 0   Montmorency  Maison individuelle    Proprietaire
# 1   Montmorency           Collective       Locataire
# 2     Richelieu           Collective       Locataire
# 3   Laurentides  Maison individuelle    Proprietaire
# 4   Montmorency           Collective    Proprietaire
# 5      Montréal           Collective    Proprietaire
# 6     Richelieu  Maison individuelle    Proprietaire
# 7      Montréal           Collective       Locataire
# 8   Laurentides           Collective       Locataire
# 9   Montmorency  Maison individuelle    Proprietaire
#
#                 Presence_Garage         Nombre_Etages  \
# 0  Garage chauffé à électricité           Deux étages
# 1                 Pas de Garage              Un étage
# 2                 Pas de Garage              Un étage
# 3            Garage non chauffé           Deux étages
# 4                 Pas de Garage              Un étage
# 5                 Pas de Garage              Un étage
# 6                 Pas de Garage           Deux étages
# 7                 Pas de Garage              Un étage
# 8                 Pas de Garage              Un étage
# 9                 Pas de Garage  Trois étages et plus
#
#                    Presence_SousSol Nombre_Pieces Nombre_Personnes  \
# 0                   Sous sol 6 pied             6                2
# 1  Aucun Sous-sol ou vide sanitaire             4                1
# 2  Aucun Sous-sol ou vide sanitaire             5                1
# 3                   Sous sol 6 pied             6        5 et plus
# 4  Aucun Sous-sol ou vide sanitaire             3                1
# 5  Aucun Sous-sol ou vide sanitaire             4                2
# 6                   Sous sol 6 pied             6                3
# 7  Aucun Sous-sol ou vide sanitaire             5                2
# 8  Aucun Sous-sol ou vide sanitaire             4                2
# 9                   Sous sol 6 pied            10                4
#
#   Superficie_Totale An_Construction Source_Energie_Chauf
# 0     [1000 - 1500)   [2000 - 2010)                 Bois
# 1     [1000 - 1500)   [2010 - 2020)          Electricite
# 2     [1000 - 1500)   [1960 - 1970)          Electricite
# 3     [1500 - 2000)   [2010 - 2020)          Electricite
# 4      [500 - 1000)   [2000 - 2010)          Electricite
# 5      [500 - 1000)   [1950 - 1960)          Electricite
# 6     [2500 - 3000)   [2010 - 2020)          Electricite
# 7     [1000 - 1500)   [1970 - 1980)          Electricite
# 8     [1000 - 1500)   [2000 - 2010)          Electricite
# 9     [1000 - 1500)   [1990 - 2000)          Electricite
#        geometry_unit_type  geometry_average_ceiling_height  \
# 0  single-family detached                                8
# 1          apartment unit                                8
# 2          apartment unit                                8
# 3  single-family detached                                8
# 4          apartment unit                                8
# 5          apartment unit                                8
# 6  single-family detached                                8
# 7          apartment unit                                8
# 8          apartment unit                                8
# 9  single-family detached                                8
#
#    geometry_unit_aspect_ratio  geometry_unit_cfa  geometry_garage_protrusion  \
# 0                      1.8000               1228                         0.5
# 1                      0.5556               1138                         0.5
# 2                      0.5556               1138                         0.5
# 3                      1.8000               1698                         0.5
# 4                      0.5556                750                         0.5
# 5                      0.5556                750                         0.5
# 6                      1.8000               2678                         0.5
# 7                      0.5556               1138                         0.5
# 8                      0.5556               1138                         0.5
# 9                      1.8000               1228                         0.5
#
#    year_built  geometry_unit_num_bedrooms  geometry_unit_num_occupants  \
# 0        2005                           3                            2
# 1        2015                           2                            1
# 2        1965                           3                            1
# 3        2015                           3                            5
# 4        2005                           2                            1
# 5        1955                           2                            2
# 6        2015                           3                            3
# 7        1975                           3                            2
# 8        2005                           2                            2
# 9        1995                           5                            4
#
#    geometry_garage_width  geometry_garage_depth  ...  \
# 0                     24                     24  ...
# 1                      0                     24  ...
# 2                      0                     24  ...
# 3                     24                     24  ...
# 4                      0                     24  ...
# 5                      0                     24  ...
# 6                      0                     24  ...
# 7                      0                     24  ...
# 8                      0                     24  ...
# 9                      0                     24  ...
#
#   hot_water_distribution_system_type  slab_perimeter_insulation_r  \
# 0                           Standard                            0
# 1                           Standard                            0
# 2                           Standard                            0
# 3                           Standard                            0
# 4                           Standard                            0
# 5                           Standard                            0
# 6                           Standard                            0
# 7                           Standard                            0
# 8                           Standard                            0
# 9                           Standard                            0
#
#   pv_system_2_array_azimuth mech_vent_sensible_recovery_efficiency  \
# 0                       180                                   0.72
# 1                       180                                   0.72
# 2                       180                                   0.72
# 3                       180                                   0.72
# 4                       180                                   0.72
# 5                       180                                   0.72
# 6                       180                                   0.72
# 7                       180                                   0.72
# 8                       180                                   0.72
# 9                       180                                   0.72
#
#   window_aspect_ratio      cooling_system_type  \
# 0               1.333  central air conditioner
# 1               1.333  central air conditioner
# 2               1.333  central air conditioner
# 3               1.333  central air conditioner
# 4               1.333  central air conditioner
# 5               1.333  central air conditioner
# 6               1.333  central air conditioner
# 7               1.333  central air conditioner
# 8               1.333  central air conditioner
# 9               1.333  central air conditioner
#
#   misc_plug_loads_vehicle_present mech_vent_2_flow_rate window_right_wwr  \
# 0                           false                   110             0.18
# 1                           false                   110             0.18
# 2                           false                   110             0.18
# 3                           false                   110             0.18
# 4                           false                   110             0.18
# 5                           false                   110             0.18
# 6                           false                   110             0.18
# 7                           false                   110             0.18
# 8                           false                   110             0.18
# 9                           false                   110             0.18
#
#   lighting_interior_fraction_cfl
# 0                            0.1
# 1                            0.1
# 2                            0.1
# 3                            0.1
# 4                            0.1
# 5                            0.1
# 6                            0.1
# 7                            0.1
# 8                            0.1
# 9                            0.1
#
# [10 rows x 191 columns]
