# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  66
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                   1                              16
# 2                   1                               1
# 3                   3                               3
# 4                   1                               1
# ..                ...                             ...
# 195                 2                              67
# 196                 1                               2
# 197                 1                               1
# 198                14                             116
# 199                 2                               2
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                                  Middle                  Bottom
# 2                          Not Applicable                    None
# 3                          Not Applicable                  Middle
# 4                          Not Applicable                    None
# ..                                    ...                     ...
# 195                                Middle                  Bottom
# 196                                  Left                    None
# 197                        Not Applicable                    None
# 198                                 Right                  Middle
# 199                        Not Applicable                  Bottom
#
#     Infiltration                                Windows    Insulation Wall  \
# 0       10 ACH50                   Single, Clear, Metal    QC_WoodStud-R14
# 1        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 2        3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 3        7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 4        5 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# ..           ...                                    ...                ...
# 195      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 196      1 ACH50  Triple, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R24.5
# 197      6 ACH50          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# 198      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 199      3 ACH50              Double, Clear, Metal, Air  QC_WoodStud-R12.6
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R24.6      QC_Wall-R12, interior
# 1             QC_R29.8    QC_Wall-R17.1, interior
# 2               QC_R41      QC_Wall-R17, interior
# 3             QC_R12.5    QC_Wall-R10.1, interior
# 4             QC_R30.9    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195           QC_R29.8    QC_Wall-R17.1, interior
# 196             QC_R41      QC_Wall-R17, interior
# 197           QC_R24.6      QC_Wall-R12, interior
# 198           QC_R18.3    QC_Wall-R14.4, interior
# 199           QC_R18.3      QC_Wall-R12, interior
#
#     Geometry Wall Exterior Finish  ... Piscine_Minuterie An_Construction  \
# 0                            None  ...             Aucun   [1960 - 1970)
# 1                            None  ...             Aucun   [2000 - 2010)
# 2                            None  ...             Aucun   [2010 - 2020)
# 3                            None  ...             Aucun          < 1950
# 4                            None  ...               Non   [1980 - 1990)
# ..                            ...  ...               ...             ...
# 195                          None  ...             Aucun   [2000 - 2010)
# 196                          None  ...             Aucun   [2010 - 2020)
# 197                          None  ...               Non   [1960 - 1970)
# 198                          None  ...             Aucun   [1970 - 1980)
# 199                          None  ...             Aucun   [1960 - 1970)
#
#     Source_Energie_Chauf    Chauffage_Logement              Climatisation  \
# 0            Electricite  Plinthes électriques  Fenêtre, mobile, portable
# 1            Electricite  Plinthes électriques                     Aucune
# 2            Electricite  Plinthes électriques                     Aucune
# 3            Electricite  Plinthes électriques                     Aucune
# 4            Electricite  Plinthes électriques  Fenêtre, mobile, portable
# ..                   ...                   ...                        ...
# 195          Electricite  Plinthes électriques  Fenêtre, mobile, portable
# 196          Electricite           Thermopompe                   Centrale
# 197          Electricite  Plinthes électriques  Fenêtre, mobile, portable
# 198          Electricite           Thermopompe                   Centrale
# 199           Bi-energie           Thermopompe                   Centrale
#
#     Spa_Presence Spa_Logement Spa_Saison Spa_Utilisation_SaisonChaude  \
# 0            Non        Aucun      Aucun                        Aucun
# 1            Non        Aucun      Aucun                        Aucun
# 2            Non        Aucun      Aucun                        Aucun
# 3            Non        Aucun      Aucun                        Aucun
# 4            Non        Aucun      Aucun                        Aucun
# ..           ...          ...        ...                          ...
# 195          Non        Aucun      Aucun                        Aucun
# 196          Non        Aucun      Aucun                        Aucun
# 197          Non        Aucun      Aucun                        Aucun
# 198          Non        Aucun      Aucun                        Aucun
# 199          Non        Aucun      Aucun                        Aucun
#
#     Spa_Utilisation_SaisonFroide
# 0                          Aucun
# 1                          Aucun
# 2                          Aucun
# 3                          Aucun
# 4                          Aucun
# ..                           ...
# 195                        Aucun
# 196                        Aucun
# 197                        Aucun
# 198                        Aucun
# 199                        Aucun
#
# [200 rows x 37 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 197  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 198  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 199  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                             16          apartment unit
# 2                              1  single-family detached
# 3                              3          apartment unit
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                           67          apartment unit
# 196                            2  single-family attached
# 197                            1  single-family detached
# 198                          116          apartment unit
# 199                            2          apartment unit
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      0.5556
# 2                                  8                      1.8000
# 3                                  8                      0.5556
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      0.5556
# 196                                8                      0.5556
# 197                                8                      1.8000
# 198                                8                      0.5556
# 199                                8                      0.5556
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 1698                         0.5        1965  ...
# 1                 1138                         0.5        2005  ...
# 2                 1228                         0.5        2015  ...
# 3                 1138                         0.5        1940  ...
# 4                 2179                         0.5        1985  ...
# ..                 ...                         ...         ...  ...
# 195               2115                         0.5        2005  ...
# 196                750                         0.5        2015  ...
# 197                750                         0.5        1965  ...
# 198               1138                         0.5        1975  ...
# 199               1682                         0.5        1965  ...
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2              electricity                                  1.0
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199               fuel oil                                  0.8
#
#      geothermal_loop_configuration      cooling_system_type  \
# 0                             none  central air conditioner
# 1                             none                     none
# 2                             none                     none
# 3                             none                     none
# 4                             none  central air conditioner
# ..                             ...                      ...
# 195                           none  central air conditioner
# 196                           none                     none
# 197                           none  central air conditioner
# 198                           none                     none
# 199                           none                     none
#
#     cooling_system_cooling_compressor_type  overhangs_front_depth  \
# 0                             single stage                    NaN
# 1                                     None                    NaN
# 2                                     None                    NaN
# 3                                     None                   10.0
# 4                             single stage                    NaN
# ..                                     ...                    ...
# 195                           single stage                    NaN
# 196                                    NaN                    NaN
# 197                           single stage                    NaN
# 198                                    NaN                    NaN
# 199                                    NaN                   10.0
#
#     overhangs_front_distance_to_top_of_window  heat_pump_is_ducted  \
# 0                                         NaN                  NaN
# 1                                         NaN                  NaN
# 2                                         NaN                  NaN
# 3                                         1.0                  NaN
# 4                                         NaN                  NaN
# ..                                        ...                  ...
# 195                                       NaN                  NaN
# 196                                       NaN                 true
# 197                                       NaN                  NaN
# 198                                       NaN                 true
# 199                                       1.0                 true
#
#      heat_pump_cooling_compressor_type  heat_pump_compressor_lockout_temp
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 195                                NaN                                NaN
# 196                       single stage                                NaN
# 197                                NaN                                NaN
# 198                       single stage                                NaN
# 199                       single stage                               10.4
#
# [200 rows x 71 columns]
