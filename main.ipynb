# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBachArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 10
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBachArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire


MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)
display(pd.DataFrame(lst_dct_args))
dfHPXML = pd.DataFrame(lst_dct_HPXML)
dfHPXML.to_csv("building-test.csv", index=False)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  194
#   geometry_foundation_type Territoire_HQ        Type_Logement Mode_Occupation  \
# 0                     Slab      Montréal           Collective    Proprietaire
# 1          Heated Basement   Laurentides  Maison individuelle    Proprietaire
# 2          Heated Basement     Richelieu  Maison individuelle    Proprietaire
# 3                     Slab   Laurentides           Collective       Locataire
# 4          Heated Basement   Laurentides  Maison individuelle    Proprietaire
# 5                     Slab     Richelieu           Collective       Locataire
# 6                     Slab      Montréal           Collective       Locataire
# 7          Heated Basement      Montréal  Maison individuelle    Proprietaire
# 8          Heated Basement   Laurentides  Maison individuelle    Proprietaire
# 9                     Slab      Montréal  Maison individuelle    Proprietaire
#
#                 Presence_Garage         Nombre_Etages  \
# 0                 Pas de Garage              Un étage
# 1  Garage chauffé à électricité           Deux étages
# 2  Garage chauffé à électricité  Trois étages et plus
# 3                 Pas de Garage              Un étage
# 4  Garage chauffé à électricité  Trois étages et plus
# 5                 Pas de Garage              Un étage
# 6                 Pas de Garage              Un étage
# 7  Garage chauffé à électricité  Trois étages et plus
# 8  Garage chauffé à électricité           Deux étages
# 9  Garage chauffé à électricité           Deux étages
#
#                    Presence_SousSol Nombre_Pieces Nombre_Personnes  \
# 0  Aucun Sous-sol ou vide sanitaire             4                2
# 1                   Sous sol 6 pied             6                2
# 2                   Sous sol 6 pied            12        5 et plus
# 3  Aucun Sous-sol ou vide sanitaire             3                2
# 4                   Sous sol 6 pied             8                2
# 5  Aucun Sous-sol ou vide sanitaire             3                2
# 6  Aucun Sous-sol ou vide sanitaire             4                2
# 7                   Sous sol 6 pied            12                3
# 8                   Sous sol 6 pied            10                3
# 9                   Sous sol 6 pied             7                2
#
#   Superficie_Totale An_Construction Source_Energie_Chauf
# 0     [1000 - 1500)   [1970 - 1980)          Electricite
# 1     [1000 - 1500)   [1960 - 1970)           Bi-energie
# 2           >= 5000   [2000 - 2010)          Electricite
# 3      [500 - 1000)   [1990 - 2000)          Electricite
# 4     [1500 - 2000)          < 1950          Electricite
# 5      [500 - 1000)   [1970 - 1980)          Electricite
# 6     [1000 - 1500)   [1950 - 1960)          Gaz naturel
# 7     [1500 - 2000)   [1990 - 2000)          Electricite
# 8     [2000 - 2500)   [2000 - 2010)          Electricite
# 9      [500 - 1000)   [1980 - 1990)          Electricite
#   geometry_foundation_type                       weather_station_epw_filepath  \
# 0                     Slab  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1          Heated Basement  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2          Heated Basement  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3                     Slab  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4          Heated Basement  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 5                     Slab  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 6                     Slab  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 7          Heated Basement  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 8          Heated Basement  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 9                     Slab  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#    simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                        True                         -5
# 1                                        True                         -5
# 2                                        True                         -5
# 3                                        True                         -5
# 4                                        True                         -5
# 5                                        True                         -5
# 6                                        True                         -5
# 7                                        True                         -5
# 8                                        True                         -5
# 9                                        True                         -5
#
#        geometry_unit_type  geometry_average_ceiling_height  \
# 0          apartment unit                                8
# 1  single-family detached                                8
# 2  single-family detached                                8
# 3          apartment unit                                8
# 4  single-family detached                                8
# 5          apartment unit                                8
# 6          apartment unit                                8
# 7  single-family detached                                8
# 8  single-family detached                                8
# 9  single-family detached                                8
#
#    geometry_unit_aspect_ratio  geometry_unit_cfa  geometry_garage_protrusion  \
# 0                      0.5556               1138                         0.5
# 1                      1.8000               1228                         0.5
# 2                      1.8000               5587                         0.5
# 3                      0.5556                750                         0.5
# 4                      1.8000               1698                         0.5
# 5                      0.5556                750                         0.5
# 6                      0.5556               1138                         0.5
# 7                      1.8000               1698                         0.5
# 8                      1.8000               2179                         0.5
# 9                      1.8000                750                         0.5
#
#    year_built  ...  pv_system_2_array_azimuth  slab_perimeter_insulation_r  \
# 0        1975  ...                        180                            0
# 1        1965  ...                        180                            0
# 2        2005  ...                        180                            0
# 3        1995  ...                        180                            0
# 4        1940  ...                        180                            0
# 5        1975  ...                        180                            0
# 6        1955  ...                        180                            0
# 7        1995  ...                        180                            0
# 8        2005  ...                        180                            0
# 9        1985  ...                        180                            0
#
#    clothes_dryer_present  pv_system_max_power_output heat_pump_backup_type  \
# 0                   true                        4000            integrated
# 1                   true                        4000            integrated
# 2                   true                        4000            integrated
# 3                   true                        4000            integrated
# 4                   true                        4000            integrated
# 5                   true                        4000            integrated
# 6                   true                        4000            integrated
# 7                   true                        4000            integrated
# 8                   true                        4000            integrated
# 9                   true                        4000            integrated
#
#    dwhr_efficiency cooking_range_oven_fuel_type neighbor_front_distance  \
# 0             0.55                  natural gas                       0
# 1             0.55                  natural gas                       0
# 2             0.55                  natural gas                       0
# 3             0.55                  natural gas                       0
# 4             0.55                  natural gas                       0
# 5             0.55                  natural gas                       0
# 6             0.55                  natural gas                       0
# 7             0.55                  natural gas                       0
# 8             0.55                  natural gas                       0
# 9             0.55                  natural gas                       0
#
#   misc_fuel_loads_fireplace_present mech_vent_2_hours_in_operation
# 0                             false                             24
# 1                             false                             24
# 2                             false                             24
# 3                             false                             24
# 4                             false                             24
# 5                             false                             24
# 6                             false                             24
# 7                             false                             24
# 8                             false                             24
# 9                             false                             24
#
# [10 rows x 194 columns]
