# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  129
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                   1                               1
# 2                   1                               1
# 3                   1                               1
# 4                   9                              67
# ..                ...                             ...
# 195                 2                               2
# 196                 4                             116
# 197                 3                               3
# 198                 2                               2
# 199                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                          Not Applicable                    None
# 2                          Not Applicable                    None
# 3                          Not Applicable                    None
# 4                                   Right                     Top
# ..                                    ...                     ...
# 195                        Not Applicable                     Top
# 196                                Middle                  Bottom
# 197                        Not Applicable                  Bottom
# 198                        Not Applicable                     Top
# 199                        Not Applicable                    None
#
#     Infiltration                                Windows    Insulation Wall  \
# 0        7 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# 1        6 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 2        5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 3        5 ACH50                  Double, Low-E, L-Gain  QC_WoodStud-R20.7
# 4        3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# ..           ...                                    ...                ...
# 195      5 ACH50  Triple, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.6
# 196      5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 197      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 198      5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 199      6 ACH50          Double, Clear, Non-metal, Air    QC_WoodStud-R14
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R30.9    QC_Wall-R17.1, interior
# 1             QC_R30.9    QC_Wall-R17.1, interior
# 2             QC_R30.9    QC_Wall-R17.1, interior
# 3             QC_R30.9    QC_Wall-R17.1, interior
# 4               QC_R41      QC_Wall-R17, interior
# ..                 ...                        ...
# 195           QC_R18.3    QC_Wall-R14.4, interior
# 196           QC_R18.3    QC_Wall-R14.4, interior
# 197             QC_R41      QC_Wall-R17, interior
# 198           QC_R12.5    QC_Wall-R10.1, interior
# 199           QC_R24.6      QC_Wall-R12, interior
#
#     Geometry Wall Exterior Finish  ... Spa_Logement    Spa_Saison  \
# 0                            None  ...        Aucun         Aucun
# 1                            None  ...        Aucun         Aucun
# 2                            None  ...        Aucun         Aucun
# 3                            None  ...        Aucun         Aucun
# 4                            None  ...        Aucun         Aucun
# ..                            ...  ...          ...           ...
# 195                          None  ...        Aucun         Aucun
# 196                          None  ...        Aucun         Aucun
# 197                          None  ...        Aucun         Aucun
# 198                          None  ...    Exterieur  Toute_Saison
# 199                          None  ...        Aucun         Aucun
#
#     Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide Type_Batiment  \
# 0                          Aucun                        Aucun        Maison
# 1                          Aucun                        Aucun        Maison
# 2                          Aucun                        Aucun        Maison
# 3                          Aucun                        Aucun        Maison
# 4                          Aucun                        Aucun    Collective
# ..                           ...                          ...           ...
# 195                        Aucun                        Aucun          Plex
# 196                        Aucun                        Aucun    Collective
# 197                        Aucun                        Aucun          Plex
# 198                 Augmentation                     Constant          Plex
# 199                        Aucun                        Aucun        Maison
#
#     Source_Energie_Chauf                                 Chauffage_Logement  \
# 0            Electricite                               Plinthes électriques
# 1            Electricite                               Plinthes électriques
# 2            Electricite                               Plinthes électriques
# 3            Electricite                               Plinthes électriques
# 4            Gaz naturel                       Système central à eau chaude
# ..                   ...                                                ...
# 195          Electricite                               Plinthes électriques
# 196          Electricite                               Plinthes électriques
# 197          Electricite                               Plinthes électriques
# 198          Electricite    Unités convecteurs, plancher ou plafond radiant
# 199                 Bois  Fournaise ou poêle à bois et Plinthes électriques
#
#                  Climatisation ChaufEau_ChaufType Cuisiniere_Energie
# 0    Fenêtre, mobile, portable         Electrique         Electrique
# 1                       Murale         Electrique         Electrique
# 2                       Murale         Electrique         Electrique
# 3                       Aucune         Electrique         Electrique
# 4    Fenêtre, mobile, portable        Gaz Naturel         Electrique
# ..                         ...                ...                ...
# 195  Fenêtre, mobile, portable         Electrique         Electrique
# 196                     Murale         Electrique         Electrique
# 197  Fenêtre, mobile, portable         Electrique         Electrique
# 198  Fenêtre, mobile, portable         Electrique         Electrique
# 199                     Aucune         Electrique         Electrique
#
# [200 rows x 65 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                              1  single-family detached
# 2                              1  single-family detached
# 3                              1  single-family detached
# 4                             67          apartment unit
# ..                           ...                     ...
# 195                            2          apartment unit
# 196                          116          apartment unit
# 197                            3          apartment unit
# 198                            2          apartment unit
# 199                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      1.8000
# 2                                  8                      1.8000
# 3                                  8                      1.8000
# 4                                  8                      0.5556
# ..                               ...                         ...
# 195                                8                      0.5556
# 196                                8                      0.5556
# 197                                8                      0.5556
# 198                                8                      0.5556
# 199                                8                      1.8000
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 2179                        0.50        1985  ...
# 1                 1698                        0.50        2005  ...
# 2                 1228                        0.50        2005  ...
# 3                 3250                        0.50        1985  ...
# 4                  322                        0.75        2015  ...
# ..                 ...                         ...         ...  ...
# 195               1138                        0.50        1975  ...
# 196               1138                        0.50        1975  ...
# 197               1138                        0.50        2015  ...
# 198                750                        0.50        1940  ...
# 199               2179                        0.50        1965  ...
#
#      lighting_garage_fraction_lfl  lighting_garage_fraction_led  \
# 0                               0                          0.12
# 1                               0                          0.75
# 2                               0                          0.75
# 3                               0                          0.75
# 4                               0                          0.37
# ..                            ...                           ...
# 195                             0                          0.75
# 196                             0                          0.00
# 197                             0                          0.00
# 198                             0                          0.75
# 199                             0                          0.75
#
#      lighting_interior_usage_multiplier  heat_pump_is_ducted  \
# 0                                   1.0                  NaN
# 1                                   1.0                  NaN
# 2                                   1.0                  NaN
# 3                                   1.0                  NaN
# 4                                   1.0                  NaN
# ..                                  ...                  ...
# 195                                 1.0                  NaN
# 196                                 1.0                  NaN
# 197                                 1.0                  NaN
# 198                                 1.0                  NaN
# 199                                 1.0                  NaN
#
#     heat_pump_cooling_compressor_type  overhangs_front_depth  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
# ..                                ...                    ...
# 195                               NaN                   10.0
# 196                               NaN                    NaN
# 197                               NaN                   10.0
# 198                               NaN                   10.0
# 199                               NaN                    NaN
#
#     overhangs_front_distance_to_top_of_window  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       1.0
# 196                                       NaN
# 197                                       1.0
# 198                                       1.0
# 199                                       NaN
#
#      misc_plug_loads_vehicle_annual_kwh  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 195                                 NaN
# 196                                 NaN
# 197                                 NaN
# 198                                 NaN
# 199                                 NaN
#
#      misc_plug_loads_vehicle_usage_multiplier  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       NaN
# 198                                       NaN
# 199                                       NaN
#
#      heat_pump_compressor_lockout_temp
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 195                                NaN
# 196                                NaN
# 197                                NaN
# 198                                NaN
# 199                                NaN
#
# [200 rows x 136 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
