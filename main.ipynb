# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 1000
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  133
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                   3                               3
# 2                   7                              12
# 3                   1                               1
# 4                   3                               3
# ..                ...                             ...
# 995                 3                               3
# 996                 1                               1
# 997                 2                               2
# 998                 1                               1
# 999                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                          Not Applicable                     Top
# 2                                    Left                  Middle
# 3                          Not Applicable                    None
# 4                          Not Applicable                  Bottom
# ..                                    ...                     ...
# 995                        Not Applicable                     Top
# 996                        Not Applicable                    None
# 997                        Not Applicable                  Bottom
# 998                        Not Applicable                    None
# 999                        Not Applicable                    None
#
#     Infiltration                        Windows    Insulation Wall  \
# 0       10 ACH50           Single, Clear, Metal    QC_WoodStud-R14
# 1        7 ACH50      Double, Clear, Metal, Air  QC_WoodStud-R12.6
# 2        2 ACH50  Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 3        7 ACH50  Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 4        4 ACH50      Double, Clear, Metal, Air  QC_WoodStud-R18.9
# ..           ...                            ...                ...
# 995      3 ACH50  Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 996     10 ACH50  Double, Clear, Non-metal, Air  QC_WoodStud-R14.5
# 997     15 ACH50  Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 998      5 ACH50  Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 999      5 ACH50  Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R24.6      QC_Wall-R12, interior
# 1             QC_R18.3      QC_Wall-R12, interior
# 2               QC_R41      QC_Wall-R17, interior
# 3             QC_R30.9    QC_Wall-R17.1, interior
# 4             QC_R29.8    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 995             QC_R41      QC_Wall-R17, interior
# 996           QC_R19.6    QC_Wall-R10.1, interior
# 997           QC_R12.5    QC_Wall-R10.1, interior
# 998           QC_R30.9    QC_Wall-R17.1, interior
# 999           QC_R30.9    QC_Wall-R17.1, interior
#
#     Geometry Wall Exterior Finish  ... Spa_Logement Spa_Saison  \
# 0                            None  ...        Aucun      Aucun
# 1                            None  ...        Aucun      Aucun
# 2                            None  ...        Aucun      Aucun
# 3                            None  ...        Aucun      Aucun
# 4                            None  ...        Aucun      Aucun
# ..                            ...  ...          ...        ...
# 995                          None  ...        Aucun      Aucun
# 996                          None  ...        Aucun      Aucun
# 997                          None  ...        Aucun      Aucun
# 998                          None  ...        Aucun      Aucun
# 999                          None  ...        Aucun      Aucun
#
#     Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide Type_Batiment  \
# 0                          Aucun                        Aucun        Maison
# 1                          Aucun                        Aucun          Plex
# 2                          Aucun                        Aucun    Collective
# 3                          Aucun                        Aucun        Maison
# 4                          Aucun                        Aucun          Plex
# ..                           ...                          ...           ...
# 995                        Aucun                        Aucun          Plex
# 996                        Aucun                        Aucun        Maison
# 997                        Aucun                        Aucun          Plex
# 998                        Aucun                        Aucun        Maison
# 999                        Aucun                        Aucun        Maison
#
#     Source_Energie_Chauf                               Chauffage_Logement  \
# 0             Bi-energie       Thermopompe et Système central à air chaud
# 1            Electricite                             Plinthes électriques
# 2            Electricite                             Plinthes électriques
# 3            Electricite                             Plinthes électriques
# 4            Electricite                             Plinthes électriques
# ..                   ...                                              ...
# 995          Electricite                             Plinthes électriques
# 996          Electricite                      Système central à air chaud
# 997          Electricite                             Plinthes électriques
# 998          Electricite                             Plinthes électriques
# 999          Electricite  Unités convecteurs, plancher ou plafond radiant
#
#                  Climatisation ChaufEau_ChaufType Cuisiniere_Energie
# 0                     Centrale         Electrique              Aucun
# 1    Fenêtre, mobile, portable         Electrique         Electrique
# 2    Fenêtre, mobile, portable         Electrique         Electrique
# 3                       Murale         Electrique         Electrique
# 4    Fenêtre, mobile, portable         Electrique         Electrique
# ..                         ...                ...                ...
# 995  Fenêtre, mobile, portable         Electrique         Electrique
# 996                     Murale         Electrique         Electrique
# 997  Fenêtre, mobile, portable         Electrique         Electrique
# 998                     Aucune         Electrique         Electrique
# 999                     Aucune         Electrique         Electrique
#
# [1000 rows x 67 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 995  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 996  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 997  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 998  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 999  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 995                                        True                         -5
# 996                                        True                         -5
# 997                                        True                         -5
# 998                                        True                         -5
# 999                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                              3          apartment unit
# 2                             12          apartment unit
# 3                              1  single-family detached
# 4                              3          apartment unit
# ..                           ...                     ...
# 995                            3          apartment unit
# 996                            1  single-family detached
# 997                            2          apartment unit
# 998                            1  single-family detached
# 999                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      0.5556
# 2                                  8                      0.5556
# 3                                  8                      1.8000
# 4                                  8                      0.5556
# ..                               ...                         ...
# 995                                8                      0.5556
# 996                                8                      1.8000
# 997                                8                      0.5556
# 998                                8                      1.8000
# 999                                8                      1.8000
#
#      geometry_unit_cfa  year_built  geometry_unit_num_bedrooms  ...  \
# 0                 4750        1965                           6  ...
# 1                 1138        1955                           3  ...
# 2                 1682        2015                           3  ...
# 3                 5587        1995                           5  ...
# 4                 1682        1995                           3  ...
# ..                 ...         ...                         ...  ...
# 995                750        2015                           2  ...
# 996               2179        1940                           4  ...
# 997               1682        1940                           4  ...
# 998               3250        1995                           6  ...
# 999               1228        1995                           3  ...
#
#      overhangs_front_depth overhangs_front_distance_to_top_of_window  \
# 0                      NaN                                       NaN
# 1                     10.0                                       1.0
# 2                      NaN                                       NaN
# 3                      NaN                                       NaN
# 4                     10.0                                       1.0
# ..                     ...                                       ...
# 995                   10.0                                       1.0
# 996                    NaN                                       NaN
# 997                   10.0                                       1.0
# 998                    NaN                                       NaN
# 999                    NaN                                       NaN
#
#     cooling_system_cooling_compressor_type misc_plug_loads_vehicle_annual_kwh  \
# 0                                      NaN                                NaN
# 1                             single stage                                NaN
# 2                             single stage                                NaN
# 3                           variable speed                                NaN
# 4                             single stage                                NaN
# ..                                     ...                                ...
# 995                           single stage                                NaN
# 996                         variable speed                                NaN
# 997                           single stage                                NaN
# 998                                   None                                NaN
# 999                                   None                                NaN
#
#      misc_plug_loads_vehicle_usage_multiplier  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 995                                       NaN
# 996                                       NaN
# 997                                       NaN
# 998                                       NaN
# 999                                       NaN
#
#     heat_pump_heating_capacity_retention_fraction  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 995                                           NaN
# 996                                           NaN
# 997                                           NaN
# 998                                           NaN
# 999                                           NaN
#
#      heat_pump_heating_capacity_retention_temp  geothermal_loop_grout_type  \
# 0                                          NaN                         NaN
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
# ..                                         ...                         ...
# 995                                        NaN                         NaN
# 996                                        NaN                         NaN
# 997                                        NaN                         NaN
# 998                                        NaN                         NaN
# 999                                        NaN                         NaN
#
#      geothermal_loop_pipe_type  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 995                        NaN
# 996                        NaN
# 997                        NaN
# 998                        NaN
# 999                        NaN
#
#      simulation_control_ground_to_air_heat_pump_model_type
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
# [1000 rows x 143 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
