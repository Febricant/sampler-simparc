# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  67
#      Geometry Stories  Geometry Building Number Units  \
# 0                  12                             116
# 1                   1                               1
# 2                  35                             326
# 3                   1                               1
# 4                  20                              67
# ..                ...                             ...
# 195                 2                              67
# 196                 1                               1
# 197                 1                               1
# 198                 1                               1
# 199                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                                    Left                  Bottom
# 1                          Not Applicable                    None
# 2                                  Middle                  Middle
# 3                          Not Applicable                    None
# 4                                  Middle                  Middle
# ..                                    ...                     ...
# 195                                Middle                  Bottom
# 196                        Not Applicable                    None
# 197                        Not Applicable                    None
# 198                        Not Applicable                    None
# 199                        Not Applicable                    None
#
#     Infiltration                                Windows    Insulation Wall  \
# 0        5 ACH50  Double, Low-E, Non-metal, Air, M-Gain  QC_WoodStud-R18.9
# 1        6 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 2        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 3        5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 4        3 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# ..           ...                                    ...                ...
# 195      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 196      8 ACH50               Single, Clear, Non-metal  QC_WoodStud-R14.5
# 197      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 198      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 199      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R29.8    QC_Wall-R17.1, interior
# 1             QC_R27.3    QC_Wall-R14.4, interior
# 2             QC_R29.8    QC_Wall-R17.1, interior
# 3             QC_R30.9    QC_Wall-R17.1, interior
# 4             QC_R29.8    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195           QC_R29.8    QC_Wall-R17.1, interior
# 196           QC_R19.6    QC_Wall-R10.1, interior
# 197           QC_R30.9    QC_Wall-R17.1, interior
# 198           QC_R30.9    QC_Wall-R17.1, interior
# 199           QC_R27.3    QC_Wall-R14.4, interior
#
#     Geometry Wall Exterior Finish  ... Nombre_Pieces Nombre_Personnes  \
# 0                            None  ...             3                1
# 1                            None  ...             4                3
# 2                            None  ...             5                2
# 3                            None  ...             9                3
# 4                            None  ...             7                2
# ..                            ...  ...           ...              ...
# 195                          None  ...             4                1
# 196                          None  ...            11        5 et plus
# 197                          None  ...             8                1
# 198                          None  ...             8                3
# 199                          None  ...            10                3
#
#     Superficie_Totale                Presence_Garage Piscine_Presence  \
# 0       [1000 - 1500)                  Pas de Garage              Non
# 1       [1000 - 1500)                  Pas de Garage              Non
# 2        [500 - 1000)                  Pas de Garage              Non
# 3       [1500 - 2000)   Garage chauffé à électricité              Non
# 4       [1500 - 2000)                  Pas de Garage              Oui
# ..                ...                            ...              ...
# 195     [1000 - 1500)                  Pas de Garage              Non
# 196     [1500 - 2000)                  Pas de Garage              Non
# 197     [2500 - 3000)  Garage chauffé à autre source              Oui
# 198     [1500 - 2000)                  Pas de Garage              Non
# 199     [2500 - 3000)   Garage chauffé à électricité              Non
#
#           Piscine_Type Piscine_Minuterie Piscine_Chauffee Piscine_ChaufType  \
# 0                Aucun             Aucun            Aucun             Aucun
# 1                Aucun             Aucun            Aucun             Aucun
# 2                Aucun             Aucun            Aucun             Aucun
# 3                Aucun             Aucun            Aucun             Aucun
# 4    Creusee_Exterieur               Non              Non             Aucun
# ..                 ...               ...              ...               ...
# 195              Aucun             Aucun            Aucun             Aucun
# 196              Aucun             Aucun            Aucun             Aucun
# 197         Hors_Terre               Non              Non             Aucun
# 198              Aucun             Aucun            Aucun             Aucun
# 199              Aucun             Aucun            Aucun             Aucun
#
#     Piscine_Toile
# 0           Aucun
# 1           Aucun
# 2           Aucun
# 3           Aucun
# 4             Oui
# ..            ...
# 195         Aucun
# 196         Aucun
# 197           Non
# 198         Aucun
# 199         Aucun
#
# [200 rows x 33 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                            116          apartment unit
# 1                              1  single-family detached
# 2                            326          apartment unit
# 3                              1  single-family detached
# 4                             67          apartment unit
# ..                           ...                     ...
# 195                           67          apartment unit
# 196                            1  single-family detached
# 197                            1  single-family detached
# 198                            1  single-family detached
# 199                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      0.5556
# 1                                  8                      1.8000
# 2                                  8                      0.5556
# 3                                  8                      1.8000
# 4                                  8                      0.5556
# ..                               ...                         ...
# 195                                8                      0.5556
# 196                                8                      1.8000
# 197                                8                      1.8000
# 198                                8                      1.8000
# 199                                8                      1.8000
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 1138                         0.5        1995  ...
# 1                 1228                         0.5        1975  ...
# 2                  750                         0.5        2005  ...
# 3                 1698                         0.5        1985  ...
# 4                 1682                         0.5        1985  ...
# ..                 ...                         ...         ...  ...
# 195               1138                         0.5        1985  ...
# 196               1698                         0.5        1940  ...
# 197               2678                         0.5        2005  ...
# 198               1698                         0.5        1995  ...
# 199               2678                         0.5        1975  ...
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2              electricity                                  1.0
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199            electricity                                  1.0
#
#      heat_pump_is_ducted  heat_pump_cooling_compressor_type  \
# 0                   true                       single stage
# 1                    NaN                                NaN
# 2                    NaN                                NaN
# 3                   true                       single stage
# 4                   true                       single stage
# ..                   ...                                ...
# 195                  NaN                                NaN
# 196                  NaN                                NaN
# 197                 true                       single stage
# 198                  NaN                                NaN
# 199                  NaN                                NaN
#
#     geothermal_loop_configuration      cooling_system_type  \
# 0                            none                     none
# 1                            none                     none
# 2                            none  central air conditioner
# 3                            none                     none
# 4                            none                     none
# ..                            ...                      ...
# 195                          none  central air conditioner
# 196                          none                     none
# 197                          none                     none
# 198                          none  central air conditioner
# 199                          none                     none
#
#     cooling_system_cooling_compressor_type  overhangs_front_depth  \
# 0                                      NaN                    NaN
# 1                                     None                    NaN
# 2                             single stage                    NaN
# 3                                      NaN                    NaN
# 4                                      NaN                    NaN
# ..                                     ...                    ...
# 195                           single stage                    NaN
# 196                                   None                    NaN
# 197                                    NaN                    NaN
# 198                           single stage                    NaN
# 199                                   None                    NaN
#
#      overhangs_front_distance_to_top_of_window  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 195                                        NaN
# 196                                        NaN
# 197                                        NaN
# 198                                        NaN
# 199                                        NaN
#
#      heat_pump_compressor_lockout_temp
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 195                                NaN
# 196                                NaN
# 197                                NaN
# 198                                NaN
# 199                                NaN
#
# [200 rows x 71 columns]
