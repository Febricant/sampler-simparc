# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  83
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                  14                              67
# 2                  13                             183
# 3                  11                             116
# 4                   1                               1
# ..                ...                             ...
# 195                 4                              24
# 196                14                              67
# 197                 1                               1
# 198                 1                               1
# 199                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                                   Right                  Middle
# 2                                  Middle                  Middle
# 3                                  Middle                  Middle
# 4                          Not Applicable                    None
# ..                                    ...                     ...
# 195                                Middle                     Top
# 196                                  Left                  Middle
# 197                        Not Applicable                    None
# 198                        Not Applicable                    None
# 199                        Not Applicable                    None
#
#     Infiltration                                Windows    Insulation Wall  \
# 0        8 ACH50                   Single, Clear, Metal  QC_WoodStud-R17.2
# 1        3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 2        1 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 3        2 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 4        5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# ..           ...                                    ...                ...
# 195      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 196      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 197      5 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R17.2
# 198      5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 199      7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R27.3    QC_Wall-R14.4, interior
# 1               QC_R41      QC_Wall-R17, interior
# 2             QC_R29.8    QC_Wall-R17.1, interior
# 3               QC_R41      QC_Wall-R17, interior
# 4             QC_R30.9    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195           QC_R29.8    QC_Wall-R17.1, interior
# 196           QC_R29.8    QC_Wall-R17.1, interior
# 197           QC_R27.3    QC_Wall-R14.4, interior
# 198             QC_R41      QC_Wall-R17, interior
# 199           QC_R30.9    QC_Wall-R17.1, interior
#
#     Geometry Wall Exterior Finish  ... ChaufEau_ChaufType Piscine_Presence  \
# 0                            None  ...         Electrique              Non
# 1                            None  ...         Electrique              Non
# 2                            None  ...         Electrique              Non
# 3                            None  ...         Electrique              Non
# 4                            None  ...         Electrique              Oui
# ..                            ...  ...                ...              ...
# 195                          None  ...         Electrique              Non
# 196                          None  ...              Aucun              Non
# 197                          None  ...         Electrique              Non
# 198                          None  ...         Electrique              Non
# 199                          None  ...         Electrique              Non
#
#     Piscine_Type Piscine_Chauffee Piscine_ChaufType Piscine_Minuterie  \
# 0          Aucun            Aucun             Aucun             Aucun
# 1          Aucun            Aucun             Aucun             Aucun
# 2          Aucun            Aucun             Aucun             Aucun
# 3          Aucun            Aucun             Aucun             Aucun
# 4     Hors_Terre              Non             Aucun               Non
# ..           ...              ...               ...               ...
# 195        Aucun            Aucun             Aucun             Aucun
# 196        Aucun            Aucun             Aucun             Aucun
# 197        Aucun            Aucun             Aucun             Aucun
# 198        Aucun            Aucun             Aucun             Aucun
# 199        Aucun            Aucun             Aucun             Aucun
#
#     Piscine_Toile               Presence_Garage     Vehicule_Presence  \
# 0           Aucun  Garage chauffé à électricité  Aucune_VE_Aucune_VHR
# 1           Aucun                 Pas de Garage  Aucune_VE_Aucune_VHR
# 2           Aucun                 Pas de Garage  Aucune_VE_Aucune_VHR
# 3           Aucun                 Pas de Garage  Aucune_VE_Aucune_VHR
# 4             Non            Garage non chauffé  Aucune_VE_Aucune_VHR
# ..            ...                           ...                   ...
# 195         Aucun                 Pas de Garage  Aucune_VE_Aucune_VHR
# 196         Aucun                 Pas de Garage  Aucune_VE_Aucune_VHR
# 197         Aucun            Garage non chauffé  Aucune_VE_Aucune_VHR
# 198         Aucun                 Pas de Garage  Aucune_VE_Aucune_VHR
# 199         Aucun                 Pas de Garage  Aucune_VE_Aucune_VHR
#
#     Vehicule_BornePresence
# 0                    Aucun
# 1                    Aucun
# 2                    Aucun
# 3                    Aucun
# 4                    Aucun
# ..                     ...
# 195                  Aucun
# 196                  Aucun
# 197                  Aucun
# 198                  Aucun
# 199                  Aucun
#
# [200 rows x 45 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                             67          apartment unit
# 2                            183          apartment unit
# 3                            116          apartment unit
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                           24          apartment unit
# 196                           67          apartment unit
# 197                            1  single-family detached
# 198                            1  single-family detached
# 199                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      0.5556
# 2                                  8                      0.5556
# 3                                  8                      0.5556
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      0.5556
# 196                                8                      0.5556
# 197                                8                      1.8000
# 198                                8                      1.8000
# 199                                8                      1.8000
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 3250                         0.5        1975  ...
# 1                 1138                         0.5        2015  ...
# 2                 2648                         0.5        1985  ...
# 3                  750                         0.5        2015  ...
# 4                 2678                         0.5        2005  ...
# ..                 ...                         ...         ...  ...
# 195                750                         0.5        2005  ...
# 196               1682                         0.5        1985  ...
# 197               3250                         0.5        1975  ...
# 198               1228                         0.5        2015  ...
# 199               2179                         0.5        2005  ...
#
#         water_heater_type           water_heater_location  \
# 0    storage water heater               conditioned space
# 1    storage water heater               conditioned space
# 2    storage water heater               conditioned space
# 3    storage water heater               conditioned space
# 4    storage water heater               conditioned space
# ..                    ...                             ...
# 195  storage water heater  other multifamily buffer space
# 196                  None                            None
# 197  storage water heater               conditioned space
# 198  storage water heater               conditioned space
# 199  storage water heater               conditioned space
#
#      water_heater_tank_volume  heat_pump_is_ducted  \
# 0                        40.0                  NaN
# 1                        40.0                  NaN
# 2                        40.0                  NaN
# 3                         NaN                  NaN
# 4                        60.0                 true
# ..                        ...                  ...
# 195                       NaN                  NaN
# 196                       NaN                  NaN
# 197                       NaN                  NaN
# 198                      40.0                 true
# 199                      60.0                  NaN
#
#     heat_pump_compressor_lockout_temp  heat_pump_cooling_compressor_type  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                10.4                       single stage
# ..                                ...                                ...
# 195                               NaN                                NaN
# 196                               NaN                                NaN
# 197                               NaN                                NaN
# 198                               NaN                       single stage
# 199                               NaN                                NaN
#
#     overhangs_front_depth  overhangs_front_distance_to_top_of_window  \
# 0                     NaN                                        NaN
# 1                     NaN                                        NaN
# 2                     NaN                                        NaN
# 3                     NaN                                        NaN
# 4                     NaN                                        NaN
# ..                    ...                                        ...
# 195                   NaN                                        NaN
# 196                   NaN                                        NaN
# 197                   NaN                                        NaN
# 198                   NaN                                        NaN
# 199                   NaN                                        NaN
#
#      misc_plug_loads_vehicle_annual_kwh  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 195                                 NaN
# 196                                 NaN
# 197                                 NaN
# 198                                 NaN
# 199                                 NaN
#
#      misc_plug_loads_vehicle_usage_multiplier
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       NaN
# 198                                       NaN
# 199                                       NaN
#
# [200 rows x 90 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
