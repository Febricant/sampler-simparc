# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  65
#      Geometry Stories  Geometry Building Number Units  \
# 0                  12                             116
# 1                  20                              24
# 2                   1                               1
# 3                   2                               2
# 4                   1                               1
# ..                ...                             ...
# 195                 1                               1
# 196                 2                               2
# 197                 1                               1
# 198                 1                               1
# 199                 1                               1
#
#     Geometry Building Horizontal Location Infiltration  \
# 0                                    Left      1 ACH50
# 1                                   Right      1 ACH50
# 2                          Not Applicable     10 ACH50
# 3                          Not Applicable      7 ACH50
# 4                          Not Applicable      4 ACH50
# ..                                    ...          ...
# 195                        Not Applicable      6 ACH50
# 196                        Not Applicable      5 ACH50
# 197                        Not Applicable      1 ACH50
# 198                        Not Applicable      8 ACH50
# 199                        Not Applicable      5 ACH50
#
#                                    Windows    Insulation Wall  \
# 0    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 1    Double, Low-E, Non-metal, Air, M-Gain  QC_WoodStud-R18.9
# 2            Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 3            Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 4    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# ..                                     ...                ...
# 195          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 196  Double, Low-E, Non-metal, Air, M-Gain  QC_WoodStud-R18.9
# 197          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 198  Triple, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R14.5
# 199  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R29.8    QC_Wall-R17.1, interior
# 1             QC_R29.8    QC_Wall-R17.1, interior
# 2             QC_R30.9    QC_Wall-R17.1, interior
# 3             QC_R12.5    QC_Wall-R10.1, interior
# 4             QC_R30.9    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195           QC_R27.3    QC_Wall-R14.4, interior
# 196           QC_R29.8    QC_Wall-R17.1, interior
# 197             QC_R41      QC_Wall-R17, interior
# 198           QC_R19.6    QC_Wall-R10.1, interior
# 199           QC_R30.9    QC_Wall-R17.1, interior
#
#     Geometry Wall Exterior Finish geometry attic type  ... Mode_Occupation  \
# 0                            None        Vented Attic  ...    Proprietaire
# 1                            None        Vented Attic  ...       Locataire
# 2                            None        Vented Attic  ...    Proprietaire
# 3                            None        Vented Attic  ...       Locataire
# 4                            None        Vented Attic  ...    Proprietaire
# ..                            ...                 ...  ...             ...
# 195                          None        Vented Attic  ...    Proprietaire
# 196                          None        Vented Attic  ...    Proprietaire
# 197                          None        Vented Attic  ...    Proprietaire
# 198                          None        Vented Attic  ...    Proprietaire
# 199                          None        Vented Attic  ...    Proprietaire
#
#             Nombre_Etages Nombre_Pieces Nombre_Personnes Superficie_Totale  \
# 0                Un étage             2                1      [500 - 1000)
# 1                Un étage             5                1     [1000 - 1500)
# 2    Trois étages et plus             4                2     [2000 - 2500)
# 3                Un étage             5                1     [1000 - 1500)
# 4    Trois étages et plus            11                2     [3000 - 3500)
# ..                    ...           ...              ...               ...
# 195  Trois étages et plus             8                2     [1500 - 2000)
# 196  Trois étages et plus             8                4     [1500 - 2000)
# 197           Deux étages             9                1     [1500 - 2000)
# 198  Trois étages et plus             7                4     [1500 - 2000)
# 199           Deux étages             8                4     [1500 - 2000)
#
#                      Presence_SousSol An_Construction Source_Energie_Chauf  \
# 0    Aucun Sous-sol ou vide sanitaire   [1980 - 1990)          Electricite
# 1    Aucun Sous-sol ou vide sanitaire   [2000 - 2010)          Electricite
# 2                     Sous sol 6 pied   [2000 - 2010)          Electricite
# 3    Aucun Sous-sol ou vide sanitaire          < 1950          Electricite
# 4                     Sous sol 6 pied   [2000 - 2010)          Electricite
# ..                                ...             ...                  ...
# 195                   Sous sol 6 pied   [1970 - 1980)          Electricite
# 196  Aucun Sous-sol ou vide sanitaire   [1990 - 2000)          Electricite
# 197                   Sous sol 6 pied   [2010 - 2020)          Electricite
# 198                   Sous sol 6 pied          < 1950          Electricite
# 199                   Sous sol 6 pied   [1980 - 1990)          Electricite
#
#               Chauffage_Logement              Climatisation
# 0           Plinthes électriques                   Centrale
# 1           Plinthes électriques                     Murale
# 2           Plinthes électriques                     Murale
# 3           Plinthes électriques  Fenêtre, mobile, portable
# 4    Système central à air chaud                   Centrale
# ..                           ...                        ...
# 195         Plinthes électriques                     Aucune
# 196         Plinthes électriques  Fenêtre, mobile, portable
# 197                  Thermopompe                   Centrale
# 198         Plinthes électriques                     Aucune
# 199                  Thermopompe                     Murale
#
# [200 rows x 25 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 199  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#          geometry_unit_type  geometry_average_ceiling_height  \
# 0            apartment unit                                8
# 1            apartment unit                                8
# 2    single-family detached                                8
# 3            apartment unit                                8
# 4    single-family detached                                8
# ..                      ...                              ...
# 195  single-family detached                                8
# 196          apartment unit                                8
# 197  single-family detached                                8
# 198  single-family detached                                8
# 199  single-family detached                                8
#
#      geometry_unit_aspect_ratio  geometry_unit_cfa  \
# 0                        0.5556                750
# 1                        0.5556               1138
# 2                        1.8000               2179
# 3                        0.5556               1138
# 4                        1.8000               3250
# ..                          ...                ...
# 195                      1.8000               1698
# 196                      0.5556               1682
# 197                      1.8000               1698
# 198                      1.8000               1698
# 199                      1.8000               1698
#
#      geometry_garage_protrusion  year_built  geometry_unit_num_bedrooms  ...  \
# 0                           0.5        1985                           1  ...
# 1                           0.5        2005                           3  ...
# 2                           0.5        2005                           2  ...
# 3                           0.5        1940                           3  ...
# 4                           0.5        2005                           5  ...
# ..                          ...         ...                         ...  ...
# 195                         0.5        1975                           4  ...
# 196                         0.5        1995                           4  ...
# 197                         0.5        2015                           5  ...
# 198                         0.5        1940                           4  ...
# 199                         0.5        1985                           4  ...
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2              electricity                                  1.0
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199            electricity                                  1.0
#
#      geothermal_loop_configuration      cooling_system_type  \
# 0                             none  central air conditioner
# 1                             none               mini-split
# 2                             none               mini-split
# 3                             none  central air conditioner
# 4                             none  central air conditioner
# ..                             ...                      ...
# 195                           none                     none
# 196                           none  central air conditioner
# 197                           none                     none
# 198                           none                     none
# 199                           none                     none
#
#      cooling_system_cooling_compressor_type overhangs_front_depth  \
# 0                              single stage                   NaN
# 1                            variable speed                   NaN
# 2                            variable speed                   NaN
# 3                              single stage                  10.0
# 4                              single stage                   NaN
# ..                                      ...                   ...
# 195                                    None                   NaN
# 196                            single stage                  10.0
# 197                                     NaN                   NaN
# 198                                    None                   NaN
# 199                                     NaN                   NaN
#
#      overhangs_front_distance_to_top_of_window  heat_pump_is_ducted  \
# 0                                          NaN                  NaN
# 1                                          NaN                  NaN
# 2                                          NaN                  NaN
# 3                                          1.0                  NaN
# 4                                          NaN                  NaN
# ..                                         ...                  ...
# 195                                        NaN                  NaN
# 196                                        1.0                  NaN
# 197                                        NaN                 true
# 198                                        NaN                  NaN
# 199                                        NaN                 true
#
#      heat_pump_cooling_compressor_type  heat_pump_compressor_lockout_temp
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 195                                NaN                                NaN
# 196                                NaN                                NaN
# 197                       single stage                                NaN
# 198                                NaN                                NaN
# 199                       single stage                                NaN
#
# [200 rows x 70 columns]
