# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  130
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                  35                             326
# 2                   2                               2
# 3                   1                               1
# 4                   1                              16
# ..                ...                             ...
# 195                 1                               1
# 196                 1                               1
# 197                 8                             116
# 198                11                              67
# 199                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                                  Middle                  Middle
# 2                          Not Applicable                     Top
# 3                          Not Applicable                    None
# 4                                  Middle                  Bottom
# ..                                    ...                     ...
# 195                        Not Applicable                    None
# 196                        Not Applicable                    None
# 197                                  Left                  Middle
# 198                                 Right                     Top
# 199                        Not Applicable                    None
#
#     Infiltration                                Windows    Insulation Wall  \
# 0        8 ACH50                   Single, Clear, Metal  QC_WoodStud-R17.2
# 1        3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 2        2 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 3        7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 4        4 ACH50              Double, Clear, Metal, Air  QC_WoodStud-R18.9
# ..           ...                                    ...                ...
# 195     15 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 196      6 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 197     15 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.6
# 198      4 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 199      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R27.3    QC_Wall-R14.4, interior
# 1             QC_R29.8    QC_Wall-R17.1, interior
# 2               QC_R41      QC_Wall-R17, interior
# 3             QC_R30.9    QC_Wall-R17.1, interior
# 4             QC_R29.8    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195           QC_R30.9    QC_Wall-R17.1, interior
# 196           QC_R30.9    QC_Wall-R17.1, interior
# 197           QC_R18.3    QC_Wall-R14.4, interior
# 198           QC_R29.8    QC_Wall-R17.1, interior
# 199           QC_R30.9    QC_Wall-R17.1, interior
#
#     Geometry Wall Exterior Finish  ... Spa_Logement Spa_Saison  \
# 0                            None  ...        Aucun      Aucun
# 1                            None  ...        Aucun      Aucun
# 2                            None  ...        Aucun      Aucun
# 3                            None  ...        Aucun      Aucun
# 4                            None  ...        Aucun      Aucun
# ..                            ...  ...          ...        ...
# 195                          None  ...        Aucun      Aucun
# 196                          None  ...        Aucun      Aucun
# 197                          None  ...        Aucun      Aucun
# 198                          None  ...        Aucun      Aucun
# 199                          None  ...        Aucun      Aucun
#
#     Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide Type_Batiment  \
# 0                          Aucun                        Aucun        Maison
# 1                          Aucun                        Aucun    Collective
# 2                          Aucun                        Aucun          Plex
# 3                          Aucun                        Aucun        Maison
# 4                          Aucun                        Aucun    Collective
# ..                           ...                          ...           ...
# 195                        Aucun                        Aucun        Maison
# 196                        Aucun                        Aucun        Maison
# 197                        Aucun                        Aucun    Collective
# 198                        Aucun                        Aucun    Collective
# 199                        Aucun                        Aucun        Maison
#
#     Source_Energie_Chauf                                 Chauffage_Logement  \
# 0                   Bois  Fournaise ou poêle à bois et Plinthes électriques
# 1            Electricite                               Plinthes électriques
# 2            Electricite                               Plinthes électriques
# 3            Electricite                       Système central à eau chaude
# 4            Electricite                               Plinthes électriques
# ..                   ...                                                ...
# 195           Bi-energie         Thermopompe et Système central à air chaud
# 196          Electricite                        Système central à air chaud
# 197          Electricite         Thermopompe murale et Plinthes électriques
# 198          Electricite                               Plinthes électriques
# 199          Electricite                               Plinthes électriques
#
#                  Climatisation ChaufEau_ChaufType Cuisiniere_Energie
# 0                       Aucune         Electrique         Electrique
# 1                       Murale         Electrique         Electrique
# 2    Fenêtre, mobile, portable         Electrique         Electrique
# 3                       Murale         Electrique         Electrique
# 4                       Murale         Electrique         Electrique
# ..                         ...                ...                ...
# 195                     Murale         Electrique         Electrique
# 196  Fenêtre, mobile, portable         Electrique         Electrique
# 197                     Murale         Electrique              Aucun
# 198                     Aucune         Electrique         Electrique
# 199                     Aucune         Electrique         Electrique
#
# [200 rows x 67 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                            326          apartment unit
# 2                              2          apartment unit
# 3                              1  single-family detached
# 4                             16          apartment unit
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                            1  single-family detached
# 197                          116          apartment unit
# 198                           67          apartment unit
# 199                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      0.5556
# 2                                  8                      0.5556
# 3                                  8                      1.8000
# 4                                  8                      0.5556
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      1.8000
# 197                                8                      0.5556
# 198                                8                      0.5556
# 199                                8                      1.8000
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 3250                         0.5        1975  ...
# 1                 1682                         0.5        1995  ...
# 2                 1138                         0.5        2015  ...
# 3                  750                         0.5        2005  ...
# 4                  750                         0.5        1995  ...
# ..                 ...                         ...         ...  ...
# 195               2678                         0.5        1985  ...
# 196               2179                         0.5        2005  ...
# 197                750                         0.5        1975  ...
# 198                750                         0.5        2005  ...
# 199               2179                         0.5        1985  ...
#
#      overhangs_front_depth  overhangs_front_distance_to_top_of_window  \
# 0                      NaN                                        NaN
# 1                      NaN                                        NaN
# 2                     10.0                                        1.0
# 3                      NaN                                        NaN
# 4                      NaN                                        NaN
# ..                     ...                                        ...
# 195                    NaN                                        NaN
# 196                    NaN                                        NaN
# 197                    NaN                                        NaN
# 198                    NaN                                        NaN
# 199                    NaN                                        NaN
#
#      water_heater_tank_volume  heat_pump_is_ducted  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                        40.0                  NaN
# 3                        60.0                  NaN
# 4                        40.0                  NaN
# ..                        ...                  ...
# 195                      40.0                 true
# 196                      60.0                  NaN
# 197                      60.0                false
# 198                      40.0                  NaN
# 199                      50.0                  NaN
#
#     heat_pump_compressor_lockout_temp  heat_pump_cooling_compressor_type  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ..                                ...                                ...
# 195                              10.4                       single stage
# 196                               NaN                                NaN
# 197                               NaN                     variable speed
# 198                               NaN                                NaN
# 199                               NaN                                NaN
#
#     heat_pump_heating_capacity_retention_fraction  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 195                                           NaN
# 196                                           NaN
# 197                                           0.5
# 198                                           NaN
# 199                                           NaN
#
#      heat_pump_heating_capacity_retention_temp  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 195                                        NaN
# 196                                        NaN
# 197                                      -15.0
# 198                                        NaN
# 199                                        NaN
#
#      misc_plug_loads_vehicle_annual_kwh  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 195                                 NaN
# 196                                 NaN
# 197                                 NaN
# 198                                 NaN
# 199                                 NaN
#
#      misc_plug_loads_vehicle_usage_multiplier
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       NaN
# 198                                       NaN
# 199                                       NaN
#
# [200 rows x 140 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
