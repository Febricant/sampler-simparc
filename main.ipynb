# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBachArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 100
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBachArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire


MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)
display(pd.DataFrame(lst_dct_args))
dfHPXML = pd.DataFrame(lst_dct_HPXML)
dfHPXML.to_csv("building-test.csv", index=False)
dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  49
#    geometry_building_num_units Infiltration  \
# 0                            3      6 ACH50
# 1                           25      3 ACH50
# 2                            1      3 ACH50
# 3                            1      5 ACH50
# 4                            8      6 ACH50
# ..                         ...          ...
# 95                           1      6 ACH50
# 96                           5      4 ACH50
# 97                           3      2 ACH50
# 98                           1      7 ACH50
# 99                           1      2 ACH50
#
#                                   Windows    Insulation Wall  \
# 0               Double, Clear, Metal, Air  QC_WoodStud-R12.6
# 1   Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.2
# 2   Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R17.2
# 3           Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 4           Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# ..                                    ...                ...
# 95          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# 96  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 97          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 98  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# 99  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R24.5
#
#    Insulation Ceiling Insulation Foundation Wall  \
# 0            QC_R18.3      QC_Wall-R12, interior
# 1            QC_R12.5    QC_Wall-R10.1, interior
# 2            QC_R27.3    QC_Wall-R14.4, interior
# 3            QC_R30.9    QC_Wall-R17.1, interior
# 4            QC_R18.3      QC_Wall-R12, interior
# ..                ...                        ...
# 95           QC_R24.6      QC_Wall-R12, interior
# 96           QC_R29.8    QC_Wall-R17.1, interior
# 97           QC_R29.8    QC_Wall-R17.1, interior
# 98           QC_R30.9    QC_Wall-R17.1, interior
# 99             QC_R41      QC_Wall-R17, interior
#
#    Geometry Wall Exterior Finish geometry attic type HVAC Has Shared System  \
# 0                           None        Vented Attic                   None
# 1                           None        Vented Attic                   None
# 2                           None        Vented Attic                   None
# 3                           None        Vented Attic                   None
# 4                           None        Vented Attic                   None
# ..                           ...                 ...                    ...
# 95                          None        Vented Attic                   None
# 96                          None        Vented Attic                   None
# 97                          None        Vented Attic                   None
# 98                          None        Vented Attic                   None
# 99                          None        Vented Attic                   None
#
#                 HVAC Heating Efficiency  ... Mode_Occupation An_Construction  \
# 0   Electric Baseboard, 100% Efficiency  ...       Locataire   [1950 - 1960)
# 1   Electric Baseboard, 100% Efficiency  ...    Proprietaire          < 1950
# 2   Electric Baseboard, 100% Efficiency  ...    Proprietaire   [1970 - 1980)
# 3   Electric Baseboard, 100% Efficiency  ...    Proprietaire   [1980 - 1990)
# 4   Electric Baseboard, 100% Efficiency  ...       Locataire   [1950 - 1960)
# ..                                  ...  ...             ...             ...
# 95  Electric Baseboard, 100% Efficiency  ...    Proprietaire   [1950 - 1960)
# 96  Electric Baseboard, 100% Efficiency  ...       Locataire   [1980 - 1990)
# 97  Electric Baseboard, 100% Efficiency  ...       Locataire   [1980 - 1990)
# 98  Electric Baseboard, 100% Efficiency  ...    Proprietaire   [1980 - 1990)
# 99  Electric Baseboard, 100% Efficiency  ...    Proprietaire   [2010 - 2020)
#
#    Source_Energie_Chauf    Chauffage_Logement         Nombre_Etages  \
# 0           Electricite  Plinthes électriques              Un étage
# 1           Electricite  Plinthes électriques              Un étage
# 2           Electricite  Plinthes électriques           Deux étages
# 3           Electricite  Plinthes électriques           Deux étages
# 4           Electricite  Plinthes électriques              Un étage
# ..                  ...                   ...                   ...
# 95          Electricite  Plinthes électriques  Trois étages et plus
# 96          Electricite  Plinthes électriques              Un étage
# 97          Electricite  Plinthes électriques              Un étage
# 98          Electricite  Plinthes électriques           Deux étages
# 99          Electricite  Plinthes électriques              Un étage
#
#    Nombre_Pieces Nombre_Personnes Superficie_Totale  \
# 0              4                2      [500 - 1000)
# 1              3                3      [500 - 1000)
# 2              5                2     [3000 - 3500)
# 3             10                3     [1500 - 2000)
# 4              3        5 et plus     [1000 - 1500)
# ..           ...              ...               ...
# 95             9        5 et plus     [2000 - 2500)
# 96             4                1      [500 - 1000)
# 97             3                1     [3000 - 3500)
# 98             6                1     [2000 - 2500)
# 99             4                1      [500 - 1000)
#
#                     Presence_SousSol               Presence_Garage
# 0   Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# 1   Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# 2                    Sous sol 6 pied                 Pas de Garage
# 3                    Sous sol 6 pied                 Pas de Garage
# 4   Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# ..                               ...                           ...
# 95                   Sous sol 6 pied  Garage chauffé à électricité
# 96  Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# 97  Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# 98                   Sous sol 6 pied  Garage chauffé à électricité
# 99  Aucun Sous-sol ou vide sanitaire            Garage non chauffé
#
# [100 rows x 23 columns]
#    geometry_building_num_units  \
# 0                            3
# 1                           25
# 2                            1
# 3                            1
# 4                            8
# ..                         ...
# 95                           1
# 96                           5
# 97                           3
# 98                           1
# 99                           1
#
#                          weather_station_epw_filepath  \
# 0   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2   2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 3   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                ...
# 95  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 96  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 97  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 98  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 99  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#     simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                         True                         -5
# 1                                         True                         -5
# 2                                         True                         -5
# 3                                         True                         -5
# 4                                         True                         -5
# ..                                         ...                        ...
# 95                                        True                         -5
# 96                                        True                         -5
# 97                                        True                         -5
# 98                                        True                         -5
# 99                                        True                         -5
#
#         geometry_unit_type  geometry_average_ceiling_height  \
# 0           apartment unit                                8
# 1           apartment unit                                8
# 2   single-family detached                                8
# 3   single-family detached                                8
# 4           apartment unit                                8
# ..                     ...                              ...
# 95  single-family detached                                8
# 96          apartment unit                                8
# 97          apartment unit                                8
# 98  single-family detached                                8
# 99  single-family detached                                8
#
#     geometry_unit_aspect_ratio  geometry_unit_cfa  geometry_garage_protrusion  \
# 0                       0.5556                750                         0.5
# 1                       0.5556                750                         0.5
# 2                       1.8000               3250                         0.5
# 3                       1.8000               1698                         0.5
# 4                       0.5556               1138                         0.5
# ..                         ...                ...                         ...
# 95                      1.8000               2179                         0.5
# 96                      0.5556                750                         0.5
# 97                      0.5556               3250                         0.5
# 98                      1.8000               2179                         0.5
# 99                      1.8000                750                         0.5
#
#     year_built  ...  air_leakage_value    air_leakage_type  \
# 0         1955  ...                  5  unit exterior only
# 1         1940  ...                  5  unit exterior only
# 2         1975  ...                  5  unit exterior only
# 3         1985  ...                  5  unit exterior only
# 4         1955  ...                  5  unit exterior only
# ..         ...  ...                ...                 ...
# 95        1955  ...                  5  unit exterior only
# 96        1985  ...                  5  unit exterior only
# 97        1985  ...                  5  unit exterior only
# 98        1985  ...                  5  unit exterior only
# 99        2015  ...                  5  unit exterior only
#
#     site_shielding_of_home  rim_joist_assembly_r  \
# 0                   normal                   0.0
# 1                   normal                   0.0
# 2                   normal                   2.5
# 3                   normal                   2.5
# 4                   normal                   0.0
# ..                     ...                   ...
# 95                  normal                   2.5
# 96                  normal                   0.0
# 97                  normal                   0.0
# 98                  normal                   2.5
# 99                  normal                   0.0
#
#    geometry_unit_left_wall_is_adiabatic  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 95                                False
# 96                                False
# 97                                False
# 98                                False
# 99                                False
#
#     geometry_unit_right_wall_is_adiabatic  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ..                                    ...
# 95                                  False
# 96                                  False
# 97                                  False
# 98                                  False
# 99                                  False
#
#    geometry_unit_front_wall_is_adiabatic  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ..                                   ...
# 95                                 False
# 96                                 False
# 97                                 False
# 98                                 False
# 99                                 False
#
#     geometry_unit_back_wall_is_adiabatic      cooling_system_type  \
# 0                                  False                     none
# 1                                  False  central air conditioner
# 2                                  False  central air conditioner
# 3                                  False                     none
# 4                                  False  central air conditioner
# ..                                   ...                      ...
# 95                                 False               mini-split
# 96                                 False               mini-split
# 97                                 False                     none
# 98                                 False  central air conditioner
# 99                                 False                     none
#
#     cooling_system_cooling_compressor_type
# 0                                     None
# 1                             single stage
# 2                             single stage
# 3                                     None
# 4                             single stage
# ..                                     ...
# 95                          variable speed
# 96                          variable speed
# 97                                    None
# 98                            single stage
# 99                                    None
#
# [100 rows x 49 columns]
