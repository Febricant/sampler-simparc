# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  120
#      Geometry Stories  Geometry Building Number Units  \
# 0                   2                               2
# 1                  12                             116
# 2                   2                              18
# 3                   8                             326
# 4                   1                               1
# ..                ...                             ...
# 195                 1                               1
# 196                21                              67
# 197                 1                               1
# 198                 2                               2
# 199                 9                             326
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                  Bottom
# 1                                   Right                     Top
# 2                                   Right                  Bottom
# 3                                  Middle                  Middle
# 4                          Not Applicable                    None
# ..                                    ...                     ...
# 195                        Not Applicable                    None
# 196                                 Right                  Middle
# 197                        Not Applicable                    None
# 198                        Not Applicable                     Top
# 199                                Middle                  Middle
#
#     Infiltration                                Windows    Insulation Wall  \
# 0       10 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.2
# 1        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 2        5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 3        4 ACH50  Triple, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 4        6 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# ..           ...                                    ...                ...
# 195      6 ACH50  Double, Low-E, Non-metal, Air, L-Gain    QC_WoodStud-R14
# 196      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 197      6 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 198      1 ACH50  Double, Low-E, Non-metal, Air, M-Gain  QC_WoodStud-R18.9
# 199      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R12.5    QC_Wall-R10.1, interior
# 1               QC_R41      QC_Wall-R17, interior
# 2               QC_R41      QC_Wall-R17, interior
# 3             QC_R29.8    QC_Wall-R17.1, interior
# 4             QC_R27.3    QC_Wall-R14.4, interior
# ..                 ...                        ...
# 195           QC_R24.6      QC_Wall-R12, interior
# 196           QC_R29.8    QC_Wall-R17.1, interior
# 197           QC_R30.9    QC_Wall-R17.1, interior
# 198           QC_R29.8    QC_Wall-R17.1, interior
# 199             QC_R41      QC_Wall-R17, interior
#
#     Geometry Wall Exterior Finish  ...                  Presence_SousSol  \
# 0                            None  ...  Aucun Sous-sol ou vide sanitaire
# 1                            None  ...  Aucun Sous-sol ou vide sanitaire
# 2                            None  ...  Aucun Sous-sol ou vide sanitaire
# 3                            None  ...  Aucun Sous-sol ou vide sanitaire
# 4                            None  ...                   Sous sol 6 pied
# ..                            ...  ...                               ...
# 195                          None  ...                   Sous sol 6 pied
# 196                          None  ...  Aucun Sous-sol ou vide sanitaire
# 197                          None  ...                   Sous sol 6 pied
# 198                          None  ...  Aucun Sous-sol ou vide sanitaire
# 199                          None  ...  Aucun Sous-sol ou vide sanitaire
#
#     ChaufEau_Presence       ChaufEau_Type An_Construction An_ConstructionCode  \
# 0            Logement          40 gallons          < 1950              < 1946
# 1            Logement          40 gallons   [2010 - 2020)             >= 2011
# 2            Logement          60 gallons   [2010 - 2020)             >= 2011
# 3            Logement  60 et plus gallons   [1990 - 2000)       [1984 - 2011)
# 4            Logement          60 gallons   [1970 - 1980)       [1946 - 1984)
# ..                ...                 ...             ...                 ...
# 195          Logement          40 gallons   [1960 - 1970)       [1946 - 1984)
# 196           Central         Non definit   [1990 - 2000)       [1984 - 2011)
# 197          Logement         Ne sait pas   [1980 - 1990)       [1984 - 2011)
# 198          Logement          40 gallons   [1990 - 2000)       [1984 - 2011)
# 199          Logement         Ne sait pas   [2010 - 2020)             >= 2011
#
#     Source_Energie_Chauf            Chauffage_Logement  \
# 0            Electricite          Plinthes électriques
# 1            Electricite          Plinthes électriques
# 2            Electricite          Plinthes électriques
# 3            Gaz naturel  Système central à eau chaude
# 4                   Bois     Fournaise ou poêle à bois
# ..                   ...                           ...
# 195          Electricite                   Thermopompe
# 196          Electricite          Plinthes électriques
# 197          Electricite          Plinthes électriques
# 198          Electricite                   Thermopompe
# 199          Electricite          Plinthes électriques
#
#                  Climatisation ChaufEau_ChaufType Cuisiniere_Energie
# 0                       Aucune         Electrique         Electrique
# 1    Fenêtre, mobile, portable         Electrique         Electrique
# 2                       Aucune         Electrique         Electrique
# 3    Fenêtre, mobile, portable         Electrique         Electrique
# 4                       Aucune         Electrique         Electrique
# ..                         ...                ...                ...
# 195                     Murale         Electrique         Electrique
# 196                     Murale         Electrique         Electrique
# 197                     Murale         Electrique         Electrique
# 198                   Centrale         Electrique         Electrique
# 199  Fenêtre, mobile, portable         Electrique         Electrique
#
# [200 rows x 63 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              2          apartment unit
# 1                            116          apartment unit
# 2                             18          apartment unit
# 3                            326          apartment unit
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                           67          apartment unit
# 197                            1  single-family detached
# 198                            2          apartment unit
# 199                          326          apartment unit
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      0.5556
# 1                                  8                      0.5556
# 2                                  8                      0.5556
# 3                                  8                      0.5556
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      0.5556
# 197                                8                      1.8000
# 198                                8                      0.5556
# 199                                8                      0.5556
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 2115                         0.5        1940  ...
# 1                  750                         0.5        2015  ...
# 2                  750                         0.5        2015  ...
# 3                  750                         0.5        1995  ...
# 4                 1228                         0.5        1975  ...
# ..                 ...                         ...         ...  ...
# 195               2179                         0.5        1965  ...
# 196               1138                         0.5        1995  ...
# 197               2179                         0.5        1985  ...
# 198               2115                         0.5        1995  ...
# 199                750                         0.5        2015  ...
#
#      extra_refrigerator_rated_annual_kwh  extra_refrigerator_usage_multiplier  \
# 0                                      0                                  0.0
# 1                                      0                                  0.0
# 2                                      0                                  0.0
# 3                                      0                                  0.0
# 4                                      0                                  0.0
# ..                                   ...                                  ...
# 195                                  480                                  1.0
# 196                                    0                                  0.0
# 197                                    0                                  0.0
# 198                                    0                                  0.0
# 199                                    0                                  0.0
#
#      freezer_present  freezer_rated_annual_kwh freezer_usage_multiplier  \
# 0               True                       935                    0.342
# 1              False                         0                    0.000
# 2              False                         0                    0.000
# 3              False                         0                    0.000
# 4              False                         0                    0.000
# ..               ...                       ...                      ...
# 195            False                         0                    0.000
# 196             True                       935                    0.342
# 197            False                         0                    0.000
# 198            False                         0                    0.000
# 199            False                         0                    0.000
#
#      heat_pump_is_ducted heat_pump_compressor_lockout_temp  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
# ..                   ...                               ...
# 195                 true                               NaN
# 196                  NaN                               NaN
# 197                  NaN                               NaN
# 198                 true                               NaN
# 199                  NaN                               NaN
#
#      heat_pump_cooling_compressor_type  misc_plug_loads_vehicle_annual_kwh  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# ..                                 ...                                 ...
# 195                       single stage                                 NaN
# 196                                NaN                                 NaN
# 197                                NaN                                 NaN
# 198                       single stage                              3274.0
# 199                                NaN                                 NaN
#
#      misc_plug_loads_vehicle_usage_multiplier
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       NaN
# 198                                       1.0
# 199                                       NaN
#
# [200 rows x 125 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
