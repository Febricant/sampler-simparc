# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 1000
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  131
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                  35                             326
# 2                   1                               1
# 3                   1                               1
# 4                   3                               3
# ..                ...                             ...
# 995                 2                               6
# 996                 1                               1
# 997                 1                               1
# 998                 1                               1
# 999                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                                  Middle                  Middle
# 2                          Not Applicable                    None
# 3                          Not Applicable                    None
# 4                          Not Applicable                     Top
# ..                                    ...                     ...
# 995                                  Left                     Top
# 996                        Not Applicable                    None
# 997                        Not Applicable                    None
# 998                        Not Applicable                    None
# 999                        Not Applicable                    None
#
#                                    Windows    Insulation Wall  \
# 0    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R14.5
# 1            Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 2            Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 3            Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 4                Double, Clear, Metal, Air  QC_WoodStud-R12.2
# ..                                     ...                ...
# 995          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 996          Double, Clear, Non-metal, Air  QC_WoodStud-R14.5
# 997          Double, Clear, Non-metal, Air  QC_WoodStud-R14.5
# 998              Double, Clear, Metal, Air  QC_WoodStud-R20.7
# 999              Double, Clear, Metal, Air  QC_WoodStud-R24.5
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R19.6    QC_Wall-R10.1, interior
# 1             QC_R12.5    QC_Wall-R10.1, interior
# 2             QC_R30.9    QC_Wall-R17.1, interior
# 3             QC_R30.9    QC_Wall-R17.1, interior
# 4             QC_R12.5    QC_Wall-R10.1, interior
# ..                 ...                        ...
# 995           QC_R18.3    QC_Wall-R14.4, interior
# 996           QC_R19.6    QC_Wall-R10.1, interior
# 997           QC_R19.6    QC_Wall-R10.1, interior
# 998           QC_R30.9    QC_Wall-R17.1, interior
# 999             QC_R41      QC_Wall-R17, interior
#
#     Geometry Wall Exterior Finish geometry attic type  ... Eclairage_LED  \
# 0                            None        Vented Attic  ...     25 à 50 %
# 1                            None        Vented Attic  ...            0%
# 2                            None        Vented Attic  ...      1 à 24 %
# 3                            None        Vented Attic  ...  Plus de 50 %
# 4                            None        Vented Attic  ...  Plus de 50 %
# ..                            ...                 ...  ...           ...
# 995                          None        Vented Attic  ...     25 à 50 %
# 996                          None        Vented Attic  ...  Plus de 50 %
# 997                          None        Vented Attic  ...  Plus de 50 %
# 998                          None        Vented Attic  ...   Ne sait pas
# 999                          None        Vented Attic  ...      1 à 24 %
#
#     Type_Batiment An_Construction     Infiltration An_ConstructionCode  \
# 0          Maison          < 1950  Option=10 ACH50              < 1946
# 1      Collective          < 1950  Option=15 ACH50              < 1946
# 2          Maison   [1980 - 1990)   Option=5 ACH50       [1971 - 1986)
# 3          Maison   [2000 - 2010)   Option=7 ACH50       [1986 - 2013)
# 4            Plex          < 1950   Option=4 ACH50              < 1946
# ..            ...             ...              ...                 ...
# 995    Collective   [1970 - 1980)   Option=4 ACH50       [1946 - 1971)
# 996        Maison          < 1950  Option=10 ACH50              < 1946
# 997        Maison          < 1950   Option=8 ACH50              < 1946
# 998        Maison   [2000 - 2010)   Option=7 ACH50       [1986 - 2013)
# 999        Maison   [2010 - 2020)   Option=2 ACH50             >= 2013
#
#     Source_Energie_Chauf Cuisiniere_Energie  \
# 0            Electricite         Electrique
# 1            Electricite         Electrique
# 2            Electricite         Electrique
# 3            Electricite         Electrique
# 4            Electricite         Electrique
# ..                   ...                ...
# 995          Electricite         Electrique
# 996                 Bois         Electrique
# 997               Mazout              Aucun
# 998          Electricite         Electrique
# 999          Electricite         Electrique
#
#                              Chauffage_Logement              Climatisation  \
# 0                   Système central à air chaud                   Centrale
# 1                          Plinthes électriques                     Aucune
# 2                          Plinthes électriques  Fenêtre, mobile, portable
# 3                  Système central à eau chaude                     Aucune
# 4    Thermopompe murale et Plinthes électriques                     Murale
# ..                                          ...                        ...
# 995                        Plinthes électriques                     Murale
# 996                   Fournaise ou poêle à bois  Fenêtre, mobile, portable
# 997                Système central à eau chaude                   Centrale
# 998                        Plinthes électriques                     Murale
# 999                        Plinthes électriques                     Murale
#
#     ChaufEau_ChaufType
# 0           Electrique
# 1           Electrique
# 2           Electrique
# 3           Electrique
# 4           Electrique
# ..                 ...
# 995         Electrique
# 996         Electrique
# 997         Electrique
# 998        Gaz Naturel
# 999         Electrique
#
# [1000 rows x 67 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Saguenay-Bagotville.AP-CFB.Bagotv...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 995  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 996  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 997  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 998  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 999  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 995                                        True                         -5
# 996                                        True                         -5
# 997                                        True                         -5
# 998                                        True                         -5
# 999                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                            326          apartment unit
# 2                              1  single-family detached
# 3                              1  single-family detached
# 4                              3          apartment unit
# ..                           ...                     ...
# 995                            6          apartment unit
# 996                            1  single-family detached
# 997                            1  single-family detached
# 998                            1  single-family detached
# 999                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      0.5556
# 2                                  8                      1.8000
# 3                                  8                      1.8000
# 4                                  8                      0.5556
# ..                               ...                         ...
# 995                                8                      0.5556
# 996                                8                      1.8000
# 997                                8                      1.8000
# 998                                8                      1.8000
# 999                                8                      1.8000
#
#      geometry_unit_cfa  year_built  geometry_unit_num_bedrooms  ...  \
# 0                  750        1940                           4  ...
# 1                 1138        1940                           2  ...
# 2                 1698        1985                           4  ...
# 3                 2179        2005                           5  ...
# 4                  750        1940                           2  ...
# ..                 ...         ...                         ...  ...
# 995                750        1975                           2  ...
# 996               2179        1940                           4  ...
# 997               1228        1940                           5  ...
# 998               2179        2005                           4  ...
# 999               3750        2015                           4  ...
#
#      heat_pump_heating_capacity_retention_fraction  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              0.5
# ..                                             ...
# 995                                            NaN
# 996                                            NaN
# 997                                            NaN
# 998                                            NaN
# 999                                            NaN
#
#     heat_pump_heating_capacity_retention_temp heat_pump_is_ducted  \
# 0                                         NaN                 NaN
# 1                                         NaN                 NaN
# 2                                         NaN                 NaN
# 3                                         NaN                 NaN
# 4                                       -15.0               false
# ..                                        ...                 ...
# 995                                       NaN                 NaN
# 996                                       NaN                 NaN
# 997                                       NaN                 NaN
# 998                                       NaN                 NaN
# 999                                       NaN                 NaN
#
#     heat_pump_cooling_compressor_type  heat_pump_compressor_lockout_temp  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                      variable speed                                NaN
# ..                                ...                                ...
# 995                               NaN                                NaN
# 996                               NaN                                NaN
# 997                               NaN                                NaN
# 998                               NaN                                NaN
# 999                               NaN                                NaN
#
#     misc_plug_loads_vehicle_annual_kwh  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 995                                NaN
# 996                                NaN
# 997                                NaN
# 998                                NaN
# 999                                NaN
#
#      misc_plug_loads_vehicle_usage_multiplier  geothermal_loop_grout_type  \
# 0                                         NaN                         NaN
# 1                                         NaN                         NaN
# 2                                         NaN                         NaN
# 3                                         NaN                         NaN
# 4                                         NaN                         NaN
# ..                                        ...                         ...
# 995                                       NaN                         NaN
# 996                                       NaN                         NaN
# 997                                       NaN                         NaN
# 998                                       NaN                         NaN
# 999                                       NaN                         NaN
#
#      geothermal_loop_pipe_type  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 995                        NaN
# 996                        NaN
# 997                        NaN
# 998                        NaN
# 999                        NaN
#
#      simulation_control_ground_to_air_heat_pump_model_type
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
# [1000 rows x 143 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
