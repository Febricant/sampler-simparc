# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  82
#      Geometry Stories  Geometry Building Number Units  \
# 0                  12                             116
# 1                   3                               3
# 2                   1                               1
# 3                  11                             116
# 4                   1                               1
# ..                ...                             ...
# 195                 1                               1
# 196                 1                               1
# 197                 1                               1
# 198                 1                               1
# 199                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                                    Left                  Bottom
# 1                          Not Applicable                  Middle
# 2                          Not Applicable                    None
# 3                                  Middle                  Middle
# 4                          Not Applicable                    None
# ..                                    ...                     ...
# 195                        Not Applicable                    None
# 196                        Not Applicable                    None
# 197                        Not Applicable                    None
# 198                        Not Applicable                    None
# 199                        Not Applicable                    None
#
#     Infiltration                                Windows    Insulation Wall  \
# 0       10 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.6
# 1        7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 2        3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 3        2 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 4        7 ACH50          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# ..           ...                                    ...                ...
# 195      5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 196      8 ACH50          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# 197      7 ACH50  Double, Low-E, Non-metal, Air, L-Gain    QC_WoodStud-R14
# 198      5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 199     10 ACH50          Double, Clear, Non-metal, Air    QC_WoodStud-R14
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R18.3      QC_Wall-R12, interior
# 1             QC_R12.5    QC_Wall-R10.1, interior
# 2             QC_R30.9    QC_Wall-R17.1, interior
# 3             QC_R29.8    QC_Wall-R17.1, interior
# 4             QC_R24.6      QC_Wall-R12, interior
# ..                 ...                        ...
# 195           QC_R27.3    QC_Wall-R14.4, interior
# 196           QC_R24.6      QC_Wall-R12, interior
# 197           QC_R24.6      QC_Wall-R12, interior
# 198             QC_R41      QC_Wall-R17, interior
# 199           QC_R24.6      QC_Wall-R12, interior
#
#     Geometry Wall Exterior Finish  ... Spa_Presence Spa_Logement  \
# 0                            None  ...          Non        Aucun
# 1                            None  ...          Non        Aucun
# 2                            None  ...          Non        Aucun
# 3                            None  ...          Non        Aucun
# 4                            None  ...          Non        Aucun
# ..                            ...  ...          ...          ...
# 195                          None  ...          Oui    Exterieur
# 196                          None  ...          Non        Aucun
# 197                          None  ...          Non        Aucun
# 198                          None  ...          Oui    Exterieur
# 199                          None  ...          Non        Aucun
#
#        Spa_Saison Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide  \
# 0           Aucun                        Aucun                        Aucun
# 1           Aucun                        Aucun                        Aucun
# 2           Aucun                        Aucun                        Aucun
# 3           Aucun                        Aucun                        Aucun
# 4           Aucun                        Aucun                        Aucun
# ..            ...                          ...                          ...
# 195   Pas utilisé                        Aucun                        Aucun
# 196         Aucun                        Aucun                        Aucun
# 197         Aucun                        Aucun                        Aucun
# 198  Toute_Saison                     Constant                     Constant
# 199         Aucun                        Aucun                        Aucun
#
#     An_Construction Source_Energie_Chauf ChaufEau_ChaufType  \
# 0     [1950 - 1960)          Electricite         Electrique
# 1            < 1950          Electricite         Electrique
# 2     [2000 - 2010)          Electricite         Electrique
# 3     [1990 - 2000)          Electricite         Electrique
# 4     [1950 - 1960)          Electricite         Electrique
# ..              ...                  ...                ...
# 195   [1970 - 1980)                 Bois         Electrique
# 196   [1960 - 1970)           Bi-energie         Electrique
# 197   [1960 - 1970)          Electricite         Electrique
# 198   [2010 - 2020)          Electricite         Electrique
# 199   [1960 - 1970)           Bi-energie         Electrique
#
#                                   Chauffage_Logement  \
# 0                               Plinthes électriques
# 1                               Plinthes électriques
# 2                                        Thermopompe
# 3    Unités convecteurs, plancher ou plafond radiant
# 4                               Plinthes électriques
# ..                                               ...
# 195                        Fournaise ou poêle à bois
# 196                                      Thermopompe
# 197                     Système central à eau chaude
# 198                      Système central à air chaud
# 199                                      Thermopompe
#
#                  Climatisation
# 0    Fenêtre, mobile, portable
# 1    Fenêtre, mobile, portable
# 2                     Centrale
# 3                       Aucune
# 4                       Murale
# ..                         ...
# 195                     Aucune
# 196                   Centrale
# 197                     Aucune
# 198                     Aucune
# 199                   Centrale
#
# [200 rows x 43 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Saguenay-Bagotville.AP-CFB.Bagotv...
# ..                                                 ...
# 195  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 199  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                            116          apartment unit
# 1                              3          apartment unit
# 2                              1  single-family detached
# 3                            116          apartment unit
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                            1  single-family detached
# 197                            1  single-family detached
# 198                            1  single-family detached
# 199                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      0.5556
# 1                                  8                      0.5556
# 2                                  8                      1.8000
# 3                                  8                      0.5556
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      1.8000
# 197                                8                      1.8000
# 198                                8                      1.8000
# 199                                8                      1.8000
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                  750                         0.5        1955  ...
# 1                 1138                         0.5        1940  ...
# 2                  750                         0.5        2005  ...
# 3                 1138                         0.5        1995  ...
# 4                 2179                         0.5        1955  ...
# ..                 ...                         ...         ...  ...
# 195               1698                         0.5        1975  ...
# 196               3750                         0.5        1965  ...
# 197               1698                         0.5        1965  ...
# 198               1228                         0.5        2015  ...
# 199               2678                         0.5        1965  ...
#
#         water_heater_type  water_heater_location  overhangs_front_depth  \
# 0    storage water heater      conditioned space                    NaN
# 1    storage water heater      conditioned space                   10.0
# 2    storage water heater      conditioned space                    NaN
# 3    storage water heater      conditioned space                    NaN
# 4    storage water heater      conditioned space                    NaN
# ..                    ...                    ...                    ...
# 195  storage water heater      conditioned space                    NaN
# 196  storage water heater      conditioned space                    NaN
# 197  storage water heater      conditioned space                    NaN
# 198  storage water heater      conditioned space                    NaN
# 199  storage water heater      conditioned space                    NaN
#
#      overhangs_front_distance_to_top_of_window water_heater_tank_volume  \
# 0                                          NaN                      NaN
# 1                                          1.0                     40.0
# 2                                          NaN                     70.0
# 3                                          NaN                     60.0
# 4                                          NaN                     40.0
# ..                                         ...                      ...
# 195                                        NaN                      NaN
# 196                                        NaN                     60.0
# 197                                        NaN                     60.0
# 198                                        NaN                     40.0
# 199                                        NaN                      NaN
#
#      heat_pump_is_ducted heat_pump_cooling_compressor_type  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                   true                      single stage
# 3                    NaN                               NaN
# 4                    NaN                               NaN
# ..                   ...                               ...
# 195                  NaN                               NaN
# 196                 true                      single stage
# 197                  NaN                               NaN
# 198                  NaN                               NaN
# 199                 true                      single stage
#
#      misc_plug_loads_vehicle_annual_kwh  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 195                                 NaN
# 196                                 NaN
# 197                                 NaN
# 198                                 NaN
# 199                                 NaN
#
#      misc_plug_loads_vehicle_usage_multiplier  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       NaN
# 198                                       NaN
# 199                                       NaN
#
#      heat_pump_compressor_lockout_temp
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 195                                NaN
# 196                               10.4
# 197                                NaN
# 198                                NaN
# 199                               10.4
#
# [200 rows x 90 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
