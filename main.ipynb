# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBachArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 10
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBachArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire


MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)
display(pd.DataFrame(lst_dct_args))
dfHPXML = pd.DataFrame(lst_dct_HPXML)
dfHPXML.to_csv("building-test.csv", index=False)
#dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  43
#   geometry_building_num_units Infiltration  \
# 0                           1      4 ACH50
# 1                           1      5 ACH50
# 2                           1      6 ACH50
# 3                           2      5 ACH50
# 4                           1      8 ACH50
# 5                           3      5 ACH50
# 6                           2      4 ACH50
# 7                           1      7 ACH50
# 8                           1     15 ACH50
# 9                           8      3 ACH50
#
#                                  Windows    Insulation_Wall  \
# 0              Double, Clear, Metal, Air  QC_WoodStud-R20.7
# 1              Double, Clear, Metal, Air  QC_WoodStud-R24.5
# 2              Double, Clear, Metal, Air  QC_WoodStud-R17.2
# 3  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.6
# 4  Double, Low-E, Non-metal, Air, M-Gain  QC_WoodStud-R20.7
# 5          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 6          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 7          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# 8          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# 9  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
#
#   Insulation_Ceiling Insulation_Foundation_Wall Geometry_Wall_Exterior_Finish  \
# 0           QC_R30.9    QC_Wall-R17.1, interior                          None
# 1             QC_R41      QC_Wall-R17, interior                          None
# 2           QC_R27.3    QC_Wall-R14.4, interior                          None
# 3           QC_R18.3    QC_Wall-R14.4, interior                          None
# 4           QC_R30.9    QC_Wall-R17.1, interior                          None
# 5           QC_R18.3      QC_Wall-R12, interior                          None
# 6           QC_R18.3    QC_Wall-R14.4, interior                          None
# 7           QC_R24.6      QC_Wall-R12, interior                          None
# 8           QC_R24.6      QC_Wall-R12, interior                          None
# 9           QC_R29.8    QC_Wall-R17.1, interior                          None
#
#   geometry attic type HVAC_Has_Shared_System Territoire_HQ  \
# 0        Vented Attic                   None   Montmorency
# 1        Vented Attic                   None   Laurentides
# 2        Vented Attic                   None   Laurentides
# 3        Vented Attic                   None      Montréal
# 4        Vented Attic                   None   Laurentides
# 5        Vented Attic                   None   Laurentides
# 6        Vented Attic                   None     Richelieu
# 7        Vented Attic                   None   Montmorency
# 8        Vented Attic                   None      Montréal
# 9        Vented Attic                   None   Laurentides
#
#          Type_Logement Mode_Occupation     Presence_Garage  \
# 0  Maison individuelle       Locataire  Garage non chauffé
# 1  Maison individuelle    Proprietaire       Pas de Garage
# 2  Maison individuelle    Proprietaire       Pas de Garage
# 3               Duplex       Locataire       Pas de Garage
# 4  Maison individuelle    Proprietaire       Pas de Garage
# 5              Triplex       Locataire       Pas de Garage
# 6               Duplex    Proprietaire       Pas de Garage
# 7  Maison individuelle    Proprietaire       Pas de Garage
# 8  Maison individuelle    Proprietaire       Pas de Garage
# 9           Collective       Locataire       Pas de Garage
#
#           Nombre_Etages                  Presence_SousSol Nombre_Pieces  \
# 0           Deux étages                   Sous sol 6 pied             9
# 1              Un étage      Vide sanitaire moins 6 pieds             4
# 2  Trois étages et plus                   Sous sol 6 pied             6
# 3              Un étage  Aucun Sous-sol ou vide sanitaire             5
# 4           Deux étages                   Sous sol 6 pied             5
# 5              Un étage  Aucun Sous-sol ou vide sanitaire             3
# 6  Trois étages et plus  Aucun Sous-sol ou vide sanitaire             6
# 7  Trois étages et plus                   Sous sol 6 pied            11
# 8              Un étage                   Sous sol 6 pied             5
# 9              Un étage  Aucun Sous-sol ou vide sanitaire             4
#
#   Nombre_Personnes Superficie_Totale An_Construction Source_Energie_Chauf
# 0        5 et plus     [2500 - 3000)   [2000 - 2010)          Electricite
# 1                1     [1000 - 1500)   [2010 - 2020)          Electricite
# 2        5 et plus     [2000 - 2500)   [1970 - 1980)          Electricite
# 3        5 et plus      [500 - 1000)   [1970 - 1980)          Electricite
# 4                2      [500 - 1000)   [2000 - 2010)          Electricite
# 5        5 et plus      [500 - 1000)   [1950 - 1960)          Electricite
# 6                1     [1000 - 1500)   [1970 - 1980)          Electricite
# 7                2     [3000 - 3500)   [1960 - 1970)          Electricite
# 8                2     [1000 - 1500)   [1950 - 1960)                 Bois
# 9                4      [500 - 1000)   [1990 - 2000)          Electricite
#   geometry_building_num_units  \
# 0                           1
# 1                           1
# 2                           1
# 3                           2
# 4                           1
# 5                           3
# 6                           2
# 7                           1
# 8                           1
# 9                           8
#
#                         weather_station_epw_filepath  \
# 0  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 1  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 5  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 6  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 7  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 8  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 9  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#    simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                        True                         -5
# 1                                        True                         -5
# 2                                        True                         -5
# 3                                        True                         -5
# 4                                        True                         -5
# 5                                        True                         -5
# 6                                        True                         -5
# 7                                        True                         -5
# 8                                        True                         -5
# 9                                        True                         -5
#
#        geometry_unit_type  geometry_average_ceiling_height  \
# 0  single-family detached                                8
# 1  single-family detached                                8
# 2  single-family detached                                8
# 3          apartment unit                                8
# 4  single-family detached                                8
# 5          apartment unit                                8
# 6          apartment unit                                8
# 7  single-family detached                                8
# 8  single-family detached                                8
# 9          apartment unit                                8
#
#    geometry_unit_aspect_ratio  geometry_unit_cfa  geometry_garage_protrusion  \
# 0                      1.8000               2678                         0.5
# 1                      1.8000               1228                         0.5
# 2                      1.8000               2179                         0.5
# 3                      0.5556                750                         0.5
# 4                      1.8000                750                         0.5
# 5                      0.5556                750                         0.5
# 6                      0.5556               1138                         0.5
# 7                      1.8000               3250                         0.5
# 8                      1.8000               1228                         0.5
# 9                      0.5556                750                         0.5
#
#    year_built  ...  wall_color  geometry_attic_type  geometry_roof_type  \
# 0        2005  ...      medium             FlatRoof               gable
# 1        2015  ...      medium             FlatRoof               gable
# 2        1975  ...      medium             FlatRoof               gable
# 3        1975  ...      medium             FlatRoof               gable
# 4        2005  ...      medium             FlatRoof               gable
# 5        1955  ...      medium             FlatRoof               gable
# 6        1975  ...      medium             FlatRoof               gable
# 7        1965  ...      medium             FlatRoof               gable
# 8        1955  ...      medium             FlatRoof               gable
# 9        1995  ...      medium             FlatRoof               gable
#
#    geometry_roof_pitch air_leakage_units  air_leakage_house_pressure  \
# 0                 6:12               ACH                          50
# 1                 6:12               ACH                          50
# 2                 6:12               ACH                          50
# 3                 6:12               ACH                          50
# 4                 6:12               ACH                          50
# 5                 6:12               ACH                          50
# 6                 6:12               ACH                          50
# 7                 6:12               ACH                          50
# 8                 6:12               ACH                          50
# 9                 6:12               ACH                          50
#
#   air_leakage_value    air_leakage_type  site_shielding_of_home  \
# 0                 5  unit exterior only                  normal
# 1                 5  unit exterior only                  normal
# 2                 5  unit exterior only                  normal
# 3                 5  unit exterior only                  normal
# 4                 5  unit exterior only                  normal
# 5                 5  unit exterior only                  normal
# 6                 5  unit exterior only                  normal
# 7                 5  unit exterior only                  normal
# 8                 5  unit exterior only                  normal
# 9                 5  unit exterior only                  normal
#
#    rim_joist_assembly_r
# 0                   2.5
# 1                   2.5
# 2                   2.5
# 3                   0.0
# 4                   2.5
# 5                   0.0
# 6                   0.0
# 7                   2.5
# 8                   2.5
# 9                   0.0
#
# [10 rows x 43 columns]
