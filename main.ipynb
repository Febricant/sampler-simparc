# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 10
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
display(df1)
dfHPXML = pd.DataFrame(lst_dct_HPXML)
dfHPXML.to_csv("building-test.csv", index=False)
# Out:
# Nombre d'attributs HPXML:  192
#   Territoire_HQ        Type_Logement Mode_Occupation  \
# 0      Montréal              Triplex       Locataire
# 1      Montréal           Collective       Locataire
# 2   Montmorency  Maison individuelle    Proprietaire
# 3   Montmorency  Maison individuelle    Proprietaire
# 4   Montmorency  Maison individuelle       Locataire
# 5     Richelieu  Maison individuelle    Proprietaire
# 6     Richelieu           Collective       Locataire
# 7   Laurentides  Maison individuelle    Proprietaire
# 8     Richelieu           Collective       Locataire
# 9   Montmorency  Maison individuelle    Proprietaire
#
#                 Presence_Garage         Nombre_Etages  \
# 0                 Pas de Garage           Deux étages
# 1                 Pas de Garage              Un étage
# 2                 Pas de Garage  Trois étages et plus
# 3  Garage chauffé à électricité  Trois étages et plus
# 4  Garage chauffé à électricité  Trois étages et plus
# 5                 Pas de Garage           Deux étages
# 6                 Pas de Garage              Un étage
# 7                 Pas de Garage  Trois étages et plus
# 8                 Pas de Garage              Un étage
# 9  Garage chauffé à électricité  Trois étages et plus
#
#                    Presence_SousSol Nombre_Pieces Nombre_Personnes  \
# 0  Aucun Sous-sol ou vide sanitaire             7        5 et plus
# 1  Aucun Sous-sol ou vide sanitaire             3                2
# 2                   Sous sol 6 pied             5                2
# 3                   Sous sol 6 pied             7                4
# 4                   Sous sol 6 pied             9                4
# 5                   Sous sol 6 pied             8                3
# 6  Aucun Sous-sol ou vide sanitaire             3                2
# 7                   Sous sol 6 pied             7                4
# 8  Aucun Sous-sol ou vide sanitaire             3                2
# 9                   Sous sol 6 pied             6                1
#
#   Superficie_Totale An_Construction Source_Energie_Chauf
# 0     [1000 - 1500)   [1950 - 1960)           Bi-energie
# 1     [1000 - 1500)   [1950 - 1960)          Electricite
# 2     [1000 - 1500)   [1990 - 2000)          Electricite
# 3     [2000 - 2500)   [1960 - 1970)           Bi-energie
# 4     [2500 - 3000)   [1970 - 1980)          Electricite
# 5     [3500 - 4000)   [1980 - 1990)          Electricite
# 6     [1000 - 1500)   [1990 - 2000)          Electricite
# 7     [1000 - 1500)   [1970 - 1980)          Electricite
# 8      [500 - 1000)   [2000 - 2010)          Electricite
# 9     [1500 - 2000)   [1960 - 1970)          Electricite
