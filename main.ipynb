# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  66
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                   2                              13
# 2                  35                             326
# 3                   1                               1
# 4                  20                              67
# ..                ...                             ...
# 195                 1                               1
# 196                20                              67
# 197                 3                               3
# 198                14                             116
# 199                 9                             183
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                                    Left                     Top
# 2                                  Middle                  Middle
# 3                          Not Applicable                    None
# 4                                  Middle                  Middle
# ..                                    ...                     ...
# 195                        Not Applicable                    None
# 196                                Middle                  Middle
# 197                        Not Applicable                  Middle
# 198                                 Right                  Middle
# 199                                Middle                  Middle
#
#     Infiltration                                Windows    Insulation Wall  \
# 0       10 ACH50               Single, Clear, Non-metal  QC_WoodStud-R14.5
# 1        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 2        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 3        8 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R14.5
# 4        3 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# ..           ...                                    ...                ...
# 195      6 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 196      3 ACH50  Triple, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 197      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 198      5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 199      1 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R19.6    QC_Wall-R10.1, interior
# 1             QC_R29.8    QC_Wall-R17.1, interior
# 2               QC_R41      QC_Wall-R17, interior
# 3             QC_R19.6    QC_Wall-R10.1, interior
# 4             QC_R29.8    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195           QC_R27.3    QC_Wall-R14.4, interior
# 196           QC_R29.8    QC_Wall-R17.1, interior
# 197           QC_R18.3      QC_Wall-R12, interior
# 198           QC_R12.5    QC_Wall-R10.1, interior
# 199             QC_R41      QC_Wall-R17, interior
#
#     Geometry Wall Exterior Finish  ... Piscine_Minuterie An_Construction  \
# 0                            None  ...             Aucun          < 1950
# 1                            None  ...             Aucun   [1990 - 2000)
# 2                            None  ...             Aucun   [2010 - 2020)
# 3                            None  ...             Aucun          < 1950
# 4                            None  ...             Aucun   [1980 - 1990)
# ..                            ...  ...               ...             ...
# 195                          None  ...             Aucun   [1970 - 1980)
# 196                          None  ...             Aucun   [1980 - 1990)
# 197                          None  ...             Aucun   [1960 - 1970)
# 198                          None  ...             Aucun          < 1950
# 199                          None  ...             Aucun   [2010 - 2020)
#
#     Source_Energie_Chauf                                 Chauffage_Logement  \
# 0            Electricite                               Plinthes électriques
# 1            Electricite                               Plinthes électriques
# 2             Bi-energie                                        Thermopompe
# 3                   Bois  Fournaise ou poêle à bois et Plinthes électriques
# 4            Electricite                               Plinthes électriques
# ..                   ...                                                ...
# 195          Electricite                               Plinthes électriques
# 196          Electricite                               Plinthes électriques
# 197          Electricite                               Plinthes électriques
# 198          Electricite                               Plinthes électriques
# 199          Electricite                               Plinthes électriques
#
#                  Climatisation Spa_Presence Spa_Logement Spa_Saison  \
# 0                     Centrale          Non        Aucun      Aucun
# 1                       Murale          Non        Aucun      Aucun
# 2                       Murale          Non        Aucun      Aucun
# 3                       Murale          Non        Aucun      Aucun
# 4                       Aucune          Non        Aucun      Aucun
# ..                         ...          ...          ...        ...
# 195                     Aucune          Non        Aucun      Aucun
# 196                     Aucune          Non        Aucun      Aucun
# 197  Fenêtre, mobile, portable          Non        Aucun      Aucun
# 198  Fenêtre, mobile, portable          Non        Aucun      Aucun
# 199                     Murale          Non        Aucun      Aucun
#
#     Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide
# 0                          Aucun                        Aucun
# 1                          Aucun                        Aucun
# 2                          Aucun                        Aucun
# 3                          Aucun                        Aucun
# 4                          Aucun                        Aucun
# ..                           ...                          ...
# 195                        Aucun                        Aucun
# 196                        Aucun                        Aucun
# 197                        Aucun                        Aucun
# 198                        Aucun                        Aucun
# 199                        Aucun                        Aucun
#
# [200 rows x 37 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                             13          apartment unit
# 2                            326          apartment unit
# 3                              1  single-family detached
# 4                             67          apartment unit
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                           67          apartment unit
# 197                            3          apartment unit
# 198                          116          apartment unit
# 199                          183          apartment unit
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      0.5556
# 2                                  8                      0.5556
# 3                                  8                      1.8000
# 4                                  8                      0.5556
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      0.5556
# 197                                8                      0.5556
# 198                                8                      0.5556
# 199                                8                      0.5556
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                  750                         0.5        1940  ...
# 1                 1138                         0.5        1995  ...
# 2                  750                         0.5        2015  ...
# 3                 2678                         0.5        1940  ...
# 4                 1138                         0.5        1985  ...
# ..                 ...                         ...         ...  ...
# 195               2179                         0.5        1975  ...
# 196                750                         0.5        1985  ...
# 197               1138                         0.5        1965  ...
# 198               1138                         0.5        1940  ...
# 199                750                         0.5        2015  ...
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2                 fuel oil                                  0.8
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199            electricity                                  1.0
#
#      geothermal_loop_configuration      cooling_system_type  \
# 0                             none  central air conditioner
# 1                             none               mini-split
# 2                             none                     none
# 3                             none               mini-split
# 4                             none                     none
# ..                             ...                      ...
# 195                           none                     none
# 196                           none                     none
# 197                           none  central air conditioner
# 198                           none  central air conditioner
# 199                           none               mini-split
#
#     cooling_system_cooling_compressor_type  heat_pump_is_ducted  \
# 0                             single stage                  NaN
# 1                           variable speed                  NaN
# 2                                      NaN                 true
# 3                           variable speed                  NaN
# 4                                     None                  NaN
# ..                                     ...                  ...
# 195                                   None                  NaN
# 196                                   None                  NaN
# 197                           single stage                  NaN
# 198                           single stage                  NaN
# 199                         variable speed                  NaN
#
#     heat_pump_compressor_lockout_temp  heat_pump_cooling_compressor_type  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                10.4                       single stage
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ..                                ...                                ...
# 195                               NaN                                NaN
# 196                               NaN                                NaN
# 197                               NaN                                NaN
# 198                               NaN                                NaN
# 199                               NaN                                NaN
#
#      overhangs_front_depth  overhangs_front_distance_to_top_of_window
# 0                      NaN                                        NaN
# 1                      NaN                                        NaN
# 2                      NaN                                        NaN
# 3                      NaN                                        NaN
# 4                      NaN                                        NaN
# ..                     ...                                        ...
# 195                    NaN                                        NaN
# 196                    NaN                                        NaN
# 197                   10.0                                        1.0
# 198                    NaN                                        NaN
# 199                    NaN                                        NaN
#
# [200 rows x 71 columns]
