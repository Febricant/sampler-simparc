# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  68
#      Geometry Stories  Geometry Building Number Units  \
# 0                   3                               3
# 1                   1                               1
# 2                  12                             116
# 3                   9                             326
# 4                   1                               1
# ..                ...                             ...
# 195                 1                               1
# 196                 2                              12
# 197                 1                               8
# 198                 1                               1
# 199                 2                               2
#
#     Geometry Building Horizontal Location Infiltration  \
# 0                          Not Applicable      3 ACH50
# 1                          Not Applicable      3 ACH50
# 2                                   Right      6 ACH50
# 3                                  Middle      3 ACH50
# 4                          Not Applicable      6 ACH50
# ..                                    ...          ...
# 195                        Not Applicable      6 ACH50
# 196                                  Left      5 ACH50
# 197                                 Right      1 ACH50
# 198                        Not Applicable      6 ACH50
# 199                        Not Applicable      6 ACH50
#
#                                    Windows    Insulation Wall  \
# 0            Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 1    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# 2    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 3            Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 4    Double, Low-E, Non-metal, Air, M-Gain    QC_WoodStud-R14
# ..                                     ...                ...
# 195          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 196  Double, Low-E, Non-metal, Air, M-Gain  QC_WoodStud-R18.9
# 197          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 198  Triple, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R17.2
# 199          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R12.5    QC_Wall-R10.1, interior
# 1             QC_R30.9    QC_Wall-R17.1, interior
# 2             QC_R29.8    QC_Wall-R17.1, interior
# 3             QC_R29.8    QC_Wall-R17.1, interior
# 4             QC_R24.6      QC_Wall-R12, interior
# ..                 ...                        ...
# 195           QC_R27.3    QC_Wall-R14.4, interior
# 196           QC_R29.8    QC_Wall-R17.1, interior
# 197           QC_R29.8    QC_Wall-R17.1, interior
# 198           QC_R27.3    QC_Wall-R14.4, interior
# 199           QC_R18.3      QC_Wall-R12, interior
#
#     Geometry Wall Exterior Finish geometry attic type  ... Mode_Occupation  \
# 0                            None        Vented Attic  ...       Locataire
# 1                            None        Vented Attic  ...    Proprietaire
# 2                            None        Vented Attic  ...       Locataire
# 3                            None        Vented Attic  ...    Proprietaire
# 4                            None        Vented Attic  ...    Proprietaire
# ..                            ...                 ...  ...             ...
# 195                          None        Vented Attic  ...    Proprietaire
# 196                          None        Vented Attic  ...       Locataire
# 197                          None        Vented Attic  ...       Locataire
# 198                          None        Vented Attic  ...    Proprietaire
# 199                          None        Vented Attic  ...    Proprietaire
#
#             Nombre_Etages Nombre_Pieces Nombre_Personnes Superficie_Totale  \
# 0                Un étage             4                2     [1000 - 1500)
# 1    Trois étages et plus            10                2     [2500 - 3000)
# 2                Un étage             3                1      [500 - 1000)
# 3                Un étage             3                1      [500 - 1000)
# 4    Trois étages et plus            13                2     [3500 - 4000)
# ..                    ...           ...              ...               ...
# 195           Deux étages             7                2     [2000 - 2500)
# 196              Un étage             4                1     [1000 - 1500)
# 197              Un étage             4                3     [1000 - 1500)
# 198           Deux étages            13                2     [3000 - 3500)
# 199              Un étage             4                1     [3000 - 3500)
#
#                      Presence_SousSol An_Construction Source_Energie_Chauf  \
# 0    Aucun Sous-sol ou vide sanitaire          < 1950          Electricite
# 1                     Sous sol 6 pied   [2000 - 2010)          Electricite
# 2    Aucun Sous-sol ou vide sanitaire   [1980 - 1990)          Electricite
# 3    Aucun Sous-sol ou vide sanitaire   [2000 - 2010)          Electricite
# 4                     Sous sol 6 pied   [1960 - 1970)               Mazout
# ..                                ...             ...                  ...
# 195                   Sous sol 6 pied   [1970 - 1980)                 Bois
# 196  Aucun Sous-sol ou vide sanitaire   [1990 - 2000)          Electricite
# 197  Aucun Sous-sol ou vide sanitaire   [2000 - 2010)          Electricite
# 198                   Sous sol 6 pied   [1970 - 1980)          Electricite
# 199  Aucun Sous-sol ou vide sanitaire   [1950 - 1960)          Electricite
#
#                                     Chauffage_Logement  \
# 0                                 Plinthes électriques
# 1                                 Plinthes électriques
# 2                                 Plinthes électriques
# 3                                          Thermopompe
# 4                          Système central à air chaud
# ..                                                 ...
# 195  Fournaise ou poêle à bois et Système central à...
# 196                               Plinthes électriques
# 197                               Plinthes électriques
# 198                               Plinthes électriques
# 199                               Plinthes électriques
#
#                  Climatisation
# 0                       Murale
# 1                       Aucune
# 2    Fenêtre, mobile, portable
# 3                     Centrale
# 4    Fenêtre, mobile, portable
# ..                         ...
# 195                     Murale
# 196                     Aucune
# 197                     Aucune
# 198                     Murale
# 199                     Aucune
#
# [200 rows x 25 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 197  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              3          apartment unit
# 1                              1  single-family detached
# 2                            116          apartment unit
# 3                            326          apartment unit
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                           12          apartment unit
# 197                            8          apartment unit
# 198                            1  single-family detached
# 199                            2          apartment unit
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      0.5556
# 1                                  8                      1.8000
# 2                                  8                      0.5556
# 3                                  8                      0.5556
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      0.5556
# 197                                8                      0.5556
# 198                                8                      1.8000
# 199                                8                      0.5556
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 1138                         0.5        1940  ...
# 1                 2678                         0.5        2005  ...
# 2                  750                         0.5        1985  ...
# 3                  750                         0.5        2005  ...
# 4                 3750                         0.5        1965  ...
# ..                 ...                         ...         ...  ...
# 195               2179                         0.5        1975  ...
# 196               1138                         0.5        1995  ...
# 197               1138                         0.5        2005  ...
# 198               3250                         0.5        1975  ...
# 199               3250                         0.5        1955  ...
#
#      heat_pump_backup_use_existing_system  heat_pump_backup_type  \
# 0                                   false                   none
# 1                                   false                   none
# 2                                   false                   none
# 3                                   false             integrated
# 4                                   false                   none
# ..                                    ...                    ...
# 195                                 false                   none
# 196                                 false                   none
# 197                                 false                   none
# 198                                 false                   none
# 199                                 false                   none
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2              electricity                                  1.0
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199            electricity                                  1.0
#
#     geothermal_loop_configuration      cooling_system_type  \
# 0                            none               mini-split
# 1                            none                     none
# 2                            none  central air conditioner
# 3                            none                     none
# 4                            none  central air conditioner
# ..                            ...                      ...
# 195                          none               mini-split
# 196                          none                     none
# 197                          none                     none
# 198                          none               mini-split
# 199                          none                     none
#
#     cooling_system_cooling_compressor_type  heat_pump_is_ducted  \
# 0                           variable speed                  NaN
# 1                                     None                  NaN
# 2                             single stage                  NaN
# 3                                      NaN                 true
# 4                             single stage                  NaN
# ..                                     ...                  ...
# 195                         variable speed                  NaN
# 196                                   None                  NaN
# 197                                   None                  NaN
# 198                         variable speed                  NaN
# 199                                   None                  NaN
#
#      heat_pump_cooling_compressor_type  heat_pump_compressor_lockout_temp
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                         single stage                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 195                                NaN                                NaN
# 196                                NaN                                NaN
# 197                                NaN                                NaN
# 198                                NaN                                NaN
# 199                                NaN                                NaN
#
# [200 rows x 71 columns]
