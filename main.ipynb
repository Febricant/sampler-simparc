# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  68
#      Geometry Stories  Geometry Building Number Units  \
# 0                   3                               3
# 1                   1                              16
# 2                   1                               1
# 3                   2                               2
# 4                   1                               1
# ..                ...                             ...
# 195                 2                              67
# 196                 1                               1
# 197                 1                               1
# 198                 1                               1
# 199                 3                               3
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                  Bottom
# 1                                  Middle                  Bottom
# 2                          Not Applicable                    None
# 3                          Not Applicable                     Top
# 4                          Not Applicable                    None
# ..                                    ...                     ...
# 195                                Middle                  Bottom
# 196                        Not Applicable                    None
# 197                        Not Applicable                    None
# 198                        Not Applicable                    None
# 199                        Not Applicable                  Middle
#
#     Infiltration                                Windows    Insulation Wall  \
# 0       10 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.2
# 1        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 2        7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 3        6 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 4        8 ACH50  Double, Low-E, Non-metal, Air, L-Gain    QC_WoodStud-R14
# ..           ...                                    ...                ...
# 195      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 196      8 ACH50               Single, Clear, Non-metal  QC_WoodStud-R14.5
# 197      1 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R24.5
# 198      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 199      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R12.5    QC_Wall-R10.1, interior
# 1             QC_R29.8    QC_Wall-R17.1, interior
# 2             QC_R27.3    QC_Wall-R14.4, interior
# 3             QC_R18.3      QC_Wall-R12, interior
# 4             QC_R24.6      QC_Wall-R12, interior
# ..                 ...                        ...
# 195             QC_R41      QC_Wall-R17, interior
# 196           QC_R19.6    QC_Wall-R10.1, interior
# 197             QC_R41      QC_Wall-R17, interior
# 198           QC_R30.9    QC_Wall-R17.1, interior
# 199           QC_R18.3    QC_Wall-R14.4, interior
#
#     Geometry Wall Exterior Finish  ... Piscine_Minuterie An_Construction  \
# 0                            None  ...             Aucun          < 1950
# 1                            None  ...             Aucun   [1980 - 1990)
# 2                            None  ...               Oui   [1970 - 1980)
# 3                            None  ...             Aucun   [1950 - 1960)
# 4                            None  ...             Aucun   [1950 - 1960)
# ..                            ...  ...               ...             ...
# 195                          None  ...             Aucun   [2010 - 2020)
# 196                          None  ...             Aucun          < 1950
# 197                          None  ...             Aucun   [2010 - 2020)
# 198                          None  ...             Aucun   [2000 - 2010)
# 199                          None  ...             Aucun   [1970 - 1980)
#
#     Source_Energie_Chauf           Chauffage_Logement  \
# 0            Electricite         Plinthes électriques
# 1            Electricite         Plinthes électriques
# 2            Electricite  Système central à air chaud
# 3            Electricite         Plinthes électriques
# 4            Electricite         Plinthes électriques
# ..                   ...                          ...
# 195          Electricite         Plinthes électriques
# 196          Electricite         Plinthes électriques
# 197          Electricite         Plinthes électriques
# 198          Electricite                  Thermopompe
# 199          Electricite         Plinthes électriques
#
#                  Climatisation Spa_Presence Spa_Logement    Spa_Saison  \
# 0    Fenêtre, mobile, portable          Non        Aucun         Aucun
# 1                     Centrale          Non        Aucun         Aucun
# 2                     Centrale          Non        Aucun         Aucun
# 3    Fenêtre, mobile, portable          Non        Aucun         Aucun
# 4                       Aucune          Non        Aucun         Aucun
# ..                         ...          ...          ...           ...
# 195  Fenêtre, mobile, portable          Non        Aucun         Aucun
# 196                     Murale          Non        Aucun         Aucun
# 197  Fenêtre, mobile, portable          Non        Aucun         Aucun
# 198                     Murale          Oui    Exterieur  Toute_Saison
# 199  Fenêtre, mobile, portable          Non        Aucun         Aucun
#
#     Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide
# 0                          Aucun                        Aucun
# 1                          Aucun                        Aucun
# 2                          Aucun                        Aucun
# 3                          Aucun                        Aucun
# 4                          Aucun                        Aucun
# ..                           ...                          ...
# 195                        Aucun                        Aucun
# 196                        Aucun                        Aucun
# 197                        Aucun                        Aucun
# 198                     Constant                 Augmentation
# 199                        Aucun                        Aucun
#
# [200 rows x 37 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              3          apartment unit
# 1                             16          apartment unit
# 2                              1  single-family detached
# 3                              2          apartment unit
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                           67          apartment unit
# 196                            1  single-family detached
# 197                            1  single-family detached
# 198                            1  single-family detached
# 199                            3          apartment unit
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      0.5556
# 1                                  8                      0.5556
# 2                                  8                      1.8000
# 3                                  8                      0.5556
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      0.5556
# 196                                8                      1.8000
# 197                                8                      1.8000
# 198                                8                      1.8000
# 199                                8                      0.5556
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 1138                         0.5        1940  ...
# 1                 1682                         0.5        1985  ...
# 2                 3250                         0.5        1975  ...
# 3                  750                         0.5        1955  ...
# 4                 2179                         0.5        1955  ...
# ..                 ...                         ...         ...  ...
# 195               1138                         0.5        2015  ...
# 196               2678                         0.5        1940  ...
# 197               2179                         0.5        2015  ...
# 198               2678                         0.5        2005  ...
# 199                750                         0.5        1975  ...
#
#      heat_pump_backup_use_existing_system  heat_pump_backup_type  \
# 0                                   false                   none
# 1                                   false                   none
# 2                                   false                   none
# 3                                   false                   none
# 4                                   false                   none
# ..                                    ...                    ...
# 195                                 false                   none
# 196                                 false                   none
# 197                                 false                   none
# 198                                 false             integrated
# 199                                 false                   none
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2              electricity                                  1.0
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199            electricity                                  1.0
#
#     geothermal_loop_configuration      cooling_system_type  \
# 0                            none  central air conditioner
# 1                            none  central air conditioner
# 2                            none  central air conditioner
# 3                            none  central air conditioner
# 4                            none                     none
# ..                            ...                      ...
# 195                          none  central air conditioner
# 196                          none               mini-split
# 197                          none  central air conditioner
# 198                          none                     none
# 199                          none  central air conditioner
#
#     cooling_system_cooling_compressor_type  heat_pump_is_ducted  \
# 0                             single stage                  NaN
# 1                             single stage                  NaN
# 2                             single stage                  NaN
# 3                             single stage                  NaN
# 4                                     None                  NaN
# ..                                     ...                  ...
# 195                           single stage                  NaN
# 196                         variable speed                  NaN
# 197                           single stage                  NaN
# 198                                    NaN                 true
# 199                           single stage                  NaN
#
#      heat_pump_cooling_compressor_type  heat_pump_compressor_lockout_temp
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 195                                NaN                                NaN
# 196                                NaN                                NaN
# 197                                NaN                                NaN
# 198                       single stage                                NaN
# 199                                NaN                                NaN
#
# [200 rows x 71 columns]
