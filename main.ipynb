# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  68
#      Geometry Stories  Geometry Building Number Units  \
# 0                   2                               2
# 1                   1                              16
# 2                   3                               3
# 3                   7                              43
# 4                  20                              67
# ..                ...                             ...
# 195                 1                               1
# 196                 1                               1
# 197                 1                               1
# 198                 3                               3
# 199                 1                               1
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                  Bottom
# 1                                  Middle                  Bottom
# 2                          Not Applicable                  Middle
# 3                                    Left                  Middle
# 4                                  Middle                  Middle
# ..                                    ...                     ...
# 195                        Not Applicable                    None
# 196                        Not Applicable                    None
# 197                        Not Applicable                    None
# 198                        Not Applicable                  Middle
# 199                        Not Applicable                    None
#
#     Infiltration                                Windows    Insulation Wall  \
# 0       10 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.2
# 1        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 2        5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 3        7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 4        3 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# ..           ...                                    ...                ...
# 195      8 ACH50              Double, Clear, Metal, Air    QC_WoodStud-R14
# 196      7 ACH50  Triple, Low-E, Non-metal, Air, L-Gain    QC_WoodStud-R14
# 197      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 198      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 199      5 ACH50          Double, Clear, Non-metal, Air    QC_WoodStud-R14
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R12.5    QC_Wall-R10.1, interior
# 1             QC_R29.8    QC_Wall-R17.1, interior
# 2             QC_R18.3    QC_Wall-R14.4, interior
# 3             QC_R12.5    QC_Wall-R10.1, interior
# 4             QC_R29.8    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195           QC_R24.6      QC_Wall-R12, interior
# 196           QC_R24.6      QC_Wall-R12, interior
# 197           QC_R30.9    QC_Wall-R17.1, interior
# 198           QC_R18.3      QC_Wall-R12, interior
# 199           QC_R24.6      QC_Wall-R12, interior
#
#     Geometry Wall Exterior Finish  ... Mode_Occupation         Nombre_Etages  \
# 0                            None  ...       Locataire              Un étage
# 1                            None  ...       Locataire              Un étage
# 2                            None  ...       Locataire           Deux étages
# 3                            None  ...       Locataire              Un étage
# 4                            None  ...       Locataire              Un étage
# ..                            ...  ...             ...                   ...
# 195                          None  ...       Locataire           Deux étages
# 196                          None  ...    Proprietaire  Trois étages et plus
# 197                          None  ...    Proprietaire           Deux étages
# 198                          None  ...       Locataire           Deux étages
# 199                          None  ...    Proprietaire           Deux étages
#
#     Nombre_Pieces Nombre_Personnes Superficie_Totale  \
# 0               2                2      [500 - 1000)
# 1               3                2      [500 - 1000)
# 2               9        5 et plus     [2000 - 2500)
# 3               5                3      [500 - 1000)
# 4               5                2     [1000 - 1500)
# ..            ...              ...               ...
# 195            11                4     [2500 - 3000)
# 196            10                2           >= 5000
# 197             9                2     [2000 - 2500)
# 198             8                2     [1500 - 2000)
# 199             4                3     [2000 - 2500)
#
#                      Presence_SousSol An_Construction Source_Energie_Chauf  \
# 0    Aucun Sous-sol ou vide sanitaire          < 1950          Electricite
# 1    Aucun Sous-sol ou vide sanitaire   [2000 - 2010)          Electricite
# 2    Aucun Sous-sol ou vide sanitaire   [1970 - 1980)          Electricite
# 3    Aucun Sous-sol ou vide sanitaire          < 1950          Electricite
# 4    Aucun Sous-sol ou vide sanitaire   [1990 - 2000)          Electricite
# ..                                ...             ...                  ...
# 195                   Sous sol 6 pied   [1960 - 1970)          Electricite
# 196                   Sous sol 6 pied   [1950 - 1960)          Electricite
# 197                   Sous sol 6 pied   [1990 - 2000)          Electricite
# 198  Aucun Sous-sol ou vide sanitaire   [1960 - 1970)          Electricite
# 199                   Sous sol 6 pied   [1960 - 1970)               Mazout
#
#                Chauffage_Logement              Climatisation
# 0            Plinthes électriques  Fenêtre, mobile, portable
# 1            Plinthes électriques  Fenêtre, mobile, portable
# 2            Plinthes électriques                     Murale
# 3    Système central à eau chaude  Fenêtre, mobile, portable
# 4            Plinthes électriques                     Aucune
# ..                            ...                        ...
# 195          Plinthes électriques                     Aucune
# 196          Plinthes électriques                   Centrale
# 197  Système central à eau chaude                     Aucune
# 198          Plinthes électriques                     Aucune
# 199   Système central à air chaud                     Aucune
#
# [200 rows x 26 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              2          apartment unit
# 1                             16          apartment unit
# 2                              3          apartment unit
# 3                             43          apartment unit
# 4                             67          apartment unit
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                            1  single-family detached
# 197                            1  single-family detached
# 198                            3          apartment unit
# 199                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      0.5556
# 1                                  8                      0.5556
# 2                                  8                      0.5556
# 3                                  8                      0.5556
# 4                                  8                      0.5556
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      1.8000
# 197                                8                      1.8000
# 198                                8                      0.5556
# 199                                8                      1.8000
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                  750                         0.5        1940  ...
# 1                  750                         0.5        2005  ...
# 2                 2115                         0.5        1975  ...
# 3                  750                         0.5        1940  ...
# 4                 1138                         0.5        1995  ...
# ..                 ...                         ...         ...  ...
# 195               2678                         0.5        1965  ...
# 196               5587                         0.5        1955  ...
# 197               2179                         0.5        1995  ...
# 198               1682                         0.5        1965  ...
# 199               2179                         0.5        1965  ...
#
#      heat_pump_backup_use_existing_system  heat_pump_backup_type  \
# 0                                   false                   none
# 1                                   false                   none
# 2                                   false                   none
# 3                                   false                   none
# 4                                   false                   none
# ..                                    ...                    ...
# 195                                 false                   none
# 196                                 false                   none
# 197                                 false                   none
# 198                                 false                   none
# 199                                 false                   none
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2              electricity                                  1.0
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199            electricity                                  1.0
#
#     geothermal_loop_configuration      cooling_system_type  \
# 0                            none  central air conditioner
# 1                            none  central air conditioner
# 2                            none               mini-split
# 3                            none  central air conditioner
# 4                            none                     none
# ..                            ...                      ...
# 195                          none                     none
# 196                          none  central air conditioner
# 197                          none                     none
# 198                          none                     none
# 199                          none                     none
#
#     cooling_system_cooling_compressor_type  heat_pump_is_ducted  \
# 0                             single stage                  NaN
# 1                             single stage                  NaN
# 2                           variable speed                  NaN
# 3                             single stage                  NaN
# 4                                     None                  NaN
# ..                                     ...                  ...
# 195                                   None                  NaN
# 196                           single stage                  NaN
# 197                                   None                  NaN
# 198                                   None                  NaN
# 199                                   None                  NaN
#
#      heat_pump_cooling_compressor_type  heat_pump_compressor_lockout_temp
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 195                                NaN                                NaN
# 196                                NaN                                NaN
# 197                                NaN                                NaN
# 198                                NaN                                NaN
# 199                                NaN                                NaN
#
# [200 rows x 71 columns]
