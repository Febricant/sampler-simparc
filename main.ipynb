# %%
import os
import sys
import pandas as pd
import dtale
from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  84
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                   1                               1
# 2                   3                               3
# 3                   1                               1
# 4                   1                               1
# ..                ...                             ...
# 195                 4                              24
# 196                13                              67
# 197                 3                               3
# 198                 1                               1
# 199                 3                               3
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                          Not Applicable                    None
# 2                          Not Applicable                  Middle
# 3                          Not Applicable                    None
# 4                          Not Applicable                    None
# ..                                    ...                     ...
# 195                                Middle                     Top
# 196                                  Left                  Middle
# 197                        Not Applicable                  Bottom
# 198                        Not Applicable                    None
# 199                        Not Applicable                  Middle
#
#     Infiltration                                Windows    Insulation Wall  \
# 0        7 ACH50  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# 1        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 2        6 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 3        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 4        5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# ..           ...                                    ...                ...
# 195      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 196      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 197      7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 198     10 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 199      5 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R30.9    QC_Wall-R17.1, interior
# 1             QC_R30.9    QC_Wall-R17.1, interior
# 2             QC_R12.5    QC_Wall-R10.1, interior
# 3             QC_R30.9    QC_Wall-R17.1, interior
# 4             QC_R30.9    QC_Wall-R17.1, interior
# ..                 ...                        ...
# 195             QC_R41      QC_Wall-R17, interior
# 196           QC_R29.8    QC_Wall-R17.1, interior
# 197           QC_R12.5    QC_Wall-R10.1, interior
# 198           QC_R27.3    QC_Wall-R14.4, interior
# 199           QC_R29.8    QC_Wall-R17.1, interior
#
#     Geometry Wall Exterior Finish  ... Spa_Presence Spa_Logement Spa_Saison  \
# 0                            None  ...          Non        Aucun      Aucun
# 1                            None  ...          Non        Aucun      Aucun
# 2                            None  ...          Non        Aucun      Aucun
# 3                            None  ...          Non        Aucun      Aucun
# 4                            None  ...          Non        Aucun      Aucun
# ..                            ...  ...          ...          ...        ...
# 195                          None  ...          Non        Aucun      Aucun
# 196                          None  ...          Non        Aucun      Aucun
# 197                          None  ...          Non        Aucun      Aucun
# 198                          None  ...          Non        Aucun      Aucun
# 199                          None  ...          Non        Aucun      Aucun
#
#     Spa_Utilisation_SaisonChaude Spa_Utilisation_SaisonFroide An_Construction  \
# 0                          Aucun                        Aucun   [1990 - 2000)
# 1                          Aucun                        Aucun   [1980 - 1990)
# 2                          Aucun                        Aucun          < 1950
# 3                          Aucun                        Aucun   [2000 - 2010)
# 4                          Aucun                        Aucun   [2000 - 2010)
# ..                           ...                          ...             ...
# 195                        Aucun                        Aucun   [2010 - 2020)
# 196                        Aucun                        Aucun   [1990 - 2000)
# 197                        Aucun                        Aucun          < 1950
# 198                        Aucun                        Aucun   [1970 - 1980)
# 199                        Aucun                        Aucun   [1990 - 2000)
#
#     Source_Energie_Chauf ChaufEau_ChaufType         Chauffage_Logement  \
# 0            Electricite         Electrique                Thermopompe
# 1                   Bois         Electrique  Fournaise ou poêle à bois
# 2            Electricite         Electrique       Plinthes électriques
# 3            Electricite         Electrique       Plinthes électriques
# 4            Electricite         Electrique       Plinthes électriques
# ..                   ...                ...                        ...
# 195          Electricite         Electrique       Plinthes électriques
# 196          Electricite         Electrique       Plinthes électriques
# 197          Electricite         Electrique       Plinthes électriques
# 198          Electricite         Electrique       Plinthes électriques
# 199          Electricite         Electrique                Thermopompe
#
#                  Climatisation
# 0                       Murale
# 1                       Aucune
# 2                       Murale
# 3                       Aucune
# 4                       Aucune
# ..                         ...
# 195  Fenêtre, mobile, portable
# 196  Fenêtre, mobile, portable
# 197                     Aucune
# 198  Fenêtre, mobile, portable
# 199                     Murale
#
# [200 rows x 43 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 199  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                              1  single-family detached
# 2                              3          apartment unit
# 3                              1  single-family detached
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                           24          apartment unit
# 196                           67          apartment unit
# 197                            3          apartment unit
# 198                            1  single-family detached
# 199                            3          apartment unit
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      1.8000
# 2                                  8                      0.5556
# 3                                  8                      1.8000
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      0.5556
# 196                                8                      0.5556
# 197                                8                      0.5556
# 198                                8                      1.8000
# 199                                8                      0.5556
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 1698                         0.5        1995  ...
# 1                  750                         0.5        1985  ...
# 2                  750                         0.5        1940  ...
# 3                  750                         0.5        2005  ...
# 4                 2678                         0.5        2005  ...
# ..                 ...                         ...         ...  ...
# 195               1138                         0.5        2015  ...
# 196                750                         0.5        1995  ...
# 197               1138                         0.5        1940  ...
# 198                750                         0.5        1975  ...
# 199                750                         0.5        1995  ...
#
#      water_heater_setpoint_temperature     water_heater_type  \
# 0                                  125  storage water heater
# 1                                  125  storage water heater
# 2                                  125  storage water heater
# 3                                  125  storage water heater
# 4                                  125  storage water heater
# ..                                 ...                   ...
# 195                                125  storage water heater
# 196                                125  storage water heater
# 197                                125  storage water heater
# 198                                125  storage water heater
# 199                                125  storage water heater
#
#               water_heater_location  water_heater_tank_volume  \
# 0                 conditioned space                      60.0
# 1                 conditioned space                      60.0
# 2    other multifamily buffer space                       NaN
# 3                 conditioned space                      60.0
# 4                 conditioned space                      60.0
# ..                              ...                       ...
# 195               conditioned space                       NaN
# 196               conditioned space                      60.0
# 197  other multifamily buffer space                       NaN
# 198               conditioned space                       NaN
# 199               conditioned space                       NaN
#
#     cooling_system_cooling_compressor_type  overhangs_front_depth  \
# 0                                      NaN                    NaN
# 1                                     None                    NaN
# 2                           variable speed                   10.0
# 3                                     None                    NaN
# 4                                     None                    NaN
# ..                                     ...                    ...
# 195                           single stage                    NaN
# 196                           single stage                    NaN
# 197                                   None                   10.0
# 198                           single stage                    NaN
# 199                                    NaN                   10.0
#
#     overhangs_front_distance_to_top_of_window  \
# 0                                         NaN
# 1                                         NaN
# 2                                         1.0
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       1.0
# 198                                       NaN
# 199                                       1.0
#
#      misc_plug_loads_vehicle_annual_kwh  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 195                                 NaN
# 196                                 NaN
# 197                                 NaN
# 198                              3274.0
# 199                                 NaN
#
#      misc_plug_loads_vehicle_usage_multiplier  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                                       NaN
# 198                                       1.0
# 199                                       NaN
#
#      heat_pump_compressor_lockout_temp
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 195                                NaN
# 196                                NaN
# 197                                NaN
# 198                                NaN
# 199                                NaN
#
# [200 rows x 90 columns]

# %%
dtale.show(dfargs)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dtale.show(dfHPXML)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PW158264:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
