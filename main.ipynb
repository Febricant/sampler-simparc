# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBachArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 100
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBachArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire


MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)
display(pd.DataFrame(lst_dct_args))
dfHPXML = pd.DataFrame(lst_dct_HPXML)
dfHPXML.to_csv("building-test.csv", index=False)
dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  64
#    geometry_building_num_units Infiltration  \
# 0                            1      2 ACH50
# 1                           25      1 ACH50
# 2                            4      1 ACH50
# 3                           49      3 ACH50
# 4                            8      3 ACH50
# ..                         ...          ...
# 95                           5      1 ACH50
# 96                           3      7 ACH50
# 97                          20      2 ACH50
# 98                           1     10 ACH50
# 99                           2      7 ACH50
#
#                                   Windows    Insulation Wall  \
# 0           Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 1   Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 2   Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 3           Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 4           Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# ..                                    ...                ...
# 95  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 96  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.6
# 97          Double, Clear, Non-metal, Air  QC_WoodStud-R18.9
# 98  Double, Low-E, Non-metal, Air, L-Gain    QC_WoodStud-R14
# 99          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
#
#    Insulation Ceiling Insulation Foundation Wall  \
# 0              QC_R41      QC_Wall-R17, interior
# 1            QC_R29.8    QC_Wall-R17.1, interior
# 2            QC_R29.8    QC_Wall-R17.1, interior
# 3            QC_R29.8    QC_Wall-R17.1, interior
# 4            QC_R29.8    QC_Wall-R17.1, interior
# ..                ...                        ...
# 95           QC_R29.8    QC_Wall-R17.1, interior
# 96           QC_R18.3      QC_Wall-R12, interior
# 97           QC_R29.8    QC_Wall-R17.1, interior
# 98           QC_R24.6      QC_Wall-R12, interior
# 99           QC_R12.5    QC_Wall-R10.1, interior
#
#    Geometry Wall Exterior Finish geometry attic type HVAC Has Shared System  \
# 0                           None        Vented Attic                   None
# 1                           None        Vented Attic                   None
# 2                           None        Vented Attic                   None
# 3                           None        Vented Attic                   None
# 4                           None        Vented Attic                   None
# ..                           ...                 ...                    ...
# 95                          None        Vented Attic                   None
# 96                          None        Vented Attic                   None
# 97                          None        Vented Attic                   None
# 98                          None        Vented Attic                   None
# 99                          None        Vented Attic                   None
#
#                               HVAC Heating Efficiency  ... Mode_Occupation  \
# 0   Fuel Boiler, 72% AFUE & Electric Baseboard, 10...  ...    Proprietaire
# 1                    Electric Wall Furnace, 100% AFUE  ...       Locataire
# 2                 Electric Baseboard, 100% Efficiency  ...    Proprietaire
# 3                 Electric Baseboard, 100% Efficiency  ...       Locataire
# 4                          Electric Boiler, 100% AFUE  ...    Proprietaire
# ..                                                ...  ...             ...
# 95                   Electric Wall Furnace, 100% AFUE  ...    Proprietaire
# 96                              Fuel Boiler, 72% AFUE  ...    Proprietaire
# 97                Electric Baseboard, 100% Efficiency  ...       Locataire
# 98                Electric Baseboard, 100% Efficiency  ...    Proprietaire
# 99                              Fuel Boiler, 80% AFUE  ...       Locataire
#
#    An_Construction Source_Energie_Chauf  \
# 0          >= 2020                 Bois
# 1    [1990 - 2000)          Electricite
# 2    [2000 - 2010)          Electricite
# 3    [2000 - 2010)          Electricite
# 4    [1980 - 1990)          Electricite
# ..             ...                  ...
# 95   [1980 - 1990)          Electricite
# 96   [1960 - 1970)                 Bois
# 97   [2000 - 2010)          Electricite
# 98   [1960 - 1970)          Electricite
# 99          < 1950          Gaz naturel
#
#                                    Chauffage_Logement Nombre_Etages  \
# 0   Fournaise ou poêle à bois et Plinthes électriques      Un étage
# 1     Unités convecteurs, plancher ou plafond radiant      Un étage
# 2                                Plinthes électriques      Un étage
# 3                                Plinthes électriques      Un étage
# 4                        Système central à eau chaude      Un étage
# ..                                                ...           ...
# 95    Unités convecteurs, plancher ou plafond radiant      Un étage
# 96                          Fournaise ou poêle à bois      Un étage
# 97                               Plinthes électriques      Un étage
# 98                               Plinthes électriques   Deux étages
# 99                       Système central à eau chaude   Deux étages
#
#    Nombre_Pieces Nombre_Personnes Superficie_Totale  \
# 0              5                4     [1000 - 1500)
# 1              3                1         [1 - 500)
# 2              5                2     [1000 - 1500)
# 3              4                3     [1000 - 1500)
# 4              3                4      [500 - 1000)
# ..           ...              ...               ...
# 95             4                2     [4500 - 5000)
# 96             5                3     [1000 - 1500)
# 97             4                3      [500 - 1000)
# 98             5                2     [1000 - 1500)
# 99             4                1      [500 - 1000)
#
#                     Presence_SousSol                Presence_Garage
# 0   Aucun Sous-sol ou vide sanitaire  Garage chauffé à autre source
# 1   Aucun Sous-sol ou vide sanitaire                  Pas de Garage
# 2   Aucun Sous-sol ou vide sanitaire                  Pas de Garage
# 3   Aucun Sous-sol ou vide sanitaire                  Pas de Garage
# 4   Aucun Sous-sol ou vide sanitaire                  Pas de Garage
# ..                               ...                            ...
# 95  Aucun Sous-sol ou vide sanitaire                  Pas de Garage
# 96  Aucun Sous-sol ou vide sanitaire                  Pas de Garage
# 97  Aucun Sous-sol ou vide sanitaire                  Pas de Garage
# 98                   Sous sol 6 pied                  Pas de Garage
# 99  Aucun Sous-sol ou vide sanitaire                  Pas de Garage
#
# [100 rows x 23 columns]
#    geometry_building_num_units  \
# 0                            1
# 1                           25
# 2                            4
# 3                           49
# 4                            8
# ..                         ...
# 95                           5
# 96                           3
# 97                          20
# 98                           1
# 99                           2
#
#                          weather_station_epw_filepath  \
# 0   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2   2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 3   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                ...
# 95  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 96  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 97  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 98  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 99  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#     simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                         True                         -5
# 1                                         True                         -5
# 2                                         True                         -5
# 3                                         True                         -5
# 4                                         True                         -5
# ..                                         ...                        ...
# 95                                        True                         -5
# 96                                        True                         -5
# 97                                        True                         -5
# 98                                        True                         -5
# 99                                        True                         -5
#
#         geometry_unit_type  geometry_average_ceiling_height  \
# 0   single-family detached                                8
# 1           apartment unit                                8
# 2           apartment unit                                8
# 3           apartment unit                                8
# 4           apartment unit                                8
# ..                     ...                              ...
# 95          apartment unit                                8
# 96          apartment unit                                8
# 97          apartment unit                                8
# 98  single-family detached                                8
# 99          apartment unit                                8
#
#     geometry_unit_aspect_ratio  geometry_unit_cfa  geometry_garage_protrusion  \
# 0                       1.8000               1228                        0.50
# 1                       0.5556                322                        0.75
# 2                       0.5556               1138                        0.50
# 3                       0.5556               1138                        0.50
# 4                       0.5556                750                        0.50
# ..                         ...                ...                         ...
# 95                      0.5556               4750                        0.50
# 96                      0.5556               1138                        0.50
# 97                      0.5556                750                        0.50
# 98                      1.8000               1228                        0.50
# 99                      0.5556                750                        0.50
#
#     year_built  ...  heat_pump_sizing_methodology  \
# 0         2020  ...                          ACCA
# 1         1995  ...                          ACCA
# 2         2005  ...                          ACCA
# 3         2005  ...                          ACCA
# 4         1985  ...                          ACCA
# ..         ...  ...                           ...
# 95        1985  ...                          ACCA
# 96        1965  ...                          ACCA
# 97        2005  ...                          ACCA
# 98        1965  ...                          ACCA
# 99        1940  ...                          ACCA
#
#     heat_pump_fraction_heat_load_served  heat_pump_fraction_cool_load_served  \
# 0                                     1                                    1
# 1                                     1                                    1
# 2                                     1                                    1
# 3                                     1                                    1
# 4                                     1                                    1
# ..                                  ...                                  ...
# 95                                    1                                    1
# 96                                    1                                    1
# 97                                    1                                    1
# 98                                    1                                    1
# 99                                    1                                    1
#
#     heat_pump_backup_type heat_pump_backup_fuel  \
# 0                    none           electricity
# 1                    none           electricity
# 2                    none           electricity
# 3                    none           electricity
# 4                    none           electricity
# ..                    ...                   ...
# 95                   none           electricity
# 96                   none           electricity
# 97                   none           electricity
# 98                   none           electricity
# 99                   none           electricity
#
#     heat_pump_backup_heating_efficiency geothermal_loop_configuration  \
# 0                                   1.0                          none
# 1                                   1.0                          none
# 2                                   1.0                          none
# 3                                   1.0                          none
# 4                                   1.0                          none
# ..                                  ...                           ...
# 95                                  1.0                          none
# 96                                  1.0                          none
# 97                                  1.0                          none
# 98                                  1.0                          none
# 99                                  1.0                          none
#
#         cooling_system_type  cooling_system_cooling_compressor_type  \
# 0                mini-split                          variable speed
# 1                mini-split                          variable speed
# 2   central air conditioner                            single stage
# 3   central air conditioner                            single stage
# 4                      none                                    None
# ..                      ...                                     ...
# 95  central air conditioner                            single stage
# 96  central air conditioner                            single stage
# 97               mini-split                          variable speed
# 98               mini-split                          variable speed
# 99               mini-split                          variable speed
#
#     heat_pump_compressor_lockout_temp
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 95                                NaN
# 96                                NaN
# 97                                NaN
# 98                                NaN
# 99                                NaN
#
# [100 rows x 65 columns]
