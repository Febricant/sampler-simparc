# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 100
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire


MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)
display(pd.DataFrame(lst_dct_args))
dfHPXML = pd.DataFrame(lst_dct_HPXML)
dfHPXML.to_csv("building-test.csv", index=False)
dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  66
#    geometry_building_num_units Infiltration  \
# 0                            3      5 ACH50
# 1                            1      4 ACH50
# 2                            1      3 ACH50
# 3                           49      3 ACH50
# 4                            1      4 ACH50
# ..                         ...          ...
# 95                           3      6 ACH50
# 96                           5      8 ACH50
# 97                           1      6 ACH50
# 98                           3     10 ACH50
# 99                           1      5 ACH50
#
#                                   Windows    Insulation Wall  \
# 0               Double, Clear, Metal, Air  QC_WoodStud-R12.6
# 1   Double, Low-E, Non-metal, Air, L-Gain    QC_WoodStud-R14
# 2           Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 3           Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 4           Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# ..                                    ...                ...
# 95          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 96          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
# 97          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# 98  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R12.2
# 99          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
#
#    Insulation Ceiling Insulation Foundation Wall  \
# 0            QC_R18.3    QC_Wall-R14.4, interior
# 1            QC_R24.6      QC_Wall-R12, interior
# 2            QC_R30.9    QC_Wall-R17.1, interior
# 3              QC_R41      QC_Wall-R17, interior
# 4            QC_R30.9    QC_Wall-R17.1, interior
# ..                ...                        ...
# 95           QC_R12.5    QC_Wall-R10.1, interior
# 96           QC_R12.5    QC_Wall-R10.1, interior
# 97           QC_R24.6      QC_Wall-R12, interior
# 98           QC_R12.5    QC_Wall-R10.1, interior
# 99           QC_R27.3    QC_Wall-R14.4, interior
#
#    Geometry Wall Exterior Finish geometry attic type HVAC Has Shared System  \
# 0                           None        Vented Attic                   None
# 1                           None        Vented Attic                   None
# 2                           None        Vented Attic                   None
# 3                           None        Vented Attic                   None
# 4                           None        Vented Attic                   None
# ..                           ...                 ...                    ...
# 95                          None        Vented Attic                   None
# 96                          None        Vented Attic                   None
# 97                          None        Vented Attic                   None
# 98                          None        Vented Attic                   None
# 99                          None        Vented Attic                   None
#
#                 HVAC Heating Efficiency  ... Mode_Occupation An_Construction  \
# 0   Electric Baseboard, 100% Efficiency  ...       Locataire   [1970 - 1980)
# 1   Electric Baseboard, 100% Efficiency  ...    Proprietaire   [1950 - 1960)
# 2                 Fuel Boiler, 72% AFUE  ...       Locataire   [1990 - 2000)
# 3      Electric Wall Furnace, 100% AFUE  ...       Locataire   [2010 - 2020)
# 4      Electric Wall Furnace, 100% AFUE  ...    Proprietaire   [1990 - 2000)
# ..                                  ...  ...             ...             ...
# 95  Electric Baseboard, 100% Efficiency  ...    Proprietaire          < 1950
# 96  Electric Baseboard, 100% Efficiency  ...       Locataire          < 1950
# 97  Electric Baseboard, 100% Efficiency  ...    Proprietaire   [1960 - 1970)
# 98  Electric Baseboard, 100% Efficiency  ...       Locataire          < 1950
# 99              ASHP, SEER 15, 8.5 HSPF  ...       Locataire   [1970 - 1980)
#
#    Source_Energie_Chauf                               Chauffage_Logement  \
# 0           Electricite                             Plinthes électriques
# 1           Electricite                             Plinthes électriques
# 2                  Bois                        Fournaise ou poêle à bois
# 3           Electricite  Unités convecteurs, plancher ou plafond radiant
# 4           Electricite  Unités convecteurs, plancher ou plafond radiant
# ..                  ...                                              ...
# 95          Electricite                             Plinthes électriques
# 96          Electricite                             Plinthes électriques
# 97          Electricite                             Plinthes électriques
# 98          Electricite                             Plinthes électriques
# 99          Electricite                                      Thermopompe
#
#            Nombre_Etages Nombre_Pieces Nombre_Personnes Superficie_Totale  \
# 0               Un étage             2                1     [1000 - 1500)
# 1            Deux étages            11        5 et plus     [2000 - 2500)
# 2   Trois étages et plus            12                2     [3500 - 4000)
# 3               Un étage             3                1     [1000 - 1500)
# 4            Deux étages             8                2     [2000 - 2500)
# ..                   ...           ...              ...               ...
# 95              Un étage             4        5 et plus     [1000 - 1500)
# 96              Un étage             3                1     [1000 - 1500)
# 97  Trois étages et plus             7                3     [2500 - 3000)
# 98              Un étage             3                1      [500 - 1000)
# 99              Un étage             5                4         [1 - 500)
#
#                     Presence_SousSol               Presence_Garage
# 0   Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# 1                    Sous sol 6 pied                 Pas de Garage
# 2                    Sous sol 6 pied                 Pas de Garage
# 3   Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# 4   Aucun Sous-sol ou vide sanitaire            Garage non chauffé
# ..                               ...                           ...
# 95  Aucun Sous-sol ou vide sanitaire  Garage chauffé à électricité
# 96  Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# 97                   Sous sol 6 pied                 Pas de Garage
# 98  Aucun Sous-sol ou vide sanitaire                 Pas de Garage
# 99                   Sous sol 6 pied  Garage chauffé à électricité
#
# [100 rows x 23 columns]
#    geometry_building_num_units  \
# 0                            3
# 1                            1
# 2                            1
# 3                           49
# 4                            1
# ..                         ...
# 95                           3
# 96                           5
# 97                           1
# 98                           3
# 99                           1
#
#                          weather_station_epw_filepath  \
# 0   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4   2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                ...
# 95  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 96  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 97  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 98  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 99  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#     simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                         True                         -5
# 1                                         True                         -5
# 2                                         True                         -5
# 3                                         True                         -5
# 4                                         True                         -5
# ..                                         ...                        ...
# 95                                        True                         -5
# 96                                        True                         -5
# 97                                        True                         -5
# 98                                        True                         -5
# 99                                        True                         -5
#
#         geometry_unit_type  geometry_average_ceiling_height  \
# 0           apartment unit                                8
# 1   single-family detached                                8
# 2   single-family detached                                8
# 3           apartment unit                                8
# 4   single-family detached                                8
# ..                     ...                              ...
# 95          apartment unit                                8
# 96          apartment unit                                8
# 97  single-family detached                                8
# 98          apartment unit                                8
# 99  single-family detached                                8
#
#     geometry_unit_aspect_ratio  geometry_unit_cfa  geometry_garage_protrusion  \
# 0                       0.5556               1138                        0.50
# 1                       1.8000               2179                        0.50
# 2                       1.8000               3750                        0.50
# 3                       0.5556               1138                        0.50
# 4                       1.8000               2179                        0.50
# ..                         ...                ...                         ...
# 95                      0.5556               1138                        0.50
# 96                      0.5556               1138                        0.50
# 97                      1.8000               2678                        0.50
# 98                      0.5556                750                        0.50
# 99                      1.8000                298                        0.75
#
#     year_built  ...  heat_pump_fraction_cool_load_served  \
# 0         1975  ...                                  1.0
# 1         1955  ...                                  1.0
# 2         1995  ...                                  1.0
# 3         2015  ...                                  1.0
# 4         1995  ...                                  1.0
# ..         ...  ...                                  ...
# 95        1940  ...                                  1.0
# 96        1940  ...                                  1.0
# 97        1965  ...                                  1.0
# 98        1940  ...                                  1.0
# 99        1975  ...                                  1.0
#
#     heat_pump_backup_use_existing_system  heat_pump_backup_type  \
# 0                                  false                   none
# 1                                  false                   none
# 2                                  false                   none
# 3                                  false                   none
# 4                                  false                   none
# ..                                   ...                    ...
# 95                                 false                   none
# 96                                 false                   none
# 97                                 false                   none
# 98                                 false                   none
# 99                                 false             integrated
#
#     heat_pump_backup_fuel heat_pump_backup_heating_efficiency  \
# 0             electricity                                 1.0
# 1             electricity                                 1.0
# 2             electricity                                 1.0
# 3             electricity                                 1.0
# 4             electricity                                 1.0
# ..                    ...                                 ...
# 95            electricity                                 1.0
# 96            electricity                                 1.0
# 97            electricity                                 1.0
# 98            electricity                                 1.0
# 99            electricity                                 1.0
#
#     geothermal_loop_configuration      cooling_system_type  \
# 0                            none  central air conditioner
# 1                            none                     none
# 2                            none               mini-split
# 3                            none  central air conditioner
# 4                            none                     none
# ..                            ...                      ...
# 95                           none  central air conditioner
# 96                           none  central air conditioner
# 97                           none               mini-split
# 98                           none               mini-split
# 99                           none                     none
#
#     cooling_system_cooling_compressor_type  heat_pump_is_ducted  \
# 0                             single stage                  NaN
# 1                                     None                  NaN
# 2                           variable speed                  NaN
# 3                             single stage                  NaN
# 4                                     None                  NaN
# ..                                     ...                  ...
# 95                            single stage                  NaN
# 96                            single stage                  NaN
# 97                          variable speed                  NaN
# 98                          variable speed                  NaN
# 99                                     NaN                 true
#
#     heat_pump_cooling_compressor_type
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 95                                NaN
# 96                                NaN
# 97                                NaN
# 98                                NaN
# 99                       single stage
#
# [100 rows x 68 columns]
