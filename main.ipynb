# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBachArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Load the Bayesian Network from the saved file
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

# Display the Bayesian Network - Avant enregistrement
#gnb.showInference(InsClsSampler.bn,evs={},size = '30')

Nombre_de_Samples = 10
Evidence = {}#"Type_Logement": "Collective",
            #"Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Fait un échantillonage - Avant enregistrement
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement

#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBachArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire


MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)
display(pd.DataFrame(lst_dct_args))
dfHPXML = pd.DataFrame(lst_dct_HPXML)
dfHPXML.to_csv("building-test.csv", index=False)
#dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  49
#   geometry_building_num_units Infiltration                        Windows  \
# 0                          15      3 ACH50      Double, Clear, Metal, Air
# 1                           1     10 ACH50      Double, Clear, Metal, Air
# 2                           6      3 ACH50      Double, Clear, Metal, Air
# 3                           1      6 ACH50  Double, Clear, Non-metal, Air
# 4                           8     10 ACH50           Single, Clear, Metal
# 5                           1      6 ACH50  Double, Clear, Non-metal, Air
# 6                           1      3 ACH50  Double, Clear, Non-metal, Air
# 7                           1      4 ACH50  Double, Clear, Non-metal, Air
# 8                           1     20 ACH50  Double, Clear, Non-metal, Air
# 9                           8      3 ACH50  Double, Clear, Non-metal, Air
#
#      Insulation_Wall Insulation_Ceiling Insulation_Foundation_Wall  \
# 0  QC_WoodStud-R18.9           QC_R29.8    QC_Wall-R17.1, interior
# 1  QC_WoodStud-R14.5           QC_R19.6    QC_Wall-R10.1, interior
# 2  QC_WoodStud-R18.9           QC_R29.8    QC_Wall-R17.1, interior
# 3  QC_WoodStud-R20.7           QC_R30.9    QC_Wall-R17.1, interior
# 4  QC_WoodStud-R12.6           QC_R18.3      QC_Wall-R12, interior
# 5    QC_WoodStud-R14           QC_R24.6      QC_Wall-R12, interior
# 6  QC_WoodStud-R17.2           QC_R27.3    QC_Wall-R14.4, interior
# 7  QC_WoodStud-R20.7           QC_R30.9    QC_Wall-R17.1, interior
# 8  QC_WoodStud-R14.5           QC_R19.6    QC_Wall-R10.1, interior
# 9  QC_WoodStud-R24.5             QC_R41      QC_Wall-R17, interior
#
#   Geometry_Wall_Exterior_Finish geometry attic type HVAC_Has_Shared_System  \
# 0                          None        Vented Attic                   None
# 1                          None        Vented Attic                   None
# 2                          None        Vented Attic                   None
# 3                          None        Vented Attic                   None
# 4                          None        Vented Attic                   None
# 5                          None        Vented Attic                   None
# 6                          None        Vented Attic                   None
# 7                          None        Vented Attic                   None
# 8                          None        Vented Attic                   None
# 9                          None        Vented Attic                   None
#
#   Territoire_HQ  ...              Climatisation         Nombre_Etages  \
# 0   Laurentides  ...  Fenêtre, mobile, portable              Un étage
# 1   Laurentides  ...                     Aucune           Deux étages
# 2   Montmorency  ...                     Murale              Un étage
# 3     Richelieu  ...                     Murale  Trois étages et plus
# 4      Montréal  ...                     Murale              Un étage
# 5     Richelieu  ...                     Murale           Deux étages
# 6   Montmorency  ...                     Murale  Trois étages et plus
# 7   Laurentides  ...                     Aucune           Deux étages
# 8   Montmorency  ...                     Murale           Deux étages
# 9     Richelieu  ...                     Murale              Un étage
#
#   Nombre_Pieces Superficie_Totale Nombre_Personnes  \
# 0             3      [500 - 1000)                1
# 1             3     [4000 - 4500)                1
# 2             5     [1000 - 1500)                1
# 3             7     [2000 - 2500)                2
# 4             3     [1000 - 1500)                1
# 5             8     [1500 - 2000)                4
# 6             7     [1000 - 1500)                3
# 7             6     [2000 - 2500)                2
# 8             8     [1500 - 2000)                4
# 9             5     [1000 - 1500)                2
#
#                    Presence_SousSol An_Construction Source_Energie_Chauf  \
# 0  Aucun Sous-sol ou vide sanitaire   [1980 - 1990)          Electricite
# 1                   Sous sol 6 pied          < 1950          Electricite
# 2  Aucun Sous-sol ou vide sanitaire   [1990 - 2000)          Electricite
# 3                   Sous sol 6 pied   [1980 - 1990)          Electricite
# 4  Aucun Sous-sol ou vide sanitaire   [1950 - 1960)          Electricite
# 5                   Sous sol 6 pied   [1960 - 1970)          Electricite
# 6                   Sous sol 6 pied   [1970 - 1980)          Electricite
# 7                   Sous sol 6 pied   [1990 - 2000)          Electricite
# 8      Vide sanitaire moins 6 pieds          < 1950                 Bois
# 9  Aucun Sous-sol ou vide sanitaire   [2010 - 2020)          Electricite
#
#   Mode_Occupation               Presence_Garage
# 0    Proprietaire                 Pas de Garage
# 1    Proprietaire  Garage chauffé à électricité
# 2       Locataire                 Pas de Garage
# 3    Proprietaire  Garage chauffé à électricité
# 4       Locataire                 Pas de Garage
# 5    Proprietaire                 Pas de Garage
# 6    Proprietaire                 Pas de Garage
# 7       Locataire            Garage non chauffé
# 8    Proprietaire                 Pas de Garage
# 9       Locataire                 Pas de Garage
#
# [10 rows x 21 columns]
#   geometry_building_num_units  \
# 0                          15
# 1                           1
# 2                           6
# 3                           1
# 4                           8
# 5                           1
# 6                           1
# 7                           1
# 8                           1
# 9                           8
#
#                         weather_station_epw_filepath  \
# 0  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 3  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 4  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 5  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 6  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 7  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 8  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 9  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#    simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                        True                         -5
# 1                                        True                         -5
# 2                                        True                         -5
# 3                                        True                         -5
# 4                                        True                         -5
# 5                                        True                         -5
# 6                                        True                         -5
# 7                                        True                         -5
# 8                                        True                         -5
# 9                                        True                         -5
#
#        geometry_unit_type  geometry_average_ceiling_height  \
# 0          apartment unit                                8
# 1  single-family detached                                8
# 2          apartment unit                                8
# 3  single-family detached                                8
# 4          apartment unit                                8
# 5  single-family detached                                8
# 6  single-family detached                                8
# 7  single-family detached                                8
# 8  single-family detached                                8
# 9          apartment unit                                8
#
#    geometry_unit_aspect_ratio  geometry_unit_cfa  geometry_garage_protrusion  \
# 0                      0.5556                750                         0.5
# 1                      1.8000               4250                         0.5
# 2                      0.5556               1138                         0.5
# 3                      1.8000               2179                         0.5
# 4                      0.5556               1138                         0.5
# 5                      1.8000               1698                         0.5
# 6                      1.8000               1228                         0.5
# 7                      1.8000               2179                         0.5
# 8                      1.8000               1698                         0.5
# 9                      0.5556               1138                         0.5
#
#    year_built  ...  air_leakage_value    air_leakage_type  \
# 0        1985  ...                  5  unit exterior only
# 1        1940  ...                  5  unit exterior only
# 2        1995  ...                  5  unit exterior only
# 3        1985  ...                  5  unit exterior only
# 4        1955  ...                  5  unit exterior only
# 5        1965  ...                  5  unit exterior only
# 6        1975  ...                  5  unit exterior only
# 7        1995  ...                  5  unit exterior only
# 8        1940  ...                  5  unit exterior only
# 9        2015  ...                  5  unit exterior only
#
#    site_shielding_of_home  rim_joist_assembly_r  \
# 0                  normal                   0.0
# 1                  normal                   2.5
# 2                  normal                   0.0
# 3                  normal                   2.5
# 4                  normal                   0.0
# 5                  normal                   2.5
# 6                  normal                   2.5
# 7                  normal                   2.5
# 8                  normal                   2.5
# 9                  normal                   0.0
#
#   geometry_unit_left_wall_is_adiabatic  geometry_unit_right_wall_is_adiabatic  \
# 0                                False                                  False
# 1                                False                                  False
# 2                                False                                  False
# 3                                False                                  False
# 4                                False                                  False
# 5                                False                                  False
# 6                                False                                  False
# 7                                False                                  False
# 8                                False                                  False
# 9                                False                                  False
#
#   geometry_unit_front_wall_is_adiabatic  geometry_unit_back_wall_is_adiabatic  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
# 5                                 False                                 False
# 6                                 False                                 False
# 7                                 False                                 False
# 8                                 False                                 False
# 9                                 False                                 False
#
#        cooling_system_type  cooling_system_cooling_compressor_type
# 0  central air conditioner                            single stage
# 1                     none                            single stage
# 2               mini-split                          variable speed
# 3               mini-split                          variable speed
# 4               mini-split                          variable speed
# 5               mini-split                          variable speed
# 6               mini-split                          variable speed
# 7                     none                            single stage
# 8               mini-split                          variable speed
# 9               mini-split                          variable speed
#
# [10 rows x 49 columns]
