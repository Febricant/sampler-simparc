# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  66
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                   1                               1
# 2                   1                               2
# 3                   1                               1
# 4                   1                               1
# ..                ...                             ...
# 195                 1                               1
# 196                 1                               1
# 197                 1                               8
# 198                21                             183
# 199                 1                               1
#
#     Geometry Building Horizontal Location Infiltration  \
# 0                          Not Applicable      3 ACH50
# 1                          Not Applicable      3 ACH50
# 2                                   Right     10 ACH50
# 3                          Not Applicable      5 ACH50
# 4                          Not Applicable      7 ACH50
# ..                                    ...          ...
# 195                        Not Applicable      2 ACH50
# 196                        Not Applicable      7 ACH50
# 197                                 Right      4 ACH50
# 198                                 Right      3 ACH50
# 199                        Not Applicable      8 ACH50
#
#                                    Windows    Insulation Wall  \
# 0    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R17.2
# 1    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# 2    Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R17.2
# 3            Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 4    Double, Low-E, Non-metal, Air, M-Gain  QC_WoodStud-R14.5
# ..                                     ...                ...
# 195          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 196  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R20.7
# 197          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# 198  Triple, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R18.9
# 199  Double, Low-E, Non-metal, Air, L-Gain  QC_WoodStud-R14.5
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R27.3    QC_Wall-R14.4, interior
# 1             QC_R30.9    QC_Wall-R17.1, interior
# 2             QC_R27.3    QC_Wall-R14.4, interior
# 3             QC_R30.9    QC_Wall-R17.1, interior
# 4             QC_R19.6    QC_Wall-R10.1, interior
# ..                 ...                        ...
# 195             QC_R41      QC_Wall-R17, interior
# 196           QC_R30.9    QC_Wall-R17.1, interior
# 197           QC_R18.3    QC_Wall-R14.4, interior
# 198           QC_R29.8    QC_Wall-R17.1, interior
# 199           QC_R19.6    QC_Wall-R10.1, interior
#
#     Geometry Wall Exterior Finish geometry attic type  ... Mode_Occupation  \
# 0                            None        Vented Attic  ...    Proprietaire
# 1                            None        Vented Attic  ...    Proprietaire
# 2                            None        Vented Attic  ...    Proprietaire
# 3                            None        Vented Attic  ...    Proprietaire
# 4                            None        Vented Attic  ...    Proprietaire
# ..                            ...                 ...  ...             ...
# 195                          None        Vented Attic  ...    Proprietaire
# 196                          None        Vented Attic  ...    Proprietaire
# 197                          None        Vented Attic  ...       Locataire
# 198                          None        Vented Attic  ...    Proprietaire
# 199                          None        Vented Attic  ...       Locataire
#
#             Nombre_Etages Nombre_Pieces Nombre_Personnes Superficie_Totale  \
# 0             Deux étages             8        5 et plus     [2000 - 2500)
# 1             Deux étages             8                3     [2000 - 2500)
# 2    Trois étages et plus             8                3     [1000 - 1500)
# 3             Deux étages             6                3     [1000 - 1500)
# 4                Un étage             4                3     [2000 - 2500)
# ..                    ...           ...              ...               ...
# 195           Deux étages             8                3     [2500 - 3000)
# 196           Deux étages             9                1           >= 5000
# 197              Un étage             4                2      [500 - 1000)
# 198              Un étage             3                2     [1000 - 1500)
# 199           Deux étages             8                1     [1000 - 1500)
#
#                      Presence_SousSol An_Construction Source_Energie_Chauf  \
# 0                     Sous sol 6 pied   [1970 - 1980)          Electricite
# 1                     Sous sol 6 pied   [1980 - 1990)                 Bois
# 2                     Sous sol 6 pied   [1970 - 1980)          Electricite
# 3                     Sous sol 6 pied   [1980 - 1990)                 Bois
# 4                     Sous sol 6 pied          < 1950          Electricite
# ..                                ...             ...                  ...
# 195                   Sous sol 6 pied   [2010 - 2020)                 Bois
# 196                   Sous sol 6 pied   [1990 - 2000)          Electricite
# 197  Aucun Sous-sol ou vide sanitaire   [1970 - 1980)          Electricite
# 198  Aucun Sous-sol ou vide sanitaire   [1980 - 1990)          Electricite
# 199                   Sous sol 6 pied          < 1950          Electricite
#
#                            Chauffage_Logement              Climatisation
# 0                 Système central à air chaud                   Centrale
# 1                   Fournaise ou poêle à bois                     Aucune
# 2                        Plinthes électriques  Fenêtre, mobile, portable
# 3                   Fournaise ou poêle à bois                     Murale
# 4                Système central à eau chaude                     Aucune
# ..                                        ...                        ...
# 195  Fournaise ou poêle à bois et Thermopompe                     Murale
# 196                      Plinthes électriques  Fenêtre, mobile, portable
# 197               Système central à air chaud  Fenêtre, mobile, portable
# 198                      Plinthes électriques  Fenêtre, mobile, portable
# 199                      Plinthes électriques                   Centrale
#
# [200 rows x 25 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 2    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 3    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 4    2020s_CAN_QC_Saguenay-Bagotville.AP-CFB.Bagotv...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 197  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 198  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 199  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                              1  single-family detached
# 2                              2  single-family attached
# 3                              1  single-family detached
# 4                              1  single-family detached
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                            1  single-family detached
# 197                            8          apartment unit
# 198                          183          apartment unit
# 199                            1  single-family detached
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      1.8000
# 2                                  8                      0.5556
# 3                                  8                      1.8000
# 4                                  8                      1.8000
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      1.8000
# 197                                8                      0.5556
# 198                                8                      0.5556
# 199                                8                      1.8000
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 2179                         0.5        1975  ...
# 1                 2179                         0.5        1985  ...
# 2                 1207                         0.5        1975  ...
# 3                 1228                         0.5        1985  ...
# 4                 2179                         0.5        1940  ...
# ..                 ...                         ...         ...  ...
# 195               2678                         0.5        2015  ...
# 196               5587                         0.5        1995  ...
# 197                750                         0.5        1975  ...
# 198               1138                         0.5        1985  ...
# 199               1228                         0.5        1940  ...
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2              electricity                                  1.0
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199            electricity                                  1.0
#
#      geothermal_loop_configuration      cooling_system_type  \
# 0                             none  central air conditioner
# 1                             none                     none
# 2                             none  central air conditioner
# 3                             none               mini-split
# 4                             none                     none
# ..                             ...                      ...
# 195                           none               mini-split
# 196                           none  central air conditioner
# 197                           none  central air conditioner
# 198                           none  central air conditioner
# 199                           none  central air conditioner
#
#     cooling_system_cooling_compressor_type  heat_pump_is_ducted  \
# 0                             single stage                  NaN
# 1                                     None                  NaN
# 2                             single stage                  NaN
# 3                           variable speed                  NaN
# 4                                     None                  NaN
# ..                                     ...                  ...
# 195                         variable speed                  NaN
# 196                           single stage                  NaN
# 197                           single stage                  NaN
# 198                           single stage                  NaN
# 199                           single stage                  NaN
#
#     heat_pump_compressor_lockout_temp  heat_pump_cooling_compressor_type  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ..                                ...                                ...
# 195                               NaN                                NaN
# 196                               NaN                                NaN
# 197                               NaN                                NaN
# 198                               NaN                                NaN
# 199                               NaN                                NaN
#
#      overhangs_front_depth  overhangs_front_distance_to_top_of_window
# 0                      NaN                                        NaN
# 1                      NaN                                        NaN
# 2                      NaN                                        NaN
# 3                      NaN                                        NaN
# 4                      NaN                                        NaN
# ..                     ...                                        ...
# 195                    NaN                                        NaN
# 196                    NaN                                        NaN
# 197                    NaN                                        NaN
# 198                    NaN                                        NaN
# 199                    NaN                                        NaN
#
# [200 rows x 71 columns]
