# %%
import os
import sys
import pandas as pd

from utils.Sampler import Sampler, BuildstockBatchArguments, MapHPXML

PROJECT_DIR = os.getcwd()

# %%
# Chargement du BN
InsClsSampler = Sampler()
path = PROJECT_DIR+"/data/BayesianNetwork/BN_EUEMr.XDSL"
InsClsSampler.Load_BN(path)

Nombre_de_Samples = 200
Evidence = {}
#Evidence = {"Type_Logement": "Maison en rangee"}
#            "Nombre_Pieces": "1"}#{"Mode_Occupation": "Proprietaire"}

# Exécution de l'échantillonnage
df1 = InsClsSampler.do_Sampling(Nombre_de_Samples, evs = Evidence)
lst_dct_args = df1.to_dict(orient='records')
# Affiche les échantillons - Avant enregistrement
#s.getBNStructure()
#print(s.lst_NOEUD, s.LIST_Dict)

#Ajout de varaible hors BN
Bba = BuildstockBatchArguments()
lst_dct_args2 = Bba.sampling( lst_dct_args)

lst_dct_args = [ d2 | d1 for d1, d2 in zip(lst_dct_args, lst_dct_args2)]#lst_dct_args prioritaire

# Correspondance HPXML
MapSample = MapHPXML()
lst_dct_HPXML = MapSample.run(lst_dct_args)

#Affichage et enregistrement
print("Nombre d'attributs HPXML: ", len(lst_dct_HPXML[0].keys()))
#display(df1)

dfargs = pd.DataFrame(lst_dct_args)
dfHPXML = pd.DataFrame(lst_dct_HPXML)

dfargs.to_csv("building-input.csv", index=False)
dfHPXML.to_csv("building-test.csv", index=False)

dfHPXML.to_csv("N://Mes Documents//Projets LTE//Projet archQc//code//LTE-OPENSTUDIO-CLI//V7 Openstudio 3.7//LTE-OpenStudioCLI-Test//"+"building-test.csv", index=False)
display(dfargs)
display(dfHPXML)
# Out:
# Nombre d'attributs HPXML:  66
#      Geometry Stories  Geometry Building Number Units  \
# 0                   1                               1
# 1                   2                               2
# 2                   1                               1
# 3                   1                               1
# 4                  20                              67
# ..                ...                             ...
# 195                 1                               1
# 196                 1                               1
# 197                 1                               1
# 198                 1                               1
# 199                 9                             183
#
#     Geometry Building Horizontal Location Geometry Building Level  \
# 0                          Not Applicable                    None
# 1                          Not Applicable                     Top
# 2                          Not Applicable                    None
# 3                          Not Applicable                    None
# 4                                  Middle                  Middle
# ..                                    ...                     ...
# 195                        Not Applicable                    None
# 196                        Not Applicable                    None
# 197                        Not Applicable                    None
# 198                        Not Applicable                    None
# 199                                Middle                  Middle
#
#     Infiltration                                Windows    Insulation Wall  \
# 0        8 ACH50                   Single, Clear, Metal  QC_WoodStud-R17.2
# 1        4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R24.5
# 2        7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R17.2
# 3        7 ACH50          Double, Clear, Non-metal, Air    QC_WoodStud-R14
# 4        7 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.6
# ..           ...                                    ...                ...
# 195     10 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R14.5
# 196      7 ACH50  Triple, Low-E, Non-metal, Air, L-Gain    QC_WoodStud-R14
# 197      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 198      3 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R20.7
# 199      4 ACH50          Double, Clear, Non-metal, Air  QC_WoodStud-R12.2
#
#     Insulation Ceiling Insulation Foundation Wall  \
# 0             QC_R27.3    QC_Wall-R14.4, interior
# 1               QC_R41      QC_Wall-R17, interior
# 2             QC_R27.3    QC_Wall-R14.4, interior
# 3             QC_R24.6      QC_Wall-R12, interior
# 4             QC_R18.3      QC_Wall-R12, interior
# ..                 ...                        ...
# 195           QC_R19.6    QC_Wall-R10.1, interior
# 196           QC_R24.6      QC_Wall-R12, interior
# 197           QC_R30.9    QC_Wall-R17.1, interior
# 198           QC_R30.9    QC_Wall-R17.1, interior
# 199           QC_R12.5    QC_Wall-R10.1, interior
#
#     Geometry Wall Exterior Finish  ... Source_Energie_Chauf  \
# 0                            None  ...          Electricite
# 1                            None  ...          Electricite
# 2                            None  ...           Bi-energie
# 3                            None  ...          Electricite
# 4                            None  ...          Electricite
# ..                            ...  ...                  ...
# 195                          None  ...          Electricite
# 196                          None  ...          Electricite
# 197                          None  ...          Electricite
# 198                          None  ...          Electricite
# 199                          None  ...          Electricite
#
#                                   Chauffage_Logement  \
# 0                        Système central à air chaud
# 1                               Plinthes électriques
# 2                                        Thermopompe
# 3                                        Thermopompe
# 4                               Plinthes électriques
# ..                                               ...
# 195                                      Thermopompe
# 196                             Plinthes électriques
# 197                                      Thermopompe
# 198  Unités convecteurs, plancher ou plafond radiant
# 199                  Fournaise murale ou de plancher
#
#                  Climatisation         Nombre_Etages  \
# 0                       Murale           Deux étages
# 1    Fenêtre, mobile, portable              Un étage
# 2                     Centrale           Deux étages
# 3                     Centrale           Deux étages
# 4                       Murale              Un étage
# ..                         ...                   ...
# 195                     Murale           Deux étages
# 196  Fenêtre, mobile, portable           Deux étages
# 197                     Murale           Deux étages
# 198                     Murale  Trois étages et plus
# 199                     Murale              Un étage
#
#                      Presence_SousSol Nombre_Pieces Nombre_Personnes  \
# 0                     Sous sol 6 pied            10                4
# 1    Aucun Sous-sol ou vide sanitaire             5                4
# 2                     Sous sol 6 pied             8                2
# 3                     Sous sol 6 pied             7                3
# 4    Aucun Sous-sol ou vide sanitaire             3                1
# ..                                ...           ...              ...
# 195                   Sous sol 6 pied             7                3
# 196                   Sous sol 6 pied             6                2
# 197                   Sous sol 6 pied             7                3
# 198                   Sous sol 6 pied             9                2
# 199  Aucun Sous-sol ou vide sanitaire             4                1
#
#     Superficie_Totale Mode_Occupation               Presence_Garage
# 0       [2000 - 2500)    Proprietaire  Garage chauffé à électricité
# 1       [1000 - 1500)    Proprietaire                 Pas de Garage
# 2       [2000 - 2500)    Proprietaire            Garage non chauffé
# 3       [2500 - 3000)    Proprietaire                 Pas de Garage
# 4        [500 - 1000)       Locataire                 Pas de Garage
# ..                ...             ...                           ...
# 195     [2000 - 2500)    Proprietaire                 Pas de Garage
# 196     [2000 - 2500)       Locataire                 Pas de Garage
# 197     [1000 - 1500)    Proprietaire  Garage chauffé à électricité
# 198      [500 - 1000)    Proprietaire                 Pas de Garage
# 199      [500 - 1000)       Locataire                 Pas de Garage
#
# [200 rows x 27 columns]
#                           weather_station_epw_filepath  \
# 0    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 1    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 2    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 3    2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 4    2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# ..                                                 ...
# 195  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 196  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 197  2020s_CAN_QC_Quebec-Lesage.Intl.AP.717140_CWEC...
# 198  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
# 199  2020s_CAN_QC_Montreal-McTavish.716120_CWEC2016...
#
#      simulation_control_daylight_saving_enabled  site_time_zone_utc_offset  \
# 0                                          True                         -5
# 1                                          True                         -5
# 2                                          True                         -5
# 3                                          True                         -5
# 4                                          True                         -5
# ..                                          ...                        ...
# 195                                        True                         -5
# 196                                        True                         -5
# 197                                        True                         -5
# 198                                        True                         -5
# 199                                        True                         -5
#
#      geometry_building_num_units      geometry_unit_type  \
# 0                              1  single-family detached
# 1                              2          apartment unit
# 2                              1  single-family detached
# 3                              1  single-family detached
# 4                             67          apartment unit
# ..                           ...                     ...
# 195                            1  single-family detached
# 196                            1  single-family detached
# 197                            1  single-family detached
# 198                            1  single-family detached
# 199                          183          apartment unit
#
#      geometry_average_ceiling_height  geometry_unit_aspect_ratio  \
# 0                                  8                      1.8000
# 1                                  8                      0.5556
# 2                                  8                      1.8000
# 3                                  8                      1.8000
# 4                                  8                      0.5556
# ..                               ...                         ...
# 195                                8                      1.8000
# 196                                8                      1.8000
# 197                                8                      1.8000
# 198                                8                      1.8000
# 199                                8                      0.5556
#
#      geometry_unit_cfa  geometry_garage_protrusion  year_built  ...  \
# 0                 2179                         0.5        1975  ...
# 1                 1138                         0.5        2015  ...
# 2                 2179                         0.5        1975  ...
# 3                 2678                         0.5        1965  ...
# 4                  750                         0.5        1965  ...
# ..                 ...                         ...         ...  ...
# 195               2179                         0.5        1940  ...
# 196               2179                         0.5        1955  ...
# 197               1228                         0.5        1995  ...
# 198                750                         0.5        1985  ...
# 199                750                         0.5        1940  ...
#
#      heat_pump_backup_fuel  heat_pump_backup_heating_efficiency  \
# 0              electricity                                  1.0
# 1              electricity                                  1.0
# 2                 fuel oil                                  0.8
# 3              electricity                                  1.0
# 4              electricity                                  1.0
# ..                     ...                                  ...
# 195            electricity                                  1.0
# 196            electricity                                  1.0
# 197            electricity                                  1.0
# 198            electricity                                  1.0
# 199            electricity                                  1.0
#
#      geothermal_loop_configuration      cooling_system_type  \
# 0                             none               mini-split
# 1                             none  central air conditioner
# 2                             none                     none
# 3                             none                     none
# 4                             none               mini-split
# ..                             ...                      ...
# 195                           none                     none
# 196                           none  central air conditioner
# 197                           none                     none
# 198                           none               mini-split
# 199                           none               mini-split
#
#     cooling_system_cooling_compressor_type  overhangs_front_depth  \
# 0                           variable speed                    NaN
# 1                             single stage                   10.0
# 2                                      NaN                    NaN
# 3                                      NaN                    NaN
# 4                           variable speed                    NaN
# ..                                     ...                    ...
# 195                                    NaN                    NaN
# 196                           single stage                    NaN
# 197                                    NaN                    NaN
# 198                         variable speed                    NaN
# 199                         variable speed                    NaN
#
#     overhangs_front_distance_to_top_of_window  heat_pump_is_ducted  \
# 0                                         NaN                  NaN
# 1                                         1.0                  NaN
# 2                                         NaN                 true
# 3                                         NaN                 true
# 4                                         NaN                  NaN
# ..                                        ...                  ...
# 195                                       NaN                 true
# 196                                       NaN                  NaN
# 197                                       NaN                 true
# 198                                       NaN                  NaN
# 199                                       NaN                  NaN
#
#      heat_pump_compressor_lockout_temp  heat_pump_cooling_compressor_type
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                 10.4                       single stage
# 3                                  NaN                       single stage
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 195                                NaN                       single stage
# 196                                NaN                                NaN
# 197                                NaN                       single stage
# 198                                NaN                                NaN
# 199                                NaN                                NaN
#
# [200 rows x 71 columns]
